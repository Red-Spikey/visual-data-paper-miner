# %% [markdown]
# # Connecting the Drive to the Notebook

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Download the Scopus.csv file and put it in MyDrive folder of your Google Drive

# %% [markdown]
# # Loading The CSV file

# %%
import pandas as pd
import requests
csv = pd.read_csv('/content/drive/MyDrive/ugp/scopus.csv')
df = pd.DataFrame(csv)
dois =df['DOI'].astype(str)

# %% [markdown]
# # Downloading the XMLs from Scopus using SCOPUS API

# %%
import os
status_code = []
j =1
os.makedirs('/content/drive/MyDrive/ugp/xmls',exist_ok = True)
for i, doi in enumerate(dois):
  xml_url='https://api.elsevier.com/content/article/doi/' + doi + '?view=FULL'

  headers = {
            'X-ELS-APIKEY': 'c8cf76a7333ef42cbb26d1ce3aadc8bd',
            'Accept': 'text/xml'
          }

  r = requests.get(xml_url,stream = True,  headers=headers, timeout=30)

  status_code.append(r.status_code)
  if r.status_code == 200:
    try:
      writefile  = open("/content/drive/MyDrive/ugp/xmls/" + str(j) + ".xml", 'wb')



      for chunk in r.iter_content(2048):
        writefile.write((chunk))
    except:
      continue
  j = j+1

df['StatusCode'] = status_code

df.to_csv('/content/drive/MyDrive/ugp/scopus.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3721076774.py in <cell line: 0>()
#      11           }
#      12
# ---> 13   r = requests.get(xml_url,stream = True,  headers=headers, timeout=30)
#      14
#      15   status_code.append(r.status_code)
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.12/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532         # Receive the response from the server
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#     536             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in getresponse(self)
#     563
#     564         # Get the response from http.client.HTTPConnection
# --> 565         httplib_response = super().getresponse()
#     566
#     567         try:
#
# /usr/lib/python3.12/http/client.py in getresponse(self)
#    1428         try:
#    1429             try:
# -> 1430                 response.begin()
#    1431             except ConnectionError:
#    1432                 self.close()
#
# /usr/lib/python3.12/http/client.py in begin(self)
#     329         # read until we get a non-100 response
#     330         while True:
# --> 331             version, status, reason = self._read_status()
#     332             if status != CONTINUE:
#     333                 break
#
# /usr/lib/python3.12/http/client.py in _read_status(self)
#     290
#     291     def _read_status(self):
# --> 292         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293         if len(line) > _MAXLINE:
#     294             raise LineTooLong("status line")
#
# /usr/lib/python3.12/socket.py in readinto(self, b)
#     718         while True:
#     719             try:
# --> 720                 return self._sock.recv_into(b)
#     721             except timeout:
#     722                 self._timeout_occurred = True
#
# /usr/lib/python3.12/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1249                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250                   self.__class__)
# -> 1251             return self.read(nbytes, buffer)
#    1252         else:
#    1253             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.12/ssl.py in read(self, len, buffer)
#    1101         try:
#    1102             if buffer is not None:
# -> 1103                 return self._sslobj.read(len, buffer)
#    1104             else:
#    1105                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Obtaining Tags for Images and Captions
# ## Using Element Tree to search the XML file

# %%
import xml.etree.ElementTree as ET
import pandas as pd
import csv
import re
os.makedirs('/content/drive/MyDrive/ugp/csvs',exist_ok=True)
for i, row in df.iterrows():
    status_code = row['StatusCode']
    if status_code == 200:
        print(i+1)
        xml_file = f'/content/drive/MyDrive/ugp/xmls/{i + 1}.xml'

        try:
            tree = ET.parse(xml_file)
            root = tree.getroot()

            images = []
            captions = []
            # Extracting tags for captions
            for figure in root.findall('.//ce:figure', namespaces={'ce': 'http://www.elsevier.com/xml/common/dtd'}):
                link_element = figure.find('.//ce:link', namespaces={'ce': 'http://www.elsevier.com/xml/common/dtd'})
                locator = link_element.attrib.get('locator') if link_element is not None else None

                caption_element = figure.find('.//ce:caption', namespaces={'ce': 'http://www.elsevier.com/xml/common/dtd'})
                if caption_element is not None:
                    simple_para_element = caption_element.find('.//ce:simple-para', namespaces={'ce': 'http://www.elsevier.com/xml/common/dtd'})
                    if simple_para_element is not None:
                        raw_caption = ET.tostring(simple_para_element, encoding='unicode', method='text')
                        caption = re.sub('<.*?>', '', raw_caption)
                        caption = " ".join(caption.split())
                    else:
                        caption = None
                    captions.append(caption)
                else:
                    captions.append(None)
            # Extracting tags for Image
            for attachment in root.findall('.//xocs:attachment', namespaces={'xocs': 'http://www.elsevier.com/xml/xocs/dtd'}):
                attachment_eid = attachment.find('.//xocs:attachment-eid', namespaces={'xocs': 'http://www.elsevier.com/xml/xocs/dtd'}).text
                ucs_locator = attachment.find('.//xocs:ucs-locator', namespaces={'xocs': 'http://www.elsevier.com/xml/xocs/dtd'}).text
                filename = attachment.find('.//xocs:filename', namespaces={'xocs': 'http://www.elsevier.com/xml/xocs/dtd'}).text
                images.append((attachment_eid, ucs_locator, filename))

            # Adding to the csv file
            with open(f'/content/drive/MyDrive/ugp/csvs/output{i + 1}.csv', 'w', newline='', encoding='utf-8') as csvfile:
                csv_writer = csv.writer(csvfile)
                csv_writer.writerow(['UTD EID', 'UCS Locator', 'Filename', 'Caption'])
                for image, caption in zip(images, captions):
                    csv_writer.writerow([image[0], image[1], image[2], caption])

            df_output = pd.read_csv(f'/content/drive/MyDrive/ugp/csvs/output{i + 1}.csv')
            df_output['link'] = df_output['UTD EID'].apply(lambda x: f'https://ars.els-cdn.com/content/image/{x}'.replace('.jpg', '_lrg.jpg'))
            df_output.to_csv(f'/content/drive/MyDrive/ugp/csvs/output{i + 1}.csv', index=False)

        except ET.ParseError as e:
            print(f"ParseError: {e}. The file {xml_file} might be incomplete or malformed.")
        except Exception as e:
            print(f"An error occurred while processing the file {xml_file}: {e}")
# Out:
# 3
# 10
# 15
# 27
# 29
# 36
# 41
# 52
# 60
# 70
# 97
# 101
# 127
# 144
# 150
# 175
# 180
# 196
# 231
# 235
# 252
# 268
# 275
# 281
# 291
# 311
# 318
# 332
# 340
# 346
# 351
# 363
# 367
# 383
# 393
# 408
# 414
# 435
# 442
# 463
# 489
# 498
# ParseError: no element found: line 14198, column 15. The file /content/drive/MyDrive/ugp/xmls/498.xml might be incomplete or malformed.

# %%
import os
import re
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/ugp/scopus.csv')

# Keywords to be highlighted
keywords = [
    # Flow & regime
    'mach', 'mach number', 'reynolds', 'reynolds number',
    'compressible', 'incompressible',
    'supersonic', 'hypersonic', 'subsonic',

    # Aerodynamic quantities
    'lift', 'drag', 'lift coefficient', 'drag coefficient',
    'pressure', 'pressure coefficient', 'cp',
    'skin friction', 'shear stress',

    # Flow physics
    'boundary layer', 'flow separation', 'reattachment',
    'shock', 'shock wave',
    'wake', 'vortex', 'vorticity',
    'turbulence', 'laminar',

    # Geometry / bodies
    'airfoil', 'aerofoil', 'wing', 'delta wing',
    'nozzle', 'inlet', 'jet',

    # CFD / simulation
    'cfd', 'numerical simulation',
    'rans', 'les', 'dns',
    'k-epsilon', 'k-omega',
    'mesh', 'grid', 'solver',

    # Visualization / plots
    'contour', 'streamline', 'velocity field',
    'pressure field', 'mach contour',
    'velocity profile',

    # Experimental
    'wind tunnel', 'experimental validation'
]

# Function to highlight keywords in the caption
def highlight_keywords(caption, keywords):
    if not isinstance(caption, str):
        caption = ''

    found = False
    found_keywords = []
    for keyword in keywords:
        if re.search(r'\b' + re.escape(keyword) + r'\b', caption, re.IGNORECASE):
            found = True
            found_keywords.append(keyword)
    return found, found_keywords


for i, row in df.iterrows():
    status_code = row['StatusCode']


    if status_code == 200:
        output_file = f'/content/drive/MyDrive/ugp/csvs/output{i+1}.csv'

        # Check if the file exists
        if os.path.exists(output_file):
            try:
                # Read the corresponding output CSV file
                dof = pd.read_csv(output_file)

                # Apply the keyword highlighting function
                results = dof['Caption'].apply(lambda x: highlight_keywords(x, keywords))
                dof['contains_keywords'] = results.apply(lambda x: 1 if x[0] else 0)
                dof['found_keywords'] = results.apply(lambda x: ', '.join(x[1]) if x[1] else '')

                # Save the updated DataFrame back to the CSV file
                dof.to_csv(output_file, index=False)

            except Exception as e:
                print(f"An error occurred while processing the file {output_file}: {e}")
        else:
            print(f"The file {output_file} does not exist.")
# Out:
# The file /content/drive/MyDrive/ugp/csvs/output498.csv does not exist.

# %% [markdown]
# # Downloading the images from the csv

# %%
import os
import pandas as pd
import requests
import shutil

df = pd.read_csv('/content/drive/MyDrive/ugp/scopus.csv')


for i, row in df.iterrows():
    status_code = row['StatusCode']
    mloc = f'/content/drive/MyDrive/ugp/images/Master'
    os.makedirs(mloc,exist_ok=True)

    if status_code == 200:
        output_file = f'/content/drive/MyDrive/ugp/csvs/output{i+1}.csv'

        # Check if the corresponding output CSV file exists
        if os.path.exists(output_file):
            dof = pd.read_csv(output_file)

            # Filter the DataFrame to get rows where 'contains_keywords' is 1
            contain = dof[dof['contains_keywords'] == 1]

            # Check if there are any rows to process
            if not contain.empty:
                # Define the directory to save the images
                loc = f'/content/drive/MyDrive/ugp/images/{i+1}'
                os.makedirs(loc, exist_ok=True)

                # Variable to track if any file was downloaded
                files_downloaded = False

                # Loop through the filtered rows
                for i1, r2 in contain.iterrows():
                    url = r2['link']

                    try:
                        response = requests.get(url, stream=True, timeout=30)

                        # Check if the request was successful
                        if response.status_code == 200:
                            # Extract the file name from the URL
                            file_name = url.split("/")[-1]

                            # Define the complete path for saving the file
                            save_path = os.path.join(loc, file_name)
                            mloc2 = os.path.join(mloc,file_name)

                            # Write the file data to a file
                            with open(save_path, 'wb') as file:
                                for chunk in response.iter_content(1024):
                                    file.write(chunk)
                            shutil.copy2(save_path,mloc2)
                            print(f"File downloaded: {save_path}")
                            files_downloaded = True
                        else:
                            print(f"Failed to download file: {url} (Status code: {response.status_code})")
                    except Exception as e:
                        print(f"Error downloading file: {url} ({e})")

                # If no files were downloaded, remove the created directory
                if not files_downloaded:
                    os.rmdir(loc)
                    print(f"Removed empty directory: {loc}")
        else:
            print(f"Output file not found: {output_file}")
# Out:
# File downloaded: /content/drive/MyDrive/ugp/images/3/1-s2.0-S1270963826000994-gr5_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/3/1-s2.0-S1270963826000994-gr1_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/10/1-s2.0-S1270963826000945-gr9_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/10/1-s2.0-S1270963826000945-gr19_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/10/1-s2.0-S1270963826000945-gr10_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/10/1-s2.0-S1270963826000945-gr20_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/10/1-s2.0-S1270963826000945-gr4_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/10/1-s2.0-S1270963826000945-gr17_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/10/1-s2.0-S1270963826000945-gr6_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/10/1-s2.0-S1270963826000945-gr16_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/10/1-s2.0-S1270963826000945-gr7_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/10/1-s2.0-S1270963826000945-gr15_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/10/1-s2.0-S1270963826000945-gr1_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/10/1-s2.0-S1270963826000945-gr13_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/10/1-s2.0-S1270963826000945-gr2_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/27/1-s2.0-S1270963826000842-gr14_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/27/1-s2.0-S1270963826000842-gr11_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/27/1-s2.0-S1270963826000842-gr12_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/27/1-s2.0-S1270963826000842-ga1_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/27/1-s2.0-S1270963826000842-gr9_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/27/1-s2.0-S1270963826000842-gr8_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/27/1-s2.0-S1270963826000842-gr5_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/27/1-s2.0-S1270963826000842-gr4_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/27/1-s2.0-S1270963826000842-gr7_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/27/1-s2.0-S1270963826000842-gr6_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/27/1-s2.0-S1270963826000842-gr1_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/27/1-s2.0-S1270963826000842-gr3_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/27/1-s2.0-S1270963826000842-gr15_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/29/1-s2.0-S1270963826000635-gr17_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/29/1-s2.0-S1270963826000635-gr6_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/41/1-s2.0-S1270963826000805-gr3_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/41/1-s2.0-S1270963826000805-gr8_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/41/1-s2.0-S1270963826000805-gr11_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/41/1-s2.0-S1270963826000805-gr6_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/41/1-s2.0-S1270963826000805-gr12_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/41/1-s2.0-S1270963826000805-gr5_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/41/1-s2.0-S1270963826000805-gr13_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/52/1-s2.0-S1270963826000581-gr9_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/52/1-s2.0-S1270963826000581-gr7_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/52/1-s2.0-S1270963826000581-gr10_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/52/1-s2.0-S1270963826000581-gr5_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/97/1-s2.0-S1270963826000301-gr5_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/101/1-s2.0-S1270963825016414-gr5_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/101/1-s2.0-S1270963825016414-gr10_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/101/1-s2.0-S1270963825016414-gr11_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/101/1-s2.0-S1270963825016414-gr15_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/144/1-s2.0-S1270963825016517-gr4_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/144/1-s2.0-S1270963825016517-gr16_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/144/1-s2.0-S1270963825016517-gr14_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/144/1-s2.0-S1270963825016517-gr9_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/144/1-s2.0-S1270963825016517-gr8_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/144/1-s2.0-S1270963825016517-gr20_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/144/1-s2.0-S1270963825016517-gr26_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/144/1-s2.0-S1270963825016517-gr30_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/175/1-s2.0-S1270963825016220-gr11_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/175/1-s2.0-S1270963825016220-gr12_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/175/1-s2.0-S1270963825016220-gr6_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/175/1-s2.0-S1270963825016220-gr7_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/196/1-s2.0-S1270963825015391-gr10_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/231/1-s2.0-S1270963825015305-gr13_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/231/1-s2.0-S1270963825015305-gr14_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/231/1-s2.0-S1270963825015305-gr15_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/231/1-s2.0-S1270963825015305-gr8_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/231/1-s2.0-S1270963825015305-gr16_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/231/1-s2.0-S1270963825015305-gr17_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/231/1-s2.0-S1270963825015305-gr18_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/231/1-s2.0-S1270963825015305-gr23_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/231/1-s2.0-S1270963825015305-gr25_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/235/1-s2.0-S1270963825015032-gr19_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/235/1-s2.0-S1270963825015032-gr9_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/235/1-s2.0-S1270963825015032-gr1_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/235/1-s2.0-S1270963825015032-gr10_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/235/1-s2.0-S1270963825015032-gr3_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/235/1-s2.0-S1270963825015032-gr17_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/235/1-s2.0-S1270963825015032-gr15_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/235/1-s2.0-S1270963825015032-gr12_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/268/1-s2.0-S1270963825015044-gr3_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/275/1-s2.0-S1270963825015263-gr6_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/275/1-s2.0-S1270963825015263-gr7_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/275/1-s2.0-S1270963825015263-gr20_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/275/1-s2.0-S1270963825015263-gr17_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/275/1-s2.0-S1270963825015263-gr16_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/275/1-s2.0-S1270963825015263-gr8_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/275/1-s2.0-S1270963825015263-gr12_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/311/1-s2.0-S1270963825014361-gr9_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/311/1-s2.0-S1270963825014361-gr11_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/311/1-s2.0-S1270963825014361-gr1_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/311/1-s2.0-S1270963825014361-gr6_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/311/1-s2.0-S1270963825014361-gr7_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/311/1-s2.0-S1270963825014361-gr4_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/311/1-s2.0-S1270963825014361-gr10_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/318/1-s2.0-S1270963825013112-gr28_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/318/1-s2.0-S1270963825013112-gr27_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/318/1-s2.0-S1270963825013112-gr25_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/318/1-s2.0-S1270963825013112-gr9_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/318/1-s2.0-S1270963825013112-gr13_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/318/1-s2.0-S1270963825013112-gr12_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/351/1-s2.0-S127096382501332X-gr14_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/367/1-s2.0-S1270963825012878-gr18_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/367/1-s2.0-S1270963825012878-gr5_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/367/1-s2.0-S1270963825012878-gr12_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/367/1-s2.0-S1270963825012878-gr23_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/367/1-s2.0-S1270963825012878-gr6_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/367/1-s2.0-S1270963825012878-gr13_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/367/1-s2.0-S1270963825012878-gr24_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/367/1-s2.0-S1270963825012878-gr3_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/367/1-s2.0-S1270963825012878-gr14_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/367/1-s2.0-S1270963825012878-gr4_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/367/1-s2.0-S1270963825012878-gr15_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/367/1-s2.0-S1270963825012878-gr9_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/367/1-s2.0-S1270963825012878-gr7_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/367/1-s2.0-S1270963825012878-gr1_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/383/1-s2.0-S127096382501243X-gr18_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/414/1-s2.0-S1270963825010624-gr3_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/414/1-s2.0-S1270963825010624-gr6_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/435/1-s2.0-S1270963825012222-gr8_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/435/1-s2.0-S1270963825012222-gr9_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/435/1-s2.0-S1270963825012222-gr14_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/435/1-s2.0-S1270963825012222-gr11_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/435/1-s2.0-S1270963825012222-gr3_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/435/1-s2.0-S1270963825012222-gr12_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/435/1-s2.0-S1270963825012222-gr4_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/435/1-s2.0-S1270963825012222-gr5_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr14_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr34_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr11_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr18_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr17_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr15_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr5_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr6_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr10_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr32_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr1_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr3_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr8_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr9_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr25_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr24_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr28_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr27_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr26_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr21_lrg.jpg
# File downloaded: /content/drive/MyDrive/ugp/images/463/1-s2.0-S1270963825012271-gr20_lrg.jpg
# Output file not found: /content/drive/MyDrive/ugp/csvs/output498.csv

# %% [markdown]
# # Installing required libraries

# %%
# !pip install pytesseract
# !apt-get update
# !apt-get install -y tesseract-ocr
# !apt-get install -y libtesseract-dev
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from pytesseract) (26.0)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from pytesseract) (11.3.0)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [85.0 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,742 kB]
# Get:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [70.9 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,047 kB]
# Get:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,611 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [6,688 kB]
# Get:17 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,901 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,708 kB]
# Get:19 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [39.2 kB]
# Get:20 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 Packages [75.3 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,299 kB]
# Get:22 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,468 kB]
# Get:23 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [62.6 kB]
# Fetched 37.2 MB in 4s (8,528 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 63 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libarchive-dev libleptonica-dev
# The following NEW packages will be installed:
#   libarchive-dev libleptonica-dev libtesseract-dev
# 0 upgraded, 3 newly installed, 0 to remove and 63 not upgraded.
# Need to get 3,743 kB of archives.
# After this operation, 16.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libarchive-dev amd64 3.6.0-1ubuntu1.5 [581 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libleptonica-dev amd64 1.82.0-3build1 [1,562 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtesseract-dev amd64 4.1.1-2.1build1 [1,600 kB]
# Fetched 3,743 kB in 0s (10.2 MB/s)
# Selecting previously unselected package libarchive-dev:amd64.
# (Reading database ... 117540 files and directories currently installed.)
# Preparing to unpack .../libarchive-dev_3.6.0-1ubuntu1.5_amd64.deb ...
# Unpacking libarchive-dev:amd64 (3.6.0-1ubuntu1.5) ...
# Selecting previously unselected package libleptonica-dev.
# Preparing to unpack .../libleptonica-dev_1.82.0-3build1_amd64.deb ...
# Unpacking libleptonica-dev (1.82.0-3build1) ...
# Selecting previously unselected package libtesseract-dev:amd64.
# Preparing to unpack .../libtesseract-dev_4.1.1-2.1build1_amd64.deb ...
# Unpacking libtesseract-dev:amd64 (4.1.1-2.1build1) ...
# Setting up libleptonica-dev (1.82.0-3build1) ...
# Setting up libarchive-dev:amd64 (3.6.0-1ubuntu1.5) ...
# Setting up libtesseract-dev:amd64 (4.1.1-2.1build1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !tesseract --version
# Out:
# tesseract 4.1.1
#  leptonica-1.82.0
#   libgif 5.1.9 : libjpeg 8d (libjpeg-turbo 2.1.1) : libpng 1.6.37 : libtiff 4.3.0 : zlib 1.2.11 : libwebp 1.2.2 : libopenjp2 2.4.0
#  Found AVX2
#  Found AVX
#  Found FMA
#  Found SSE
#  Found libarchive 3.6.0 zlib/1.2.11 liblzma/5.2.5 bz2lib/1.0.8 liblz4/1.9.3 libzstd/1.4.8

# %%
    import re
    import pandas as pd
    from PIL import Image, ImageEnhance
    import pytesseract
    import os



    def highlight_keywords(caption, keywords):
        """Function to highlight keywords in a given caption."""
        if not isinstance(caption, str):
            caption = ''

        found = False
        for keyword in keywords:
            if re.search(r'\b' + re.escape(keyword) + r'\b', caption, re.IGNORECASE):
                found = True
                caption = re.sub(r'(?i)\b' + re.escape(keyword) + r'\b', r'**\g<0>**', caption)
        return found, caption

    def process_image(img_path, keywords):
        """Function to process an image, extract text, and highlight keywords."""
        try:
            image = Image.open(img_path)
            image = image.convert('L')  # Convert image to grayscale
            enhancer = ImageEnhance.Contrast(image)
            image = enhancer.enhance(2)  # Enhance image contrast
            text = pytesseract.image_to_string(image)  # Extract text from image
            found, highlighted_text = highlight_keywords(text, keywords)  # Highlight keywords in extracted text
            return 2 if found else 0, text  # Return status (2 if keywords found, otherwise 0) and extracted text
        except Exception as e:
            print(f"Error processing image {img_path}: {e}")
            return 1, ""  # Return status 1 (error) and empty text on exception

    def process_row(row, img_path, keywords):
        """Function to process a row of data."""
        if row['contains_keywords'] == 1:
            contains_keywords2, text = process_image(img_path, keywords)  # Process image and get results
            row['contains_keywords2'] = contains_keywords2  # Store result in 'contains_keywords2' column
            row['text'] = text  # Store extracted text in 'text' column
        return row  # Return processed row

    def main():
        """Main function to execute processing on CSV files."""
        df = pd.read_csv('/content/drive/MyDrive/ugp/scopus.csv')

        for i, row in df.iterrows():
            if row['StatusCode'] == 200:  # Check if StatusCode is 200(file is present)
                try:
                    # Read corresponding output CSV file
                    dof = pd.read_csv(f'/content/drive/MyDrive/ugp/csvs/output{i+1}.csv')
                    print(f"Processing output{i+1}.csv")

                    img_dir = f"/content/drive/MyDrive/ugp/images/{i+1}/"  # Directory path for images
                    # Apply processing to each row of the output CSV file
                    dof = dof.apply(
                        lambda dof_row: process_row(dof_row, os.path.join(img_dir, dof_row['UTD EID'][:-4] + '_lrg.jpg'), keywords),
                        axis=1
                    )

                    dof.to_csv(f'/content/drive/MyDrive/ugp/csvs/output{i+1}.csv', index=False)  # Save processed data back to output CSV file
                    print(f"Saved processed data to output{i+1}.csv")

                except FileNotFoundError as fnf_error:
                    print(f"Error: {fnf_error}. Skipping processing of output{i+1}.csv")

                except Exception as e:
                    print(f"Unexpected error processing output{i+1}.csv: {e}")

        df.to_csv('/content/drive/MyDrive/ugp/scopus.csv', index=False)  # Save updated main DataFrame back to scopus2.csv
        print("Main data frame updated and saved.")

    if __name__ == "__main__":
        # Keywords to consider for highlighting
        keywords = [
            # Flow & regime
            'mach', 'mach number', 'reynolds', 'reynolds number',
            'compressible', 'incompressible',
            'supersonic', 'hypersonic', 'subsonic',

            # Aerodynamic quantities
            'lift', 'drag', 'lift coefficient', 'drag coefficient',
            'pressure', 'pressure coefficient', 'cp',
            'skin friction', 'shear stress',

            # Flow physics
            'boundary layer', 'flow separation', 'reattachment',
            'shock', 'shock wave',
            'wake', 'vortex', 'vorticity',
            'turbulence', 'laminar',

            # Geometry / bodies
            'airfoil', 'aerofoil', 'wing', 'delta wing',
            'nozzle', 'inlet', 'jet',

            # CFD / simulation
            'cfd', 'numerical simulation',
            'rans', 'les', 'dns',
            'k-epsilon', 'k-omega',
            'mesh', 'grid', 'solver',

            # Visualization / plots
            'contour', 'streamline', 'velocity field',
            'pressure field', 'mach contour',
            'velocity profile',

            # Experimental
            'wind tunnel', 'experimental validation'
        ]
        main()  # Execute main function if script is run directly
# Out:
# Processing output3.csv
# Saved processed data to output3.csv
# Processing output10.csv
# Saved processed data to output10.csv
# Processing output15.csv
# Saved processed data to output15.csv
# Processing output27.csv
# Saved processed data to output27.csv
# Processing output29.csv
# Saved processed data to output29.csv
# Processing output36.csv
# Saved processed data to output36.csv
# Processing output41.csv
# Saved processed data to output41.csv
# Processing output52.csv
# Saved processed data to output52.csv
# Processing output60.csv
# Saved processed data to output60.csv
# Processing output70.csv
# Saved processed data to output70.csv
# Processing output97.csv
# Saved processed data to output97.csv
# Processing output101.csv
# Saved processed data to output101.csv
# Processing output127.csv
# Saved processed data to output127.csv
# Processing output144.csv
# Saved processed data to output144.csv
# Processing output150.csv
# Saved processed data to output150.csv
# Processing output175.csv
# Saved processed data to output175.csv
# Processing output180.csv
# Saved processed data to output180.csv
# Processing output196.csv
# Saved processed data to output196.csv
# Processing output231.csv
# Saved processed data to output231.csv
# Processing output235.csv
# Saved processed data to output235.csv
# Processing output252.csv
# Saved processed data to output252.csv
# Processing output268.csv
# Saved processed data to output268.csv
# Processing output275.csv
# Saved processed data to output275.csv
# Processing output281.csv
# Saved processed data to output281.csv
# Processing output291.csv
# Saved processed data to output291.csv
# Processing output311.csv
# Saved processed data to output311.csv
# Processing output318.csv
# Saved processed data to output318.csv
# Processing output332.csv
# Saved processed data to output332.csv
# Processing output340.csv
# Saved processed data to output340.csv
# Processing output346.csv
# Saved processed data to output346.csv
# Processing output351.csv
# Saved processed data to output351.csv
# Processing output363.csv
# Saved processed data to output363.csv
# Processing output367.csv
# Saved processed data to output367.csv
# Processing output383.csv
# Saved processed data to output383.csv
# Processing output393.csv
# Saved processed data to output393.csv
# Processing output408.csv
# Saved processed data to output408.csv
# Processing output414.csv
# Saved processed data to output414.csv
# Processing output435.csv
# Saved processed data to output435.csv
# Processing output442.csv
# Saved processed data to output442.csv
# Processing output463.csv
# Saved processed data to output463.csv
# Processing output489.csv
# Saved processed data to output489.csv
# Error: [Errno 2] No such file or directory: '/content/drive/MyDrive/ugp/csvs/output498.csv'. Skipping processing of output498.csv
# Main data frame updated and saved.

# %% [markdown]
# # Creating Individual Files for each paper with Relevant Images , CSV file ,
#
# *   List item
# *   List item
#
# XMLS file and the Link of the Paper

# %%
import pandas as pd
import os
import shutil

# Function to process the images and CSV files
def main():
    df = pd.read_csv('/content/drive/MyDrive/ugp/scopus.csv')
    count = 0

    for i, row in df.iterrows():
        df.at[i, 'Processed'] = 0
        if row['StatusCode'] == 200:
            try:
                dof = pd.read_csv(f'/content/drive/MyDrive/ugp/csvs/output{i+1}.csv')
                print(f"Processing output{i+1}.csv")

                img_dir = f"/content/drive/MyDrive/ugp/images/{i+1}/"
                refined_img_dir = f"/content/drive/MyDrive/ugp/images/Refined images/{i+1}/"

                # Check if there are rows in dof that meet the condition
                if len(dof) > 0 and any(dof['contains_keywords2'] == 2):
                    os.makedirs(refined_img_dir, exist_ok=True)

                    copied = False
                    for index, r1 in dof.iterrows():
                        try:
                            if r1['contains_keywords2'] == 2:
                                count += 1
                                src_img = os.path.join(img_dir, r1['UTD EID'][:-4] + '_lrg.jpg')
                                dst_img = os.path.join(refined_img_dir, r1['UTD EID'][:-4] + '_lrg.jpg')
                                shutil.copy(src_img, dst_img)
                                copied = True
                        except Exception as e:
                            print(f"Error processing row {index}: {e}")

                    # Check if any image was copied
                    if copied:
                        firstloc = f"/content/drive/MyDrive/ugp/xmls/{i+1}.xml"
                        secondloc = f"/content/drive/MyDrive/ugp/csvs/output{i+1}.csv"
                        shutil.copy(firstloc, refined_img_dir)
                        shutil.copy(secondloc, refined_img_dir)

                        # Update scopus.csv to mark this row as processed
                        df.at[i, 'Processed'] = 1

                        # Save the link to a text file in the refined image directory
                        link = row['Link']
                        link_file_path = os.path.join(refined_img_dir, f"Link_{i+1}.txt")
                        with open(link_file_path, 'w') as link_file:
                            link_file.write(link)
                            print(f"Link saved to {link_file_path}")

                dof.to_csv(f'/content/drive/MyDrive/ugp/csvs/output{i+1}.csv', index=False)

            except FileNotFoundError:
                print(f"FileNotFoundError: output{i+1}.csv not found.")
            except Exception as ex:
                print(f"Error processing output{i+1}.csv: {ex}")

    print(f"Total images copied: {count}")

    # Save the updated scopus.csv with the 'Processed' column
    df.to_csv('/content/drive/MyDrive/ugp/scopus.csv', index=False)

if __name__ == "__main__":
    main()
# Out:
# Processing output3.csv
# Processing output10.csv
# Link saved to /content/drive/MyDrive/ugp/images/Refined images/10/Link_10.txt
# Processing output15.csv
# Error processing output15.csv: 'contains_keywords2'
# Processing output27.csv
# Link saved to /content/drive/MyDrive/ugp/images/Refined images/27/Link_27.txt
# Processing output29.csv
# Processing output36.csv
# Error processing output36.csv: 'contains_keywords2'
# Processing output41.csv
# Link saved to /content/drive/MyDrive/ugp/images/Refined images/41/Link_41.txt
# Processing output52.csv
# Processing output60.csv
# Error processing output60.csv: 'contains_keywords2'
# Processing output70.csv
# Error processing output70.csv: 'contains_keywords2'
# Processing output97.csv
# Processing output101.csv
# Processing output127.csv
# Error processing output127.csv: 'contains_keywords2'
# Processing output144.csv
# Link saved to /content/drive/MyDrive/ugp/images/Refined images/144/Link_144.txt
# Processing output150.csv
# Error processing output150.csv: 'contains_keywords2'
# Processing output175.csv
# Link saved to /content/drive/MyDrive/ugp/images/Refined images/175/Link_175.txt
# Processing output180.csv
# Error processing output180.csv: 'contains_keywords2'
# Processing output196.csv
# Link saved to /content/drive/MyDrive/ugp/images/Refined images/196/Link_196.txt
# Processing output231.csv
# Link saved to /content/drive/MyDrive/ugp/images/Refined images/231/Link_231.txt
# Processing output235.csv
# Processing output252.csv
# Error processing output252.csv: 'contains_keywords2'
# Processing output268.csv
# Processing output275.csv
# Processing output281.csv
# Error processing output281.csv: 'contains_keywords2'
# Processing output291.csv
# Error processing output291.csv: 'contains_keywords2'
# Processing output311.csv
# Link saved to /content/drive/MyDrive/ugp/images/Refined images/311/Link_311.txt
# Processing output318.csv
# Link saved to /content/drive/MyDrive/ugp/images/Refined images/318/Link_318.txt
# Processing output332.csv
# Error processing output332.csv: 'contains_keywords2'
# Processing output340.csv
# Error processing output340.csv: 'contains_keywords2'
# Processing output346.csv
# Error processing output346.csv: 'contains_keywords2'
# Processing output351.csv
# Processing output363.csv
# Error processing output363.csv: 'contains_keywords2'
# Processing output367.csv
# Link saved to /content/drive/MyDrive/ugp/images/Refined images/367/Link_367.txt
# Processing output383.csv
# Processing output393.csv
# Error processing output393.csv: 'contains_keywords2'
# Processing output408.csv
# Error processing output408.csv: 'contains_keywords2'
# Processing output414.csv
# Link saved to /content/drive/MyDrive/ugp/images/Refined images/414/Link_414.txt
# Processing output435.csv
# Link saved to /content/drive/MyDrive/ugp/images/Refined images/435/Link_435.txt
# Processing output442.csv
# Error processing output442.csv: 'contains_keywords2'
# Processing output463.csv
# Link saved to /content/drive/MyDrive/ugp/images/Refined images/463/Link_463.txt
# Processing output489.csv
# Error processing output489.csv: 'contains_keywords2'
# FileNotFoundError: output498.csv not found.
# Total images copied: 48

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.14-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cpu)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.14-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.9 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.14 ultralytics-thop-2.0.18

# %%
# %cd /content/drive/MyDrive
# !git clone https://github.com/PrathameshLadhe/sma_train
# Out:
# /content/drive/MyDrive
# fatal: destination path 'sma_train' already exists and is not an empty directory.

# %%
## Running a model on images with pre-trained weights to detect plots , their x-label and y-label
# !yolo task=detect mode=predict model='/content/drive/MyDrive/sma_train/train/weights/best.pt' conf=0.25 source='/content/drive/MyDrive/ugp/images/Master'
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825010624-gr3_lrg.jpg: 320x640 (no detections), 251.5ms
# image 2/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825010624-gr6_lrg.jpg: 288x640 2 graphs, 3 xlabels, 2 ylabels, 748.7ms
# image 3/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012222-gr11_lrg.jpg: 640x544 2 graphs, 224.7ms
# image 4/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012222-gr12_lrg.jpg: 640x544 (no detections), 180.6ms
# image 5/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012222-gr14_lrg.jpg: 512x640 8 graphs, 8 xlabels, 8 ylabels, 182.7ms
# image 6/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012222-gr3_lrg.jpg: 256x640 1 graph, 101.6ms
# image 7/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012222-gr4_lrg.jpg: 640x352 (no detections), 131.6ms
# image 8/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012222-gr5_lrg.jpg: 640x448 1 graph, 1 xlabel, 3 ylabels, 161.1ms
# image 9/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012222-gr8_lrg.jpg: 288x640 1 graph, 1 xlabel, 1 ylabel, 102.1ms
# image 10/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012222-gr9_lrg.jpg: 288x640 1 graph, 1 xlabel, 2 ylabels, 112.1ms
# image 11/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr10_lrg.jpg: 384x640 1 graph, 1 xlabel, 1 ylabel, 223.1ms
# image 12/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr11_lrg.jpg: 320x640 (no detections), 216.4ms
# image 13/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr14_lrg.jpg: 320x640 (no detections), 164.8ms
# image 14/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr15_lrg.jpg: 288x640 2 graphs, 2 xlabels, 2 ylabels, 154.6ms
# image 15/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr17_lrg.jpg: 480x640 1 graph, 1 xlabel, 1 ylabel, 249.4ms
# image 16/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr18_lrg.jpg: 512x640 (no detections), 276.8ms
# image 17/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr1_lrg.jpg: 256x640 (no detections), 145.5ms
# image 18/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr20_lrg.jpg: 320x640 (no detections), 173.9ms
# image 19/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr21_lrg.jpg: 288x640 (no detections), 154.2ms
# image 20/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr24_lrg.jpg: 320x640 (no detections), 184.5ms
# image 21/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr25_lrg.jpg: 576x640 (no detections), 302.8ms
# image 22/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr26_lrg.jpg: 288x640 3 graphs, 2 xlabels, 2 ylabels, 165.3ms
# image 23/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr27_lrg.jpg: 416x640 1 graph, 1 ylabel, 236.3ms
# image 24/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr28_lrg.jpg: 640x480 2 graphs, 2 xlabels, 3 ylabels, 305.8ms
# image 25/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr32_lrg.jpg: 512x640 1 graph, 1 xlabel, 2 ylabels, 247.8ms
# image 26/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr34_lrg.jpg: 288x640 2 graphs, 2 xlabels, 2 ylabels, 105.6ms
# image 27/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr3_lrg.jpg: 448x640 (no detections), 193.4ms
# image 28/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr5_lrg.jpg: 288x640 2 graphs, 2 xlabels, 2 ylabels, 101.0ms
# image 29/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr6_lrg.jpg: 256x640 (no detections), 92.2ms
# image 30/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr8_lrg.jpg: 384x640 1 graph, 1 xlabel, 3 ylabels, 134.0ms
# image 31/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr9_lrg.jpg: 320x640 2 graphs, 2 xlabels, 2 ylabels, 111.8ms
# image 32/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S127096382501243X-gr18_lrg.jpg: 512x640 2 graphs, 2 xlabels, 4 ylabels, 187.8ms
# image 33/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr12_lrg.jpg: 224x640 7 graphs, 4 xlabels, 1 ylabel, 88.9ms
# image 34/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr13_lrg.jpg: 352x640 12 graphs, 9 xlabels, 2 ylabels, 139.7ms
# image 35/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr14_lrg.jpg: 352x640 13 graphs, 8 xlabels, 2 ylabels, 118.1ms
# image 36/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr15_lrg.jpg: 352x640 13 graphs, 9 xlabels, 2 ylabels, 120.0ms
# image 37/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr18_lrg.jpg: 224x640 3 graphs, 3 xlabels, 1 ylabel, 85.5ms
# image 38/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr1_lrg.jpg: 160x640 (no detections), 65.5ms
# image 39/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr23_lrg.jpg: 480x640 (no detections), 160.3ms
# image 40/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr24_lrg.jpg: 448x640 1 graph, 1 xlabel, 1 ylabel, 152.0ms
# image 41/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr3_lrg.jpg: 640x544 (no detections), 179.4ms
# image 42/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr4_lrg.jpg: 352x640 (no detections), 129.1ms
# image 43/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr5_lrg.jpg: 384x640 (no detections), 131.1ms
# image 44/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr6_lrg.jpg: 480x640 1 graph, 1 xlabel, 2 ylabels, 161.4ms
# image 45/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr7_lrg.jpg: 480x640 1 graph, 1 xlabel, 1 ylabel, 176.8ms
# image 46/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr9_lrg.jpg: 480x640 1 graph, 1 xlabel, 2 ylabels, 161.6ms
# image 47/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825013112-gr12_lrg.jpg: 320x640 (no detections), 118.0ms
# image 48/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825013112-gr13_lrg.jpg: 384x640 (no detections), 137.4ms
# image 49/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825013112-gr25_lrg.jpg: 224x640 (no detections), 87.3ms
# image 50/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825013112-gr27_lrg.jpg: 352x640 (no detections), 126.8ms
# image 51/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825013112-gr28_lrg.jpg: 576x640 (no detections), 221.8ms
# image 52/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825013112-gr9_lrg.jpg: 288x640 1 graph, 1 xlabel, 1 ylabel, 100.0ms
# image 53/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S127096382501332X-gr14_lrg.jpg: 224x640 2 graphs, 2 xlabels, 4 ylabels, 90.8ms
# image 54/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825014361-gr10_lrg.jpg: 320x640 1 graph, 1 xlabel, 1 ylabel, 112.2ms
# image 55/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825014361-gr11_lrg.jpg: 384x640 3 graphs, 1 xlabel, 2 ylabels, 132.7ms
# image 56/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825014361-gr1_lrg.jpg: 640x640 1 graph, 215.4ms
# image 57/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825014361-gr4_lrg.jpg: 448x640 (no detections), 146.7ms
# image 58/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825014361-gr6_lrg.jpg: 224x640 (no detections), 82.8ms
# image 59/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825014361-gr7_lrg.jpg: 224x640 (no detections), 96.0ms
# image 60/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825014361-gr9_lrg.jpg: 160x640 1 graph, 1 xlabel, 1 ylabel, 63.8ms
# image 61/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015032-gr10_lrg.jpg: 256x640 2 graphs, 2 xlabels, 2 ylabels, 89.8ms
# image 62/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015032-gr12_lrg.jpg: 256x640 2 graphs, 2 xlabels, 2 ylabels, 88.6ms
# image 63/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015032-gr15_lrg.jpg: 544x640 1 graph, 1 xlabel, 1 ylabel, 201.7ms
# image 64/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015032-gr17_lrg.jpg: 256x640 2 graphs, 2 xlabels, 2 ylabels, 91.4ms
# image 65/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015032-gr19_lrg.jpg: 256x640 2 graphs, 2 xlabels, 2 ylabels, 102.5ms
# image 66/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015032-gr1_lrg.jpg: 256x640 1 graph, 89.8ms
# image 67/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015032-gr3_lrg.jpg: 256x640 2 graphs, 2 xlabels, 3 ylabels, 91.4ms
# image 68/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015032-gr9_lrg.jpg: 256x640 2 graphs, 2 xlabels, 2 ylabels, 90.3ms
# image 69/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015044-gr3_lrg.jpg: 320x640 3 graphs, 3 xlabels, 3 ylabels, 151.2ms
# image 70/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015263-gr12_lrg.jpg: 320x640 3 graphs, 3 xlabels, 3 ylabels, 113.3ms
# image 71/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015263-gr16_lrg.jpg: 384x640 1 graph, 1 xlabel, 1 ylabel, 142.1ms
# image 72/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015263-gr17_lrg.jpg: 480x640 1 graph, 1 xlabel, 1 ylabel, 157.3ms
# image 73/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015263-gr20_lrg.jpg: 320x640 (no detections), 110.6ms
# image 74/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015263-gr6_lrg.jpg: 640x640 (no detections), 223.0ms
# image 75/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015263-gr7_lrg.jpg: 384x640 1 graph, 1 xlabel, 1 ylabel, 158.4ms
# image 76/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015263-gr8_lrg.jpg: 384x640 1 graph, 1 xlabel, 1 ylabel, 244.8ms
# image 77/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015305-gr13_lrg.jpg: 256x640 (no detections), 137.1ms
# image 78/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015305-gr14_lrg.jpg: 640x576 2 graphs, 2 xlabels, 3 ylabels, 326.7ms
# image 79/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015305-gr15_lrg.jpg: 640x576 2 graphs, 2 xlabels, 3 ylabels, 285.0ms
# image 80/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015305-gr16_lrg.jpg: 384x640 1 graph, 1 xlabel, 2 ylabels, 197.1ms
# image 81/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015305-gr17_lrg.jpg: 320x640 1 graph, 190.8ms
# image 82/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015305-gr18_lrg.jpg: 640x576 2 graphs, 2 xlabels, 2 ylabels, 301.3ms
# image 83/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015305-gr23_lrg.jpg: 288x640 6 graphs, 7 xlabels, 6 ylabels, 151.6ms
# image 84/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015305-gr25_lrg.jpg: 224x640 (no detections), 123.6ms
# image 85/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015305-gr8_lrg.jpg: 480x640 (no detections), 251.9ms
# image 86/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015391-gr10_lrg.jpg: 640x576 3 graphs, 4 xlabels, 6 ylabels, 288.2ms
# image 87/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016220-gr11_lrg.jpg: 224x640 (no detections), 123.3ms
# image 88/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016220-gr12_lrg.jpg: 224x640 (no detections), 148.2ms
# image 89/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016220-gr6_lrg.jpg: 320x640 (no detections), 178.8ms
# image 90/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016220-gr7_lrg.jpg: 512x640 4 graphs, 4 xlabels, 4 ylabels, 273.3ms
# image 91/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016414-gr10_lrg.jpg: 224x640 4 graphs, 3 xlabels, 1 ylabel, 135.4ms
# image 92/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016414-gr11_lrg.jpg: 448x640 1 xlabel, 172.3ms
# image 93/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016414-gr15_lrg.jpg: 512x640 2 graphs, 2 xlabels, 1 ylabel, 168.6ms
# image 94/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016414-gr5_lrg.jpg: 512x640 1 graph, 1 xlabel, 168.2ms
# image 95/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016517-gr14_lrg.jpg: 256x640 (no detections), 94.3ms
# image 96/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016517-gr16_lrg.jpg: 320x640 2 graphs, 3 xlabels, 2 ylabels, 124.5ms
# image 97/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016517-gr20_lrg.jpg: 544x640 1 graph, 1 xlabel, 1 ylabel, 187.4ms
# image 98/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016517-gr26_lrg.jpg: 640x608 8 graphs, 9 xlabels, 8 ylabels, 219.8ms
# image 99/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016517-gr30_lrg.jpg: 640x608 4 graphs, 3 xlabels, 4 ylabels, 204.4ms
# image 100/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016517-gr4_lrg.jpg: 576x640 (no detections), 197.4ms
# image 101/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016517-gr8_lrg.jpg: 288x640 1 graph, 2 xlabels, 1 ylabel, 112.3ms
# image 102/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016517-gr9_lrg.jpg: 384x640 (no detections), 130.4ms
# image 103/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000301-gr5_lrg.jpg: 416x640 (no detections), 140.8ms
# image 104/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000581-gr10_lrg.jpg: 384x640 1 graph, 1 ylabel, 148.1ms
# image 105/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000581-gr5_lrg.jpg: 128x640 (no detections), 60.4ms
# image 106/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000581-gr7_lrg.jpg: 544x640 6 ylabels, 185.3ms
# image 107/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000581-gr9_lrg.jpg: 384x640 1 graph, 1 ylabel, 135.8ms
# image 108/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000635-gr17_lrg.jpg: 256x640 2 graphs, 3 xlabels, 5 ylabels, 101.4ms
# image 109/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000635-gr6_lrg.jpg: 352x640 1 graph, 1 xlabel, 3 ylabels, 128.5ms
# image 110/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000805-gr11_lrg.jpg: 640x448 6 xlabels, 5 ylabels, 167.3ms
# image 111/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000805-gr12_lrg.jpg: 352x640 (no detections), 118.5ms
# image 112/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000805-gr13_lrg.jpg: 640x448 4 graphs, 6 xlabels, 4 ylabels, 153.5ms
# image 113/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000805-gr3_lrg.jpg: 384x640 (no detections), 140.2ms
# image 114/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000805-gr5_lrg.jpg: 640x448 (no detections), 149.8ms
# image 115/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000805-gr6_lrg.jpg: 384x640 (no detections), 151.6ms
# image 116/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000805-gr8_lrg.jpg: 256x640 (no detections), 94.1ms
# image 117/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-ga1_lrg.jpg: 576x640 (no detections), 206.0ms
# image 118/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr11_lrg.jpg: 512x640 4 graphs, 4 xlabels, 4 ylabels, 176.9ms
# image 119/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr12_lrg.jpg: 352x640 (no detections), 150.6ms
# image 120/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr14_lrg.jpg: 448x640 2 graphs, 2 xlabels, 2 ylabels, 153.5ms
# image 121/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr15_lrg.jpg: 448x640 2 graphs, 2 xlabels, 2 ylabels, 167.2ms
# image 122/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr1_lrg.jpg: 224x640 (no detections), 82.5ms
# image 123/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr3_lrg.jpg: 224x640 1 graph, 1 xlabel, 1 ylabel, 90.0ms
# image 124/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr4_lrg.jpg: 224x640 1 graph, 1 ylabel, 77.3ms
# image 125/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr5_lrg.jpg: 256x640 1 graph, 1 ylabel, 88.7ms
# image 126/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr6_lrg.jpg: 512x640 1 graph, 1 xlabel, 1 ylabel, 168.2ms
# image 127/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr7_lrg.jpg: 352x640 1 graph, 2 xlabels, 1 ylabel, 125.2ms
# image 128/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr8_lrg.jpg: 256x640 (no detections), 89.6ms
# image 129/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr9_lrg.jpg: 640x576 6 graphs, 6 xlabels, 6 ylabels, 221.9ms
# image 130/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr10_lrg.jpg: 192x640 1 ylabel, 95.1ms
# image 131/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr13_lrg.jpg: 384x640 (no detections), 157.5ms
# image 132/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr15_lrg.jpg: 320x640 1 graph, 1 xlabel, 4 ylabels, 114.6ms
# image 133/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr16_lrg.jpg: 256x640 1 graph, 2 xlabels, 1 ylabel, 91.9ms
# image 134/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr17_lrg.jpg: 256x640 1 graph, 1 xlabel, 1 ylabel, 103.2ms
# image 135/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr19_lrg.jpg: 256x640 4 graphs, 1 xlabel, 3 ylabels, 95.2ms
# image 136/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr1_lrg.jpg: 288x640 (no detections), 103.9ms
# image 137/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr20_lrg.jpg: 256x640 3 graphs, 1 xlabel, 3 ylabels, 189.7ms
# image 138/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr2_lrg.jpg: 512x640 1 graph, 1 xlabel, 1 ylabel, 269.2ms
# image 139/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr4_lrg.jpg: 640x640 2 graphs, 3 xlabels, 2 ylabels, 349.5ms
# image 140/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr6_lrg.jpg: 640x416 3 graphs, 3 xlabels, 2 ylabels, 229.4ms
# image 141/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr7_lrg.jpg: 640x480 3 graphs, 5 xlabels, 2 ylabels, 255.7ms
# image 142/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr9_lrg.jpg: 320x640 (no detections), 184.5ms
# image 143/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000994-gr1_lrg.jpg: 288x640 (no detections), 163.7ms
# image 144/144 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000994-gr5_lrg.jpg: 640x544 5 graphs, 7 xlabels, 5 ylabels, 285.0ms
# Speed: 3.4ms preprocess, 162.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 544)
# Results saved to /content/drive/MyDrive/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # Saving all the images in the Drive

# %%
import shutil
import os
from datetime import datetime
# Define source and destination paths
src_dir = '/content/drive/MyDrive/runs'
base_dst_dir = '/content/drive/MyDrive/ugp/Archived_Runs'

# Create a timestamped folder name to avoid overwriting
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
dst_dir = os.path.join(base_dst_dir, f'runs_{timestamp}')

# Ensure the base destination directory exists
os.makedirs(base_dst_dir, exist_ok=True)

# Copy the entire directory
try:
    shutil.copytree(src_dir, dst_dir)
    print(f"Folder copied from {src_dir} to {dst_dir}")
    shutil.rmtree('/content/drive/MyDrive/runs')
    print('File deleted.')
except Exception as e:
    print(f"Error copying folder: {e}")
# Out:
# Folder copied from /content/drive/MyDrive/runs to /content/drive/MyDrive/ugp/Archived_Runs/runs_20260214_192516
# File deleted.

# %% [markdown]
# # Getting the YOLO Predictions in YOLO txt format for further use.

# %%
from ultralytics import YOLO
import os

# Load the model
model = YOLO('/content/drive/MyDrive/sma_train/train/weights/best.pt')

# Create output directory if it doesn't exist
output_dir = '/content/drive/MyDrive/ugp/images/Master/output'  # Keep this for saving results
os.makedirs(output_dir, exist_ok=True)

# Iterate over images in the CORRECT directory
image_dir = '/content/drive/MyDrive/ugp/images/Master'  # This is where the images should be
for image_file in os.listdir(image_dir):
    if image_file.endswith(('.jpg', '.png', '.jpeg')):  # Filter for image files
        # Full path to the image
        image_path = os.path.join(image_dir, image_file)

        # Get predictions for the image
        predictions = model(image_path, save_txt=None)

        # Prepare output file path
        base_name = os.path.splitext(image_file)[0]
        output_file_path = os.path.join(output_dir, f"{base_name}.txt")

        # Write predictions to the text file
        with open(output_file_path, 'w') as file:
            for idx, box in enumerate(predictions[0].boxes.xywhn):  # Iterate over each detected box
                cls = int(predictions[0].boxes.cls[idx].item())
                # Write line to file in YOLO label format: cls x_center y_center width height
                file.write(f"{cls} {box[0].item()} {box[1].item()} {box[2].item()} {box[3].item()}\n")
# Out:
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000994-gr1_lrg.jpg: 288x640 (no detections), 121.7ms
# Speed: 2.5ms preprocess, 121.7ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr9_lrg.jpg: 320x640 (no detections), 111.1ms
# Speed: 2.3ms preprocess, 111.1ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000994-gr5_lrg.jpg: 640x544 5 graphs, 7 xlabels, 5 ylabels, 183.4ms
# Speed: 4.2ms preprocess, 183.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr19_lrg.jpg: 256x640 4 graphs, 1 xlabel, 3 ylabels, 124.3ms
# Speed: 2.0ms preprocess, 124.3ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr10_lrg.jpg: 192x640 1 ylabel, 73.1ms
# Speed: 1.6ms preprocess, 73.1ms inference, 0.9ms postprocess per image at shape (1, 3, 192, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr20_lrg.jpg: 256x640 3 graphs, 1 xlabel, 3 ylabels, 109.7ms
# Speed: 2.0ms preprocess, 109.7ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr4_lrg.jpg: 640x640 2 graphs, 3 xlabels, 2 ylabels, 209.8ms
# Speed: 4.8ms preprocess, 209.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr17_lrg.jpg: 256x640 1 graph, 1 xlabel, 1 ylabel, 92.3ms
# Speed: 1.9ms preprocess, 92.3ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr6_lrg.jpg: 640x416 3 graphs, 3 xlabels, 2 ylabels, 142.2ms
# Speed: 3.5ms preprocess, 142.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr16_lrg.jpg: 256x640 1 graph, 2 xlabels, 1 ylabel, 97.0ms
# Speed: 1.9ms preprocess, 97.0ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr7_lrg.jpg: 640x480 3 graphs, 5 xlabels, 2 ylabels, 171.0ms
# Speed: 3.4ms preprocess, 171.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr15_lrg.jpg: 320x640 1 graph, 1 xlabel, 4 ylabels, 125.6ms
# Speed: 2.3ms preprocess, 125.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr1_lrg.jpg: 288x640 (no detections), 102.9ms
# Speed: 2.2ms preprocess, 102.9ms inference, 0.6ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr2_lrg.jpg: 512x640 1 graph, 1 xlabel, 1 ylabel, 171.3ms
# Speed: 3.5ms preprocess, 171.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000945-gr13_lrg.jpg: 384x640 (no detections), 204.5ms
# Speed: 2.7ms preprocess, 204.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr11_lrg.jpg: 512x640 4 graphs, 4 xlabels, 4 ylabels, 274.6ms
# Speed: 6.5ms preprocess, 274.6ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr14_lrg.jpg: 448x640 2 graphs, 2 xlabels, 2 ylabels, 230.5ms
# Speed: 4.7ms preprocess, 230.5ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr12_lrg.jpg: 352x640 (no detections), 223.7ms
# Speed: 3.4ms preprocess, 223.7ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr8_lrg.jpg: 256x640 (no detections), 138.5ms
# Speed: 2.7ms preprocess, 138.5ms inference, 0.6ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr9_lrg.jpg: 640x576 6 graphs, 6 xlabels, 6 ylabels, 295.2ms
# Speed: 6.5ms preprocess, 295.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-ga1_lrg.jpg: 576x640 (no detections), 289.5ms
# Speed: 5.4ms preprocess, 289.5ms inference, 0.7ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr5_lrg.jpg: 256x640 1 graph, 1 ylabel, 147.2ms
# Speed: 2.6ms preprocess, 147.2ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr4_lrg.jpg: 224x640 1 graph, 1 ylabel, 125.8ms
# Speed: 2.5ms preprocess, 125.8ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr7_lrg.jpg: 352x640 1 graph, 2 xlabels, 1 ylabel, 189.5ms
# Speed: 3.4ms preprocess, 189.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr6_lrg.jpg: 512x640 1 graph, 1 xlabel, 1 ylabel, 280.2ms
# Speed: 4.9ms preprocess, 280.2ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr1_lrg.jpg: 224x640 (no detections), 124.1ms
# Speed: 2.5ms preprocess, 124.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr3_lrg.jpg: 224x640 1 graph, 1 xlabel, 1 ylabel, 128.4ms
# Speed: 2.4ms preprocess, 128.4ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000842-gr15_lrg.jpg: 448x640 2 graphs, 2 xlabels, 2 ylabels, 232.3ms
# Speed: 4.5ms preprocess, 232.3ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000635-gr6_lrg.jpg: 352x640 1 graph, 1 xlabel, 3 ylabels, 217.5ms
# Speed: 3.7ms preprocess, 217.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000635-gr17_lrg.jpg: 256x640 2 graphs, 3 xlabels, 5 ylabels, 148.6ms
# Speed: 2.8ms preprocess, 148.6ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000805-gr3_lrg.jpg: 384x640 (no detections), 212.0ms
# Speed: 3.7ms preprocess, 212.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000805-gr8_lrg.jpg: 256x640 (no detections), 158.5ms
# Speed: 2.6ms preprocess, 158.5ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000805-gr11_lrg.jpg: 640x448 6 xlabels, 5 ylabels, 283.6ms
# Speed: 4.4ms preprocess, 283.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000805-gr6_lrg.jpg: 384x640 (no detections), 178.3ms
# Speed: 6.9ms preprocess, 178.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000805-gr12_lrg.jpg: 352x640 (no detections), 128.0ms
# Speed: 4.4ms preprocess, 128.0ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000805-gr5_lrg.jpg: 640x448 (no detections), 150.7ms
# Speed: 3.2ms preprocess, 150.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000805-gr13_lrg.jpg: 640x448 4 graphs, 6 xlabels, 4 ylabels, 150.6ms
# Speed: 3.3ms preprocess, 150.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000581-gr7_lrg.jpg: 544x640 6 ylabels, 211.8ms
# Speed: 4.8ms preprocess, 211.8ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000581-gr9_lrg.jpg: 384x640 1 graph, 1 ylabel, 135.9ms
# Speed: 2.7ms preprocess, 135.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000581-gr5_lrg.jpg: 128x640 (no detections), 56.8ms
# Speed: 1.2ms preprocess, 56.8ms inference, 0.5ms postprocess per image at shape (1, 3, 128, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000581-gr10_lrg.jpg: 384x640 1 graph, 1 ylabel, 133.6ms
# Speed: 2.7ms preprocess, 133.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963826000301-gr5_lrg.jpg: 416x640 (no detections), 138.9ms
# Speed: 3.3ms preprocess, 138.9ms inference, 0.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016414-gr5_lrg.jpg: 512x640 1 graph, 1 xlabel, 170.7ms
# Speed: 3.5ms preprocess, 170.7ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016414-gr10_lrg.jpg: 224x640 4 graphs, 3 xlabels, 1 ylabel, 86.2ms
# Speed: 2.4ms preprocess, 86.2ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016414-gr11_lrg.jpg: 448x640 1 xlabel, 150.7ms
# Speed: 3.2ms preprocess, 150.7ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016517-gr4_lrg.jpg: 576x640 (no detections), 198.9ms
# Speed: 4.7ms preprocess, 198.9ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016414-gr15_lrg.jpg: 512x640 2 graphs, 2 xlabels, 1 ylabel, 169.1ms
# Speed: 3.3ms preprocess, 169.1ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016517-gr16_lrg.jpg: 320x640 2 graphs, 3 xlabels, 2 ylabels, 114.5ms
# Speed: 2.2ms preprocess, 114.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016517-gr14_lrg.jpg: 256x640 (no detections), 104.0ms
# Speed: 1.9ms preprocess, 104.0ms inference, 0.7ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016517-gr9_lrg.jpg: 384x640 (no detections), 134.9ms
# Speed: 2.6ms preprocess, 134.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016517-gr20_lrg.jpg: 544x640 1 graph, 1 xlabel, 1 ylabel, 182.5ms
# Speed: 3.8ms preprocess, 182.5ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016517-gr8_lrg.jpg: 288x640 1 graph, 2 xlabels, 1 ylabel, 105.6ms
# Speed: 2.2ms preprocess, 105.6ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016517-gr26_lrg.jpg: 640x608 8 graphs, 9 xlabels, 8 ylabels, 195.6ms
# Speed: 4.5ms preprocess, 195.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016220-gr11_lrg.jpg: 224x640 (no detections), 82.2ms
# Speed: 1.6ms preprocess, 82.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016517-gr30_lrg.jpg: 640x608 4 graphs, 3 xlabels, 4 ylabels, 209.2ms
# Speed: 4.5ms preprocess, 209.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016220-gr6_lrg.jpg: 320x640 (no detections), 111.7ms
# Speed: 2.2ms preprocess, 111.7ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016220-gr12_lrg.jpg: 224x640 (no detections), 106.1ms
# Speed: 1.8ms preprocess, 106.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825016220-gr7_lrg.jpg: 512x640 4 graphs, 4 xlabels, 4 ylabels, 171.5ms
# Speed: 3.4ms preprocess, 171.5ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015305-gr13_lrg.jpg: 256x640 (no detections), 93.0ms
# Speed: 2.1ms preprocess, 93.0ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015391-gr10_lrg.jpg: 640x576 3 graphs, 4 xlabels, 6 ylabels, 191.7ms
# Speed: 5.4ms preprocess, 191.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015305-gr14_lrg.jpg: 640x576 2 graphs, 2 xlabels, 3 ylabels, 189.6ms
# Speed: 3.9ms preprocess, 189.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015305-gr8_lrg.jpg: 480x640 (no detections), 174.2ms
# Speed: 3.3ms preprocess, 174.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015305-gr16_lrg.jpg: 384x640 1 graph, 1 xlabel, 2 ylabels, 134.8ms
# Speed: 2.7ms preprocess, 134.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015305-gr15_lrg.jpg: 640x576 2 graphs, 2 xlabels, 3 ylabels, 205.9ms
# Speed: 4.1ms preprocess, 205.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015305-gr17_lrg.jpg: 320x640 1 graph, 111.7ms
# Speed: 2.5ms preprocess, 111.7ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015305-gr18_lrg.jpg: 640x576 2 graphs, 2 xlabels, 2 ylabels, 196.7ms
# Speed: 4.1ms preprocess, 196.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 576)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015305-gr23_lrg.jpg: 288x640 6 graphs, 7 xlabels, 6 ylabels, 100.7ms
# Speed: 2.2ms preprocess, 100.7ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015305-gr25_lrg.jpg: 224x640 (no detections), 79.0ms
# Speed: 1.9ms preprocess, 79.0ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015032-gr19_lrg.jpg: 256x640 2 graphs, 2 xlabels, 2 ylabels, 91.2ms
# Speed: 2.2ms preprocess, 91.2ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015032-gr9_lrg.jpg: 256x640 2 graphs, 2 xlabels, 2 ylabels, 112.4ms
# Speed: 2.1ms preprocess, 112.4ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015032-gr1_lrg.jpg: 256x640 1 graph, 95.5ms
# Speed: 2.1ms preprocess, 95.5ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015032-gr10_lrg.jpg: 256x640 2 graphs, 2 xlabels, 2 ylabels, 99.6ms
# Speed: 2.0ms preprocess, 99.6ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015032-gr3_lrg.jpg: 256x640 2 graphs, 2 xlabels, 3 ylabels, 92.1ms
# Speed: 2.0ms preprocess, 92.1ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015032-gr17_lrg.jpg: 256x640 2 graphs, 2 xlabels, 2 ylabels, 91.5ms
# Speed: 2.0ms preprocess, 91.5ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015032-gr15_lrg.jpg: 544x640 1 graph, 1 xlabel, 1 ylabel, 179.7ms
# Speed: 3.5ms preprocess, 179.7ms inference, 0.9ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015032-gr12_lrg.jpg: 256x640 2 graphs, 2 xlabels, 2 ylabels, 94.0ms
# Speed: 2.0ms preprocess, 94.0ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015263-gr6_lrg.jpg: 640x640 (no detections), 222.0ms
# Speed: 6.1ms preprocess, 222.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015044-gr3_lrg.jpg: 320x640 3 graphs, 3 xlabels, 3 ylabels, 113.4ms
# Speed: 2.5ms preprocess, 113.4ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015263-gr7_lrg.jpg: 384x640 1 graph, 1 xlabel, 1 ylabel, 131.0ms
# Speed: 2.7ms preprocess, 131.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015263-gr17_lrg.jpg: 480x640 1 graph, 1 xlabel, 1 ylabel, 154.9ms
# Speed: 3.3ms preprocess, 154.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015263-gr20_lrg.jpg: 320x640 (no detections), 111.5ms
# Speed: 2.5ms preprocess, 111.5ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015263-gr8_lrg.jpg: 384x640 1 graph, 1 xlabel, 1 ylabel, 153.5ms
# Speed: 2.5ms preprocess, 153.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015263-gr16_lrg.jpg: 384x640 1 graph, 1 xlabel, 1 ylabel, 140.3ms
# Speed: 2.7ms preprocess, 140.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825014361-gr9_lrg.jpg: 160x640 1 graph, 1 xlabel, 1 ylabel, 72.0ms
# Speed: 2.4ms preprocess, 72.0ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825015263-gr12_lrg.jpg: 320x640 3 graphs, 3 xlabels, 3 ylabels, 111.6ms
# Speed: 2.5ms preprocess, 111.6ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825014361-gr11_lrg.jpg: 384x640 3 graphs, 1 xlabel, 2 ylabels, 130.4ms
# Speed: 3.0ms preprocess, 130.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825014361-gr7_lrg.jpg: 224x640 (no detections), 82.3ms
# Speed: 1.8ms preprocess, 82.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825014361-gr1_lrg.jpg: 640x640 1 graph, 381.1ms
# Speed: 8.2ms preprocess, 381.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825014361-gr6_lrg.jpg: 224x640 (no detections), 126.3ms
# Speed: 2.4ms preprocess, 126.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825014361-gr10_lrg.jpg: 320x640 1 graph, 1 xlabel, 1 ylabel, 171.1ms
# Speed: 3.2ms preprocess, 171.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825014361-gr4_lrg.jpg: 448x640 (no detections), 233.2ms
# Speed: 4.4ms preprocess, 233.2ms inference, 0.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825013112-gr28_lrg.jpg: 576x640 (no detections), 331.4ms
# Speed: 5.6ms preprocess, 331.4ms inference, 0.9ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825013112-gr9_lrg.jpg: 288x640 1 graph, 1 xlabel, 1 ylabel, 147.3ms
# Speed: 3.0ms preprocess, 147.3ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825013112-gr25_lrg.jpg: 224x640 (no detections), 129.5ms
# Speed: 2.7ms preprocess, 129.5ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825013112-gr27_lrg.jpg: 352x640 (no detections), 192.7ms
# Speed: 3.5ms preprocess, 192.7ms inference, 0.6ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825013112-gr13_lrg.jpg: 384x640 (no detections), 237.9ms
# Speed: 4.2ms preprocess, 237.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825013112-gr12_lrg.jpg: 320x640 (no detections), 178.6ms
# Speed: 3.4ms preprocess, 178.6ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S127096382501332X-gr14_lrg.jpg: 224x640 2 graphs, 2 xlabels, 4 ylabels, 125.1ms
# Speed: 2.5ms preprocess, 125.1ms inference, 1.1ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr5_lrg.jpg: 384x640 (no detections), 209.3ms
# Speed: 3.8ms preprocess, 209.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr18_lrg.jpg: 224x640 3 graphs, 3 xlabels, 1 ylabel, 123.3ms
# Speed: 2.5ms preprocess, 123.3ms inference, 1.3ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr12_lrg.jpg: 224x640 7 graphs, 4 xlabels, 1 ylabel, 174.2ms
# Speed: 2.5ms preprocess, 174.2ms inference, 3.3ms postprocess per image at shape (1, 3, 224, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr23_lrg.jpg: 480x640 (no detections), 255.0ms
# Speed: 5.2ms preprocess, 255.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr13_lrg.jpg: 352x640 12 graphs, 9 xlabels, 2 ylabels, 199.9ms
# Speed: 3.7ms preprocess, 199.9ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr6_lrg.jpg: 480x640 1 graph, 1 xlabel, 2 ylabels, 251.8ms
# Speed: 4.1ms preprocess, 251.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr3_lrg.jpg: 640x544 (no detections), 303.1ms
# Speed: 5.5ms preprocess, 303.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr24_lrg.jpg: 448x640 1 graph, 1 xlabel, 1 ylabel, 175.4ms
# Speed: 4.7ms preprocess, 175.4ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr14_lrg.jpg: 352x640 13 graphs, 8 xlabels, 2 ylabels, 125.5ms
# Speed: 2.7ms preprocess, 125.5ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr4_lrg.jpg: 352x640 (no detections), 118.7ms
# Speed: 2.7ms preprocess, 118.7ms inference, 0.5ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr15_lrg.jpg: 352x640 13 graphs, 9 xlabels, 2 ylabels, 122.7ms
# Speed: 3.1ms preprocess, 122.7ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr9_lrg.jpg: 480x640 1 graph, 1 xlabel, 2 ylabels, 177.4ms
# Speed: 3.3ms preprocess, 177.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr7_lrg.jpg: 480x640 1 graph, 1 xlabel, 1 ylabel, 173.3ms
# Speed: 3.3ms preprocess, 173.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012878-gr1_lrg.jpg: 160x640 (no detections), 66.2ms
# Speed: 1.3ms preprocess, 66.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S127096382501243X-gr18_lrg.jpg: 512x640 2 graphs, 2 xlabels, 4 ylabels, 206.8ms
# Speed: 3.9ms preprocess, 206.8ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825010624-gr3_lrg.jpg: 320x640 (no detections), 117.1ms
# Speed: 2.1ms preprocess, 117.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012222-gr8_lrg.jpg: 288x640 1 graph, 1 xlabel, 1 ylabel, 100.3ms
# Speed: 2.2ms preprocess, 100.3ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825010624-gr6_lrg.jpg: 288x640 2 graphs, 3 xlabels, 2 ylabels, 103.3ms
# Speed: 2.3ms preprocess, 103.3ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012222-gr9_lrg.jpg: 288x640 1 graph, 1 xlabel, 2 ylabels, 103.0ms
# Speed: 2.6ms preprocess, 103.0ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012222-gr14_lrg.jpg: 512x640 8 graphs, 8 xlabels, 8 ylabels, 176.5ms
# Speed: 4.0ms preprocess, 176.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012222-gr11_lrg.jpg: 640x544 2 graphs, 184.2ms
# Speed: 4.1ms preprocess, 184.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012222-gr3_lrg.jpg: 256x640 1 graph, 92.6ms
# Speed: 1.9ms preprocess, 92.6ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012222-gr12_lrg.jpg: 640x544 (no detections), 184.9ms
# Speed: 4.6ms preprocess, 184.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012222-gr4_lrg.jpg: 640x352 (no detections), 139.2ms
# Speed: 2.8ms preprocess, 139.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr14_lrg.jpg: 320x640 (no detections), 109.1ms
# Speed: 2.4ms preprocess, 109.1ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012222-gr5_lrg.jpg: 640x448 1 graph, 1 xlabel, 3 ylabels, 150.1ms
# Speed: 3.4ms preprocess, 150.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr11_lrg.jpg: 320x640 (no detections), 126.6ms
# Speed: 2.6ms preprocess, 126.6ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr34_lrg.jpg: 288x640 2 graphs, 2 xlabels, 2 ylabels, 101.1ms
# Speed: 2.1ms preprocess, 101.1ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr18_lrg.jpg: 512x640 (no detections), 177.3ms
# Speed: 3.5ms preprocess, 177.3ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr15_lrg.jpg: 288x640 2 graphs, 2 xlabels, 2 ylabels, 100.8ms
# Speed: 3.5ms preprocess, 100.8ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr17_lrg.jpg: 480x640 1 graph, 1 xlabel, 1 ylabel, 159.6ms
# Speed: 3.5ms preprocess, 159.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr6_lrg.jpg: 256x640 (no detections), 89.8ms
# Speed: 2.0ms preprocess, 89.8ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr5_lrg.jpg: 288x640 2 graphs, 2 xlabels, 2 ylabels, 120.7ms
# Speed: 2.5ms preprocess, 120.7ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr10_lrg.jpg: 384x640 1 graph, 1 xlabel, 1 ylabel, 140.3ms
# Speed: 2.9ms preprocess, 140.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr32_lrg.jpg: 512x640 1 graph, 1 xlabel, 2 ylabels, 180.7ms
# Speed: 3.4ms preprocess, 180.7ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr3_lrg.jpg: 448x640 (no detections), 161.2ms
# Speed: 3.1ms preprocess, 161.2ms inference, 0.7ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr1_lrg.jpg: 256x640 (no detections), 91.3ms
# Speed: 2.0ms preprocess, 91.3ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr8_lrg.jpg: 384x640 1 graph, 1 xlabel, 3 ylabels, 136.4ms
# Speed: 2.9ms preprocess, 136.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr9_lrg.jpg: 320x640 2 graphs, 2 xlabels, 2 ylabels, 110.4ms
# Speed: 2.5ms preprocess, 110.4ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr24_lrg.jpg: 320x640 (no detections), 113.2ms
# Speed: 2.5ms preprocess, 113.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr25_lrg.jpg: 576x640 (no detections), 187.4ms
# Speed: 4.2ms preprocess, 187.4ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr28_lrg.jpg: 640x480 2 graphs, 2 xlabels, 3 ylabels, 164.0ms
# Speed: 3.6ms preprocess, 164.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr27_lrg.jpg: 416x640 1 graph, 1 ylabel, 137.9ms
# Speed: 3.1ms preprocess, 137.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr26_lrg.jpg: 288x640 3 graphs, 2 xlabels, 2 ylabels, 113.5ms
# Speed: 3.0ms preprocess, 113.5ms inference, 0.9ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr21_lrg.jpg: 288x640 (no detections), 101.9ms
# Speed: 2.2ms preprocess, 101.9ms inference, 0.5ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/drive/MyDrive/ugp/images/Master/1-s2.0-S1270963825012271-gr20_lrg.jpg: 320x640 (no detections), 111.5ms
# Speed: 2.5ms preprocess, 111.5ms inference, 0.5ms postprocess per image at shape (1, 3, 320, 640)

# %% [markdown]
# # Explaining the YOLO txt format

# %%
import matplotlib.pyplot as plt
from PIL import Image


img_path = '/content/drive/MyDrive/ugp/images/10/1-s2.0-S1270963826000945-gr10_lrg.jpg'
img_path2 = '/content/drive/MyDrive/ugp/images/10/1-s2.0-S1270963826000945-gr13_lrg.jpg'


img1 = Image.open(img_path)
img2 = Image.open(img_path2)
fig, axs = plt.subplots(1, 2, figsize=(12, 6))


axs[0].imshow(img1)
axs[0].axis('off')


axs[1].imshow(img2)
axs[1].axis('off')

plt.show()
