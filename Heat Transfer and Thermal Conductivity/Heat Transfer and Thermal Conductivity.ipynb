# %%
# ─────────────────────────────────────────────
# BLOCK 1: Setup & Configuration
# Mount drive, install libraries, define keywords
# ─────────────────────────────────────────────

# Install pytesseract and tesseract-ocr
# !pip install pytesseract Pillow==9.0.0
# !sudo apt update
# !sudo apt install tesseract-ocr

from google.colab import drive
drive.mount('/content/drive')

import os
import re
import csv
import requests
import pandas as pd
import xml.etree.ElementTree as ET
from PIL import Image, ImageEnhance
import pytesseract

# ── Paths ──────────────────────────────────────────────────
INPUT_CSV     = '/content/drive/MyDrive/final_ugp/scopus.csv'          # your input file (read-only)
XML_DIR       = '/content/drive/MyDrive/final_ugp/pipeline/xmls'       # downloaded XML files
CSV_DIR       = '/content/drive/MyDrive/final_ugp/pipeline/csvs'       # per-paper figure CSVs
RELEVANT_OUT  = '/content/drive/MyDrive/final_ugp/pipeline/relevant_papers.csv'
TRACKER_OUT   = '/content/drive/MyDrive/final_ugp/pipeline/tracker.csv'

for d in [XML_DIR, CSV_DIR]:
    os.makedirs(d, exist_ok=True)

# ── Elsevier API key ───────────────────────────────────────
API_KEY = 'Your_Els_API_Key_Here'  # Replace with your actual API key

# ── Keywords to search for ─────────────────────────────────
KEYWORDS = [
    'temperature', 'thermal', 'conductivity', 'heat flux',
    'convection', 'gradient', 'nusselt', 'reynolds', 'curve'
]

print("✓ Setup complete. Paths and keywords are ready.")
# Out:
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Requirement already satisfied: Pillow==9.0.0 in /usr/local/lib/python3.12/dist-packages (9.0.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from pytesseract) (26.1)
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,945 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [7,061 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,295 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 12.4 MB in 2s (7,591 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 10 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 10 not upgraded.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✓ Setup complete. Paths and keywords are ready.

# %%
# ─────────────────────────────────────────────
# BLOCK 2: Install Tesseract OCR
# Only needs to run once per Colab session
# ─────────────────────────────────────────────

# !apt-get update -qq
# !apt-get install -y -qq tesseract-ocr libtesseract-dev
# !tesseract --version
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# tesseract 4.1.1
#  leptonica-1.82.0
#   libgif 5.1.9 : libjpeg 8d (libjpeg-turbo 2.1.1) : libpng 1.6.37 : libtiff 4.3.0 : zlib 1.2.11 : libwebp 1.2.2 : libopenjp2 2.4.0
#  Found AVX2
#  Found AVX
#  Found FMA
#  Found SSE
#  Found libarchive 3.6.0 zlib/1.2.11 liblzma/5.2.5 bz2lib/1.0.8 liblz4/1.9.3 libzstd/1.4.8

# %%
# ─────────────────────────────────────────────
# BLOCK 3: Helper Functions
# Reusable utilities used in Stages 1 and 2
# ─────────────────────────────────────────────

def keyword_scan(text, keywords):
    """
    Checks if any keyword appears as a whole word in the given text.
    Returns (found: bool, matched_keywords: list).
    """
    if not isinstance(text, str):
        return False, []
    found_keywords = []
    for kw in keywords:
        if re.search(r'\b' + re.escape(kw) + r'\b', text, re.IGNORECASE):
            found_keywords.append(kw)
    return bool(found_keywords), found_keywords


def fetch_xml(doi, api_key):
    """
    Fetches the full-text XML for a paper from the Elsevier API.
    Returns (status_code, response_content_or_None).
    """
    url = f'https://api.elsevier.com/content/article/doi/{doi}?view=FULL'
    headers = {'X-ELS-APIKEY': api_key, 'Accept': 'text/xml'}
    try:
        r = requests.get(url, stream=True, headers=headers, timeout=30)
        return r.status_code, r if r.status_code == 200 else None
    except Exception as e:
        print(f"  [fetch_xml] Error for DOI {doi}: {e}")
        return 0, None


def parse_figures_from_xml(xml_path):
    """
    Parses an Elsevier XML file and extracts figure metadata:
    attachment EID, UCS locator, filename, and caption text.
    Returns a list of dicts.
    """
    tree = ET.parse(xml_path)
    root = tree.getroot()

    NS_CE   = {'ce':   'http://www.elsevier.com/xml/common/dtd'}
    NS_XOCS = {'xocs': 'http://www.elsevier.com/xml/xocs/dtd'}

    # --- Captions ------------------------------------------------
    captions = []
    for figure in root.findall('.//ce:figure', NS_CE):
        cap_el = figure.find('.//ce:caption', NS_CE)
        if cap_el is not None:
            sp_el = cap_el.find('.//ce:simple-para', NS_CE)
            if sp_el is not None:
                raw = ET.tostring(sp_el, encoding='unicode', method='text')
                captions.append(" ".join(re.sub('<.*?>', '', raw).split()))
            else:
                captions.append(None)
        else:
            captions.append(None)

    # --- Attachments (images) ------------------------------------
    attachments = []
    for att in root.findall('.//xocs:attachment', NS_XOCS):
        try:
            eid      = att.find('.//xocs:attachment-eid', NS_XOCS).text
            locator  = att.find('.//xocs:ucs-locator',    NS_XOCS).text
            filename = att.find('.//xocs:filename',        NS_XOCS).text
            attachments.append({'eid': eid, 'locator': locator, 'filename': filename})
        except AttributeError:
            continue  # skip malformed entries

    # --- Zip captions and attachments together -------------------
    figures = []
    for i, att in enumerate(attachments):
        caption = captions[i] if i < len(captions) else None
        link    = f"https://ars.els-cdn.com/content/image/{att['eid']}".replace('.jpg', '_lrg.jpg')
        figures.append({
            'UTD_EID':     att['eid'],
            'UCS_Locator': att['locator'],
            'Filename':    att['filename'],
            'Caption':     caption,
            'link':        link,
        })
    return figures


def ocr_image_from_url(url, keywords):
    """
    Downloads an image directly into memory, runs Tesseract OCR,
    and scans the extracted text for keywords.
    Returns (status_code, extracted_text, matched_keywords).
      status_code: 2 = keywords found, 0 = no keywords, 1 = error
    """
    try:
        response = requests.get(url, stream=True, timeout=30)
        if response.status_code != 200:
            return 1, '', []

        # Load image from bytes without saving to disk
        from io import BytesIO
        image = Image.open(BytesIO(response.content)).convert('L')
        image = ImageEnhance.Contrast(image).enhance(2)
        text  = pytesseract.image_to_string(image)

        found, matched = keyword_scan(text, keywords)
        return (2 if found else 0), text, matched

    except Exception as e:
        print(f"  [ocr_image_from_url] Error: {e}")
        return 1, '', []

print("✓ Helper functions defined.")
# Out:
# ✓ Helper functions defined.

# %%
# ─────────────────────────────────────────────
# BLOCK 4: Stage 1 — Caption Keyword Filter
# Downloads XML for each paper, parses figure
# captions, and checks for keywords.
# Does NOT save images.
# ─────────────────────────────────────────────

df_input = pd.read_csv(INPUT_CSV)

# We work on a fresh copy — original scopus.csv is never touched
df = df_input.copy()

stage1_results = []  # per-paper results for the tracker

for i, row in df.iterrows():
    doi = row.get('DOI', '')
    print(f"[{i+1}/{len(df)}] DOI: {doi}")

    if pd.isna(doi) or str(doi).strip() == '':
        stage1_results.append({'index': i, 'stage1_status': 'skipped', 'stage1_matched_kws': ''})
        continue

    # ── Fetch XML ──────────────────────────────────────────────
    status_code, response = fetch_xml(str(doi).strip(), API_KEY)

    if status_code != 200:
        print(f"  → HTTP {status_code}: XML not available")
        stage1_results.append({'index': i, 'stage1_status': 'no_xml', 'stage1_matched_kws': ''})
        continue

    # ── Save XML to disk (needed for Stage 2 parsing) ──────────
    xml_path = os.path.join(XML_DIR, f'{i+1}.xml')
    with open(xml_path, 'wb') as f:
        for chunk in response.iter_content(2048):
            f.write(chunk)

    # ── Parse figures & scan captions ─────────────────────────
    try:
        figures = parse_figures_from_xml(xml_path)
    except ET.ParseError as e:
        print(f"  → ParseError: {e}")
        stage1_results.append({'index': i, 'stage1_status': 'parse_error', 'stage1_matched_kws': ''})
        continue

    # Save per-paper figure CSV (used in Stage 2)
    figure_csv_path = os.path.join(CSV_DIR, f'output{i+1}.csv')
    pd.DataFrame(figures).to_csv(figure_csv_path, index=False)

    # Check if any caption contains a keyword
    all_matched = []
    for fig in figures:
        found, matched = keyword_scan(fig.get('Caption', ''), KEYWORDS)
        fig['stage1_hit']      = 1 if found else 0
        fig['stage1_keywords'] = ', '.join(matched)
        all_matched.extend(matched)

    # Save updated figure CSV with stage1 columns
    pd.DataFrame(figures).to_csv(figure_csv_path, index=False)

    paper_hit = bool(all_matched)
    status    = 'passed_stage1' if paper_hit else 'dropped_stage1'
    print(f"  → Stage 1: {'PASS' if paper_hit else 'DROP'} | Keywords: {list(set(all_matched))}")
    stage1_results.append({
        'index':               i,
        'stage1_status':       status,
        'stage1_matched_kws':  ', '.join(set(all_matched)),
    })

# ── Attach Stage 1 results to main dataframe ──────────────
s1_df = pd.DataFrame(stage1_results).set_index('index')
df = df.join(s1_df)

print(f"\n✓ Stage 1 complete.")
print(f"  Passed : {(df['stage1_status'] == 'passed_stage1').sum()}")
print(f"  Dropped: {(df['stage1_status'] == 'dropped_stage1').sum()}")
# Out:
# [1/2429] DOI: 10.1016/j.molliq.2022.119164
#   → HTTP 400: XML not available
# [2/2429] DOI: 10.1016/j.ijheatmasstransfer.2019.118710
#   → HTTP 400: XML not available
# [3/2429] DOI: 10.1016/0017-9310(89)90138-5
#   → HTTP 400: XML not available
# [4/2429] DOI: 10.1007/s10765-009-0617-z
#   → HTTP 404: XML not available
# [5/2429] DOI: 10.1103/PhysRevX.10.041029
#   → HTTP 404: XML not available
# [6/2429] DOI: 10.1016/j.ijheatmasstransfer.2012.08.003
#   → HTTP 400: XML not available
# [7/2429] DOI: 10.1088/0022-3727/34/6/313
#   → HTTP 404: XML not available
# [8/2429] DOI: 10.1016/j.sab.2014.08.026
#   → HTTP 400: XML not available
# [9/2429] DOI: 10.1007/s10973-017-6836-9
#   → HTTP 404: XML not available
# [10/2429] DOI: 10.1038/s41467-020-17822-0
#   → HTTP 404: XML not available
# [11/2429] DOI: 10.1016/0017-9310(94)00312-J
#   → HTTP 400: XML not available
# [12/2429] DOI: 10.1103/PhysRevE.71.066702
#   → HTTP 404: XML not available
# [13/2429] DOI: 10.1016/j.ijthermalsci.2021.107318
#   → HTTP 400: XML not available
# [14/2429] DOI: 10.1007/s10751-024-01931-z
#   → HTTP 404: XML not available
# [15/2429] DOI: 10.1016/0017-9310(94)90045-0
#   → HTTP 400: XML not available
# [16/2429] DOI: 10.1007/s11051-012-1369-4
#   → HTTP 404: XML not available
# [17/2429] DOI: 10.1016/j.tca.2017.02.001
#   → HTTP 400: XML not available
# [18/2429] DOI: 10.1115/1.4025499
#   → HTTP 404: XML not available
# [19/2429] DOI: 10.1115/1.1416688
#   → HTTP 404: XML not available
# [20/2429] DOI: 10.1016/j.ijheatmasstransfer.2018.04.128
#   → HTTP 400: XML not available
# [21/2429] DOI: 10.1038/ncomms4579
#   → HTTP 404: XML not available
# [22/2429] DOI: 10.1016/j.combustflame.2019.06.013
#   → HTTP 400: XML not available
# [23/2429] DOI: 10.1016/j.ijthermalsci.2004.02.014
#   → HTTP 400: XML not available
# [24/2429] DOI: 10.1016/j.ijheatmasstransfer.2013.10.034
#   → HTTP 400: XML not available
# [25/2429] DOI: 10.1103/PhysRevE.75.036702
#   → HTTP 404: XML not available
# [26/2429] DOI: 10.1016/j.ijheatmasstransfer.2022.123262
#   → Stage 1: PASS | Keywords: ['convection', 'thermal', 'temperature']
# [27/2429] DOI: 10.1007/s10973-018-7974-4
#   → HTTP 404: XML not available
# [28/2429] DOI: 10.1016/j.ijheatmasstransfer.2011.06.040
#   → HTTP 400: XML not available
# [29/2429] DOI: 10.1016/j.progpolymsci.2016.05.001
#   → HTTP 400: XML not available
# [30/2429] DOI: 10.1016/j.molliq.2019.111025
#   → HTTP 400: XML not available
# [31/2429] DOI: 10.1016/j.ijthermalsci.2020.106581
#   → HTTP 400: XML not available
# [32/2429] DOI: 10.1016/j.ijheatmasstransfer.2011.06.024
#   → HTTP 400: XML not available
# [33/2429] DOI: 10.1007/s10973-018-7099-9
#   → HTTP 404: XML not available
# [34/2429] DOI: 10.1016/j.icheatmasstransfer.2024.107292
#   → HTTP 400: XML not available
# [35/2429] DOI: 10.1115/1.2789719
#   → HTTP 404: XML not available
# [36/2429] DOI: 10.1088/0031-8949/87/05/055005
#   → HTTP 404: XML not available
# [37/2429] DOI: 10.1063/1.1915540
#   → HTTP 404: XML not available
# [38/2429] DOI: 10.1016/j.ijheatfluidflow.2011.12.005
#   → HTTP 400: XML not available
# [39/2429] DOI: 10.1016/j.combustflame.2017.02.015
#   → HTTP 400: XML not available
# [40/2429] DOI: 10.1016/j.icheatmasstransfer.2020.104930
#   → Stage 1: PASS | Keywords: ['thermal', 'conductivity']
# [41/2429] DOI: 10.1016/j.icheatmasstransfer.2016.07.001
#   → HTTP 400: XML not available
# [42/2429] DOI: 10.1115/1.1454111
#   → HTTP 404: XML not available
# [43/2429] DOI: 10.2514/2.6458
#   → HTTP 404: XML not available
# [44/2429] DOI: 10.1016/S0017-9310(97)00042-2
#   → HTTP 400: XML not available
# [45/2429] DOI: 10.1016/j.ijheatmasstransfer.2017.10.126
#   → HTTP 400: XML not available
# [46/2429] DOI: 10.1016/j.ijheatmasstransfer.2016.04.094
#   → HTTP 400: XML not available
# [47/2429] DOI: 10.1080/01457630590907185
#   → HTTP 404: XML not available
# [48/2429] DOI: 10.13182/nt96-a35286
#   → HTTP 404: XML not available
# [49/2429] DOI: 10.1016/j.icheatmasstransfer.2013.06.007
#   → HTTP 400: XML not available
# [50/2429] DOI: 10.1016/j.ijheatmasstransfer.2020.120066
#   → HTTP 400: XML not available
# [51/2429] DOI: 10.1016/0017-9310(78)90182-5
#   → HTTP 400: XML not available
# [52/2429] DOI: 10.1016/j.ijheatmasstransfer.2017.01.094
#   → HTTP 400: XML not available
# [53/2429] DOI: 10.1016/j.combustflame.2016.07.007
#   → HTTP 400: XML not available
# [54/2429] DOI: 10.4028/www.scientific.net/DDF.374.148
#   → HTTP 404: XML not available
# [55/2429] DOI: 10.1016/j.ndteint.2009.01.011
#   → HTTP 400: XML not available
# [56/2429] DOI: 10.1115/1.2824119
#   → HTTP 404: XML not available
# [57/2429] DOI: 10.1016/j.icheatmasstransfer.2018.07.004
#   → HTTP 400: XML not available
# [58/2429] DOI: 10.1016/j.ijheatfluidflow.2006.09.005
#   → HTTP 400: XML not available
# [59/2429] DOI: 10.1016/j.combustflame.2016.10.007
#   → HTTP 400: XML not available
# [60/2429] DOI: 10.1115/1.2818775
#   → HTTP 404: XML not available
# [61/2429] DOI: 10.1115/1.2928010
#   → HTTP 404: XML not available
# [62/2429] DOI: 10.1016/j.ijheatmasstransfer.2009.04.029
#   → HTTP 400: XML not available
# [63/2429] DOI: 10.3390/app6090226
#   → HTTP 404: XML not available
# [64/2429] DOI: 10.1016/j.ijthermalsci.2011.06.010
#   → HTTP 400: XML not available
# [65/2429] DOI: 10.1007/s00231-011-0792-x
#   → HTTP 404: XML not available
# [66/2429] DOI: 10.1016/j.ijheatmasstransfer.2013.10.007
#   → HTTP 400: XML not available
# [67/2429] DOI: 10.1016/j.ijheatmasstransfer.2014.04.040
#   → HTTP 400: XML not available
# [68/2429] DOI: 10.1016/j.progpolymsci.2014.07.001
#   → HTTP 400: XML not available
# [69/2429] DOI: 10.1016/j.nucengdes.2019.110207
#   → HTTP 400: XML not available
# [70/2429] DOI: 10.1016/j.icheatmasstransfer.2016.02.009
#   → HTTP 400: XML not available
# [71/2429] DOI: 10.1016/j.diamond.2024.111018
#   → HTTP 400: XML not available
# [72/2429] DOI: 10.1080/10407782.2017.1412679
#   → HTTP 404: XML not available
# [73/2429] DOI: 10.1016/j.ijthermalsci.2020.106682
#   → HTTP 400: XML not available
# [74/2429] DOI: 10.1016/j.combustflame.2023.112831
#   → HTTP 400: XML not available
# [75/2429] DOI: 10.3390/s21113873
#   → HTTP 404: XML not available
# [76/2429] DOI: 10.1016/j.icheatmasstransfer.2017.04.006
#   → HTTP 400: XML not available
# [77/2429] DOI: 10.1016/j.icheatmasstransfer.2025.108845
#   → Stage 1: PASS | Keywords: ['convection', 'temperature']
# [78/2429] DOI: 10.1016/j.ijheatmasstransfer.2015.04.034
#   → HTTP 400: XML not available
# [79/2429] DOI: 10.1115/1.2227038
#   → HTTP 404: XML not available
# [80/2429] DOI: 10.1038/nnano.2016.17
#   → HTTP 404: XML not available
# [81/2429] DOI: 10.1016/S0017-9310(02)00101-1
#   → HTTP 400: XML not available
# [82/2429] DOI: 10.1016/j.ijthermalsci.2021.107007
#   → HTTP 400: XML not available
# [83/2429] DOI: 10.1021/nl902358m
#   → HTTP 404: XML not available
# [84/2429] DOI: 10.1140/epjp/s13360-020-00252-8
#   → HTTP 404: XML not available
# [85/2429] DOI: 10.1115/1.2830048
#   → HTTP 404: XML not available
# [86/2429] DOI: 10.1016/j.icheatmasstransfer.2017.05.024
#   → HTTP 400: XML not available
# [87/2429] DOI: 10.1103/PhysRevB.80.195423
#   → HTTP 404: XML not available
# [88/2429] DOI: 10.1016/j.ijheatmasstransfer.2019.119162
#   → HTTP 400: XML not available
# [89/2429] DOI: 10.1016/0360-3199(90)90181-W
#   → HTTP 400: XML not available
# [90/2429] DOI: 10.1016/j.ijheatmasstransfer.2014.05.058
#   → HTTP 400: XML not available
# [91/2429] DOI: 10.1016/j.molliq.2019.112249
#   → HTTP 400: XML not available
# [92/2429] DOI: 10.1103/PhysRevE.76.061203
#   → HTTP 404: XML not available
# [93/2429] DOI: 10.1007/s10973-018-7182-2
#   → HTTP 404: XML not available
# [94/2429] DOI: 10.1016/j.ijheatmasstransfer.2016.02.042
#   → HTTP 400: XML not available
# [95/2429] DOI: 10.1007/s10973-013-3472-x
#   → HTTP 404: XML not available
# [96/2429] DOI: 10.1016/j.ijhydene.2011.04.055
#   → HTTP 400: XML not available
# [97/2429] DOI: 10.1063/1.2802183
#   → HTTP 404: XML not available
# [98/2429] DOI: 10.1016/j.colsurfa.2020.125918
#   → HTTP 400: XML not available
# [99/2429] DOI: 10.1103/PhysRevB.104.245209
#   → HTTP 404: XML not available
# [100/2429] DOI: 10.1007/s10973-020-10176-1
#   → HTTP 404: XML not available
# [101/2429] DOI: 10.1109/27.848096
#   → HTTP 404: XML not available
# [102/2429] DOI: 10.1016/j.molliq.2021.116929
#   → HTTP 400: XML not available
# [103/2429] DOI: 10.1038/s41467-017-00115-4
#   → HTTP 404: XML not available
# [104/2429] DOI: 10.1016/j.colsurfa.2016.04.016
#   → HTTP 400: XML not available
# [105/2429] DOI: 10.1016/j.combustflame.2017.02.003
#   → HTTP 400: XML not available
# [106/2429] DOI: 10.1016/j.matchemphys.2021.125182
#   → HTTP 400: XML not available
# [107/2429] DOI: 10.1080/00102200008952127
#   → HTTP 404: XML not available
# [108/2429] DOI: 10.1038/nnano.2015.6
#   → HTTP 404: XML not available
# [109/2429] DOI: 10.1007/s00231-006-0212-9
#   → HTTP 404: XML not available
# [110/2429] DOI: 10.1088/0964-1726/21/4/045013
#   → HTTP 404: XML not available
# [111/2429] DOI: 10.1016/j.ijheatmasstransfer.2022.123452
#   → HTTP 400: XML not available
# [112/2429] DOI: 10.1063/1.4975219
#   → HTTP 404: XML not available
# [113/2429] DOI: 10.1016/j.ijheatmasstransfer.2004.06.022
#   → HTTP 400: XML not available
# [114/2429] DOI: 10.1016/j.ijheatmasstransfer.2014.07.001
#   → HTTP 400: XML not available
# [115/2429] DOI: 10.1016/0017-9310(83)90011-X
#   → HTTP 400: XML not available
# [116/2429] DOI: 10.1016/j.ijthermalsci.2013.12.018
#   → HTTP 400: XML not available
# [117/2429] DOI: 10.1016/j.ijthermalsci.2021.106935
#   → HTTP 400: XML not available
# [118/2429] DOI: 10.1007/s13204-020-01578-6
#   → HTTP 404: XML not available
# [119/2429] DOI: 10.1016/j.ijheatmasstransfer.2016.07.042
#   → HTTP 400: XML not available
# [120/2429] DOI: 10.1115/1.4036804
#   → HTTP 404: XML not available
# [121/2429] DOI: 10.1186/1556-276X-6-293
#   → HTTP 404: XML not available
# [122/2429] DOI: 10.1115/1.3246712
#   → HTTP 404: XML not available
# [123/2429] DOI: 10.1115/1.3450239
#   → HTTP 404: XML not available
# [124/2429] DOI: 10.1016/j.ijthermalsci.2020.106446
#   → HTTP 400: XML not available
# [125/2429] DOI: 10.1016/j.icheatmasstransfer.2016.09.009
#   → HTTP 400: XML not available
# [126/2429] DOI: 10.1115/1.3072928
#   → HTTP 404: XML not available
# [127/2429] DOI: 10.1016/j.ijheatmasstransfer.2020.119331
#   → HTTP 400: XML not available
# [128/2429] DOI: 10.1063/1.1898437
#   → HTTP 404: XML not available
# [129/2429] DOI: 10.1016/j.jqsrt.2007.10.008
#   → HTTP 400: XML not available
# [130/2429] DOI: 10.1016/j.ijheatmasstransfer.2006.11.042
#   → HTTP 400: XML not available
# [131/2429] DOI: 10.1016/j.elstat.2018.01.004
#   → HTTP 400: XML not available
# [132/2429] DOI: 10.1088/2053-1583/3/3/035016
#   → HTTP 404: XML not available
# [133/2429] DOI: 10.1016/j.icheatmasstransfer.2025.108606
#   → HTTP 400: XML not available
# [134/2429] DOI: 10.1016/S0029-5493(01)00487-3
#   → HTTP 400: XML not available
# [135/2429] DOI: 10.1016/S0017-9310(02)00348-4
#   → HTTP 400: XML not available
# [136/2429] DOI: 10.1016/j.molliq.2019.111982
#   → HTTP 400: XML not available
# [137/2429] DOI: 10.1016/j.icarus.2011.09.030
#   → HTTP 400: XML not available
# [138/2429] DOI: 10.1177/0892705717738304
#   → HTTP 404: XML not available
# [139/2429] DOI: 10.1007/s10973-018-7484-4
#   → HTTP 404: XML not available
# [140/2429] DOI: 10.1115/1.4023747
#   → HTTP 404: XML not available
# [141/2429] DOI: 10.1149/1.1393490
#   → HTTP 404: XML not available
# [142/2429] DOI: 10.1016/j.ijheatfluidflow.2013.07.006
#   → HTTP 400: XML not available
# [143/2429] DOI: 10.1016/j.ijheatmasstransfer.2005.01.002
#   → HTTP 400: XML not available
# [144/2429] DOI: 10.1016/j.ijheatmasstransfer.2015.05.007
#   → HTTP 400: XML not available
# [145/2429] DOI: 10.1007/s11090-008-9165-8
#   → HTTP 404: XML not available
# [146/2429] DOI: 10.1016/j.colsurfa.2017.05.004
#   → HTTP 400: XML not available
# [147/2429] DOI: 10.1016/j.ijheatmasstransfer.2014.07.098
#   → HTTP 400: XML not available
# [148/2429] DOI: 10.1016/j.icheatmasstransfer.2016.04.028
#   → HTTP 400: XML not available
# [149/2429] DOI: 10.1080/10407789208944769
#   → HTTP 404: XML not available
# [150/2429] DOI: 10.1016/j.combustflame.2011.06.003
#   → HTTP 400: XML not available
# [151/2429] DOI: 10.1016/j.icheatmasstransfer.2017.12.006
#   → HTTP 400: XML not available
# [152/2429] DOI: 10.1016/j.ijthermalsci.2014.06.001
#   → HTTP 400: XML not available
# [153/2429] DOI: 10.1016/j.combustflame.2014.09.017
#   → HTTP 400: XML not available
# [154/2429] DOI: 10.1115/1.1332780
#   → HTTP 404: XML not available
# [155/2429] DOI: 10.1007/s10973-014-4328-8
#   → HTTP 404: XML not available
# [156/2429] DOI: 10.1016/j.ijheatmasstransfer.2004.03.014
#   → HTTP 400: XML not available
# [157/2429] DOI: 10.1016/j.ijheatmasstransfer.2006.05.016
#   → HTTP 400: XML not available
# [158/2429] DOI: 10.1016/j.jct.2018.04.007
#   → HTTP 400: XML not available
# [159/2429] DOI: 10.1016/j.ultsonch.2019.104639
#   → HTTP 400: XML not available
# [160/2429] DOI: 10.1007/s11663-001-0079-6
#   → HTTP 404: XML not available
# [161/2429] DOI: 10.1016/j.ijmecsci.2017.12.025
#   → HTTP 400: XML not available
# [162/2429] DOI: 10.1016/j.cryogenics.2020.103174
#   → HTTP 400: XML not available
# [163/2429] DOI: 10.1115/1.2910879
#   → HTTP 404: XML not available
# [164/2429] DOI: 10.1016/j.ijheatmasstransfer.2014.01.058
#   → HTTP 400: XML not available
# [165/2429] DOI: 10.1016/j.ijthermalsci.2016.06.002
#   → HTTP 400: XML not available
# [166/2429] DOI: 10.1016/j.molliq.2022.121164
#   → HTTP 400: XML not available
# [167/2429] DOI: 10.1016/S0017-9310(01)00220-4
#   → HTTP 400: XML not available
# [168/2429] DOI: 10.1016/j.mseb.2007.01.048
#   → HTTP 400: XML not available
# [169/2429] DOI: 10.3390/coatings7100158
#   → HTTP 404: XML not available
# [170/2429] DOI: 10.1115/1.1518496
#   → HTTP 404: XML not available
# [171/2429] DOI: 10.1016/j.ijheatmasstransfer.2013.11.031
#   → HTTP 400: XML not available
# [172/2429] DOI: 10.1016/j.ijheatmasstransfer.2022.122582
#   → HTTP 400: XML not available
# [173/2429] DOI: 10.1016/j.ijthermalsci.2021.106972
#   → HTTP 400: XML not available
# [174/2429] DOI: 10.1016/j.ijheatmasstransfer.2015.01.047
#   → HTTP 400: XML not available
# [175/2429] DOI: 10.1016/j.ijheatmasstransfer.2021.120903
#   → HTTP 400: XML not available
# [176/2429] DOI: 10.1007/s00231-002-0397-5
#   → HTTP 404: XML not available
# [177/2429] DOI: 10.1016/j.icheatmasstransfer.2022.106244
#   → HTTP 400: XML not available
# [178/2429] DOI: 10.1016/j.ijthermalsci.2017.10.015
#   → HTTP 400: XML not available
# [179/2429] DOI: 10.1016/j.ijheatmasstransfer.2020.119914
#   → HTTP 400: XML not available
# [180/2429] DOI: 10.1016/j.icheatmasstransfer.2015.09.004
#   → HTTP 400: XML not available
# [181/2429] DOI: 10.1016/j.combustflame.2019.07.046
#   → HTTP 400: XML not available
# [182/2429] DOI: 10.1016/j.icheatmasstransfer.2019.02.002
#   → HTTP 400: XML not available
# [183/2429] DOI: 10.1016/j.microrel.2005.06.003
#   → HTTP 400: XML not available
# [184/2429] DOI: 10.1115/1.2911909
#   → HTTP 404: XML not available
# [185/2429] DOI: 10.1016/j.jmmm.2012.08.037
#   → HTTP 400: XML not available
# [186/2429] DOI: 10.1016/j.ijheatmasstransfer.2018.12.005
#   → HTTP 400: XML not available
# [187/2429] DOI: 10.1016/j.ijheatmasstransfer.2015.11.030
#   → HTTP 400: XML not available
# [188/2429] DOI: 10.1016/j.ijthermalsci.2014.07.017
#   → HTTP 400: XML not available
# [189/2429] DOI: 10.1007/s11051-010-0197-7
#   → HTTP 404: XML not available
# [190/2429] DOI: 10.1080/01457632.2018.1442309
#   → HTTP 404: XML not available
# [191/2429] DOI: 10.1186/1556-276X-6-229
#   → HTTP 404: XML not available
# [192/2429] DOI: 10.1016/j.ijheatmasstransfer.2018.04.059
#   → HTTP 400: XML not available
# [193/2429] DOI: 10.1016/j.ijheatmasstransfer.2013.06.057
#   → HTTP 400: XML not available
# [194/2429] DOI: 10.1016/j.colsurfa.2021.126720
#   → HTTP 400: XML not available
# [195/2429] DOI: 10.1615/JEnhHeatTransf.v14.i3.40
#   → HTTP 404: XML not available
# [196/2429] DOI: 10.1016/j.molliq.2014.04.019
#   → HTTP 400: XML not available
# [197/2429] DOI: 10.1115/1.3250610
#   → HTTP 404: XML not available
# [198/2429] DOI: 10.1016/j.icheatmasstransfer.2020.104698
#   → HTTP 400: XML not available
# [199/2429] DOI: 10.1016/j.ijheatmasstransfer.2016.03.125
#   → HTTP 400: XML not available
# [200/2429] DOI: 10.1038/s41467-024-46799-3
#   → HTTP 404: XML not available
# [201/2429] DOI: 10.1016/j.ijthermalsci.2013.04.024
#   → HTTP 400: XML not available
# [202/2429] DOI: 10.1103/PhysRevE.75.026403
#   → HTTP 404: XML not available
# [203/2429] DOI: 10.1016/j.ijheatmasstransfer.2017.01.011
#   → HTTP 400: XML not available
# [204/2429] DOI: 10.1063/5.0091291
#   → HTTP 404: XML not available
# [205/2429] DOI: 10.1016/j.ijheatmasstransfer.2018.11.044
#   → HTTP 400: XML not available
# [206/2429] DOI: 10.1016/j.ijheatmasstransfer.2015.08.107
#   → HTTP 400: XML not available
# [207/2429] DOI: 10.1016/j.ijheatmasstransfer.2015.06.032
#   → HTTP 400: XML not available
# [208/2429] DOI: 10.1016/j.chemphys.2004.08.005
#   → HTTP 400: XML not available
# [209/2429] DOI: 10.1016/j.ijheatmasstransfer.2014.10.006
#   → HTTP 400: XML not available
# [210/2429] DOI: 10.1007/s00231-019-02581-6
#   → HTTP 404: XML not available
# [211/2429] DOI: 10.1115/1.3245679
#   → HTTP 404: XML not available
# [212/2429] DOI: 10.1016/j.progpolymsci.2011.11.003
#   → HTTP 400: XML not available
# [213/2429] DOI: 10.1016/j.physb.2014.09.031
#   → HTTP 400: XML not available
# [214/2429] DOI: 10.1115/1.4036526
#   → HTTP 404: XML not available
# [215/2429] DOI: 10.1016/j.ijhydene.2012.03.018
#   → HTTP 400: XML not available
# [216/2429] DOI: 10.1007/s002310000168
#   → HTTP 404: XML not available
# [217/2429] DOI: 10.1007/s10973-020-09541-x
#   → HTTP 404: XML not available
# [218/2429] DOI: 10.1016/j.ijheatmasstransfer.2020.120292
#   → HTTP 400: XML not available
# [219/2429] DOI: 10.1016/j.cryogenics.2005.09.002
#   → HTTP 400: XML not available
# [220/2429] DOI: 10.1140/epjp/i2018-12278-4
#   → HTTP 404: XML not available
# [221/2429] DOI: 10.1016/j.ijheatmasstransfer.2023.124790
#   → HTTP 400: XML not available
# [222/2429] DOI: 10.1016/j.ijheatmasstransfer.2021.122314
#   → HTTP 400: XML not available
# [223/2429] DOI: 10.1080/104077899275399
#   → HTTP 404: XML not available
# [224/2429] DOI: 10.1016/S0017-9310(97)00217-2
#   → HTTP 400: XML not available
# [225/2429] DOI: 10.1016/j.ijheatmasstransfer.2023.123892
#   → Stage 1: PASS | Keywords: ['temperature']
# [226/2429] DOI: 10.1080/10407782.2013.869449
#   → HTTP 404: XML not available
# [227/2429] DOI: 10.1016/j.icheatmasstransfer.2004.10.030
#   → HTTP 400: XML not available
# [228/2429] DOI: 10.1016/j.ijthermalsci.2017.01.017
#   → HTTP 400: XML not available
# [229/2429] DOI: 10.1016/j.icheatmasstransfer.2020.104957
#   → HTTP 400: XML not available
# [230/2429] DOI: 10.2514/2.6711
#   → HTTP 404: XML not available
# [231/2429] DOI: 10.1016/j.ijheatmasstransfer.2019.118459
#   → HTTP 400: XML not available
# [232/2429] DOI: 10.1016/0304-8853(90)90032-L
#   → HTTP 400: XML not available
# [233/2429] DOI: 10.1007/s10973-017-6744-z
#   → HTTP 404: XML not available
# [234/2429] DOI: 10.1016/j.icheatmasstransfer.2008.07.015
#   → HTTP 400: XML not available
# [235/2429] DOI: 10.1016/j.ijheatmasstransfer.2019.01.018
#   → HTTP 400: XML not available
# [236/2429] DOI: 10.1016/j.tca.2008.09.012
#   → HTTP 400: XML not available
# [237/2429] DOI: 10.1063/1.4975153
#   → HTTP 404: XML not available
# [238/2429] DOI: 10.1002/adem.200900138
#   → HTTP 404: XML not available
# [239/2429] DOI: 10.1016/j.ijheatmasstransfer.2017.11.019
#   → HTTP 400: XML not available
# [240/2429] DOI: 10.1038/s41467-020-18212-2
#   → HTTP 404: XML not available
# [241/2429] DOI: 10.1016/0017-9310(88)90096-8
#   → HTTP 400: XML not available
# [242/2429] DOI: 10.1016/j.molliq.2018.02.086
#   → HTTP 400: XML not available
# [243/2429] DOI: 10.1016/j.ijthermalsci.2014.10.012
#   → HTTP 400: XML not available
# [244/2429] DOI: 10.1016/j.ijmultiphaseflow.2016.05.016
#   → HTTP 400: XML not available
# [245/2429] DOI: 10.1007/s12274-020-3255-1
#   → HTTP 404: XML not available
# [246/2429] DOI: 10.1063/1.356287
#   → HTTP 404: XML not available
# [247/2429] DOI: 10.1016/j.cma.2018.09.041
#   → HTTP 400: XML not available
# [248/2429] DOI: 10.1016/j.tca.2012.07.017
#   → HTTP 400: XML not available
# [249/2429] DOI: 10.1016/0017-9310(87)90166-9
#   → HTTP 400: XML not available
# [250/2429] DOI: 10.1016/j.ijft.2020.100029
#   → Stage 1: PASS | Keywords: ['heat flux', 'thermal']
# [251/2429] DOI: 10.1016/j.molliq.2021.116771
#   → HTTP 400: XML not available
# [252/2429] DOI: 10.1002/polb.10713
#   → HTTP 404: XML not available
# [253/2429] DOI: 10.1016/j.icheatmasstransfer.2017.06.012
#   → HTTP 400: XML not available
# [254/2429] DOI: 10.1038/s41467-023-36690-y
#   → HTTP 404: XML not available
# [255/2429] DOI: 10.1016/j.ijheatmasstransfer.2018.07.093
#   → HTTP 400: XML not available
# [256/2429] DOI: 10.1016/j.ijheatmasstransfer.2016.04.096
#   → HTTP 400: XML not available
# [257/2429] DOI: 10.1016/j.combustflame.2006.04.011
#   → HTTP 400: XML not available
# [258/2429] DOI: 10.1007/s11051-007-9347-y
#   → HTTP 404: XML not available
# [259/2429] DOI: 10.1016/j.icheatmasstransfer.2013.07.003
#   → HTTP 400: XML not available
# [260/2429] DOI: 10.1016/j.ijthermalsci.2018.11.030
#   → HTTP 400: XML not available
# [261/2429] DOI: 10.1016/j.cryogenics.2009.09.003
#   → HTTP 400: XML not available
# [262/2429] DOI: 10.1016/j.icheatmasstransfer.2016.03.004
#   → HTTP 400: XML not available
# [263/2429] DOI: 10.1088/0957-0233/15/9/034
#   → HTTP 404: XML not available
# [264/2429] DOI: 10.1007/s002310000120
#   → HTTP 404: XML not available
# [265/2429] DOI: 10.1016/j.ijthermalsci.2019.04.028
#   → HTTP 400: XML not available
# [266/2429] DOI: 10.1016/j.ijheatmasstransfer.2017.02.016
#   → HTTP 400: XML not available
# [267/2429] DOI: 10.1038/s41467-018-04251-3
#   → HTTP 404: XML not available
# [268/2429] DOI: 10.1007/s00231-011-0945-y
#   → HTTP 404: XML not available
# [269/2429] DOI: 10.1016/j.ijheatmasstransfer.2016.10.084
#   → HTTP 400: XML not available
# [270/2429] DOI: 10.1016/j.ijthermalsci.2016.04.010
#   → HTTP 400: XML not available
# [271/2429] DOI: 10.1007/s10765-020-02651-6
#   → HTTP 404: XML not available
# [272/2429] DOI: 10.1016/j.combustflame.2003.09.013
#   → HTTP 400: XML not available
# [273/2429] DOI: 10.1016/j.ijthermalsci.2018.04.030
#   → HTTP 400: XML not available
# [274/2429] DOI: 10.1016/j.ijthermalsci.2015.10.005
#   → HTTP 400: XML not available
# [275/2429] DOI: 10.1016/j.ijthermalsci.2008.05.017
#   → HTTP 400: XML not available
# [276/2429] DOI: 10.1016/j.ijheatmasstransfer.2003.08.012
#   → HTTP 400: XML not available
# [277/2429] DOI: 10.1016/j.molliq.2017.05.071
#   → HTTP 400: XML not available
# [278/2429] DOI: 10.1007/s10973-005-0619-4
#   → HTTP 404: XML not available
# [279/2429] DOI: 10.1016/j.molliq.2019.03.127
#   → HTTP 400: XML not available
# [280/2429] DOI: 10.1016/j.ijheatmasstransfer.2013.07.024
#   → HTTP 400: XML not available
# [281/2429] DOI: 10.1016/j.ijhydene.2011.01.146
#   → HTTP 400: XML not available
# [282/2429] DOI: 10.1016/j.icheatmasstransfer.2017.10.005
#   → HTTP 400: XML not available
# [283/2429] DOI: 10.1016/j.ijheatmasstransfer.2021.122393
#   → HTTP 400: XML not available
# [284/2429] DOI: 10.1016/j.ijmecsci.2018.05.031
#   → HTTP 400: XML not available
# [285/2429] DOI: 10.1007/s10973-017-6301-9
#   → HTTP 404: XML not available
# [286/2429] DOI: 10.1016/j.ijheatmasstransfer.2020.120716
#   → HTTP 400: XML not available
# [287/2429] DOI: 10.1007/s11666-017-0585-y
#   → HTTP 404: XML not available
# [288/2429] DOI: 10.1016/j.ijheatmasstransfer.2019.118974
#   → HTTP 400: XML not available
# [289/2429] DOI: 10.1115/1.1287793
#   → HTTP 404: XML not available
# [290/2429] DOI: 10.1016/j.pepi.2017.01.005
#   → HTTP 400: XML not available
# [291/2429] DOI: 10.1016/j.ijmultiphaseflow.2012.01.003
#   → HTTP 400: XML not available
# [292/2429] DOI: 10.1016/j.ultsonch.2025.107520
#   → Stage 1: PASS | Keywords: ['temperature']
# [293/2429] DOI: 10.1016/j.ijheatmasstransfer.2020.120293
#   → HTTP 400: XML not available
# [294/2429] DOI: 10.1016/j.ijthermalsci.2021.107151
#   → HTTP 400: XML not available
# [295/2429] DOI: 10.1016/j.ijheatmasstransfer.2015.01.019
#   → HTTP 400: XML not available
# [296/2429] DOI: 10.1016/j.combustflame.2022.112595
#   → HTTP 400: XML not available
# [297/2429] DOI: 10.1016/j.ijheatmasstransfer.2017.10.036
#   → HTTP 400: XML not available
# [298/2429] DOI: 10.1080/01457632.2012.624858
#   → HTTP 404: XML not available
# [299/2429] DOI: 10.1016/j.molliq.2019.01.153
#   → HTTP 400: XML not available
# [300/2429] DOI: 10.1016/j.ijthermalsci.2018.12.020
#   → HTTP 400: XML not available
# [301/2429] DOI: 10.1016/j.icheatmasstransfer.2014.04.011
#   → HTTP 400: XML not available
# [302/2429] DOI: 10.1016/j.icheatmasstransfer.2022.106246
#   → HTTP 400: XML not available
# [303/2429] DOI: 10.1007/s11666-011-9623-3
#   → HTTP 404: XML not available
# [304/2429] DOI: 10.1016/S0017-9310(00)00046-6
#   → HTTP 400: XML not available
# [305/2429] DOI: 10.1016/j.icheatmasstransfer.2020.105018
#   → HTTP 400: XML not available
# [306/2429] DOI: 10.1016/j.ijheatmasstransfer.2019.04.046
#   → HTTP 400: XML not available
# [307/2429] DOI: 10.1186/1556-276X-8-64
#   → HTTP 404: XML not available
# [308/2429] DOI: 10.1115/1.4004430
#   → HTTP 404: XML not available
# [309/2429] DOI: 10.1016/j.ijthermalsci.2021.107016
#   → HTTP 400: XML not available
# [310/2429] DOI: 10.1016/j.icheatmasstransfer.2016.06.005
#   → HTTP 400: XML not available
# [311/2429] DOI: 10.1016/j.ijthermalsci.2004.11.012
#   → HTTP 400: XML not available
# [312/2429] DOI: 10.1088/0268-1242/31/11/113003
#   → HTTP 404: XML not available
# [313/2429] DOI: 10.1615/JEnhHeatTransf.v15.i4.10
#   → HTTP 404: XML not available
# [314/2429] DOI: 10.1016/j.ijheatmasstransfer.2023.124180
#   → HTTP 400: XML not available
# [315/2429] DOI: 10.1016/j.ijheatmasstransfer.2014.08.071
#   → HTTP 400: XML not available
# [316/2429] DOI: 10.1007/s002310050222
#   → HTTP 404: XML not available
# [317/2429] DOI: 10.1117/12.809021
#   → HTTP 404: XML not available
# [318/2429] DOI: 10.1016/j.ijhydene.2013.03.104
#   → HTTP 400: XML not available
# [319/2429] DOI: 10.1080/10407780290059396
#   → HTTP 404: XML not available
# [320/2429] DOI: 10.1016/j.ijheatmasstransfer.2020.119540
#   → HTTP 400: XML not available
# [321/2429] DOI: 10.1016/j.ijthermalsci.2011.10.007
#   → HTTP 400: XML not available
# [322/2429] DOI: 10.1080/01457632.2017.1358488
#   → HTTP 404: XML not available
# [323/2429] DOI: 10.1016/j.ijheatmasstransfer.2021.121256
#   → HTTP 400: XML not available
# [324/2429] DOI: 10.1016/j.ijthermalsci.2012.08.015
#   → HTTP 400: XML not available
# [325/2429] DOI: 10.1002/htj.21606
#   → HTTP 404: XML not available
# [326/2429] DOI: 10.1016/j.ijthermalsci.2006.11.009
#   → HTTP 400: XML not available
# [327/2429] DOI: 10.1115/1.1351169
#   → HTTP 404: XML not available
# [328/2429] DOI: 10.1016/j.ijthermalsci.2020.106331
#   → HTTP 400: XML not available
# [329/2429] DOI: 10.1016/j.icheatmasstransfer.2011.03.005
#   → HTTP 400: XML not available
# [330/2429] DOI: 10.1016/j.jnoncrysol.2017.05.020
#   → HTTP 400: XML not available
# [331/2429] DOI: 10.3390/ma13041011
#   → HTTP 404: XML not available
# [332/2429] DOI: 10.1039/b817666c
#   → HTTP 404: XML not available
# [333/2429] DOI: 10.1007/s11051-009-9658-2
#   → HTTP 404: XML not available
# [334/2429] DOI: 10.1016/j.ijheatmasstransfer.2013.05.001
#   → HTTP 400: XML not available
# [335/2429] DOI: 10.1063/1.4705510
#   → HTTP 404: XML not available
# [336/2429] DOI: 10.1016/j.ijheatmasstransfer.2012.11.037
#   → HTTP 400: XML not available
# [337/2429] DOI: 10.2514/1.T4119
#   → HTTP 404: XML not available
# [338/2429] DOI: 10.1038/s41467-024-48888-9
#   → HTTP 404: XML not available
# [339/2429] DOI: 10.1016/j.icheatmasstransfer.2015.04.006
#   → HTTP 400: XML not available
# [340/2429] DOI: 10.1016/j.ijheatmasstransfer.2009.09.024
#   → HTTP 400: XML not available
# [341/2429] DOI: 10.1016/j.ijheatmasstransfer.2021.121191
#   → HTTP 400: XML not available
# [342/2429] DOI: 10.1016/j.molliq.2019.03.051
#   → HTTP 400: XML not available
# [343/2429] DOI: 10.1016/j.ijheatmasstransfer.2007.07.029
#   → HTTP 400: XML not available
# [344/2429] DOI: 10.1016/j.ijheatmasstransfer.2012.05.076
#   → HTTP 400: XML not available
# [345/2429] DOI: 10.1186/1556-276X-6-231
#   → HTTP 404: XML not available
# [346/2429] DOI: 10.1016/j.ijheatmasstransfer.2012.06.036
#   → HTTP 400: XML not available
# [347/2429] DOI: 10.1016/j.icheatmasstransfer.2022.106054
#   → Stage 1: DROP | Keywords: []
# [348/2429] DOI: 10.1103/PhysRevApplied.11.024044
#   → HTTP 404: XML not available
# [349/2429] DOI: 10.1063/1.4930258
#   → HTTP 404: XML not available
# [350/2429] DOI: 10.1016/j.icheatmasstransfer.2017.07.019
#   → HTTP 400: XML not available
# [351/2429] DOI: 10.1016/j.icheatmasstransfer.2023.106690
#   → HTTP 400: XML not available
# [352/2429] DOI: 10.1016/j.icheatmasstransfer.2014.08.037
#   → HTTP 400: XML not available
# [353/2429] DOI: 10.1016/j.matchemphys.2007.10.029
#   → HTTP 400: XML not available
# [354/2429] DOI: 10.1016/j.icheatmasstransfer.2016.05.025
#   → HTTP 400: XML not available
# [355/2429] DOI: 10.1016/S0014-3057(01)00208-7
#   → HTTP 400: XML not available
# [356/2429] DOI: 10.1016/j.physe.2017.10.004
#   → HTTP 400: XML not available
# [357/2429] DOI: 10.1016/j.icheatmasstransfer.2016.08.009
#   → HTTP 400: XML not available
# [358/2429] DOI: 10.1016/j.icheatmasstransfer.2019.104450
#   → HTTP 400: XML not available
# [359/2429] DOI: 10.1016/j.ijheatmasstransfer.2004.03.009
#   → HTTP 400: XML not available
# [360/2429] DOI: 10.1016/S0301-9322(03)00105-8
#   → HTTP 400: XML not available
# [361/2429] DOI: 10.1016/j.molliq.2017.09.035
#   → HTTP 400: XML not available
# [362/2429] DOI: 10.1039/c9cp02397f
#   → HTTP 404: XML not available
# [363/2429] DOI: 10.1103/PhysRevLett.94.087201
#   → HTTP 404: XML not available
# [364/2429] DOI: 10.1016/j.ijhydene.2010.03.057
#   → HTTP 400: XML not available
# [365/2429] DOI: 10.1063/1.4979554
#   → HTTP 404: XML not available
# [366/2429] DOI: 10.1007/s10973-019-08617-7
#   → HTTP 404: XML not available
# [367/2429] DOI: 10.1016/j.combustflame.2005.08.038
#   → HTTP 400: XML not available
# [368/2429] DOI: 10.3938/jkps.43.747
#   → HTTP 404: XML not available
# [369/2429] DOI: 10.1088/0022-3727/40/18/037
#   → HTTP 404: XML not available
# [370/2429] DOI: 10.1017/S0022112084001555
#   → HTTP 404: XML not available
# [371/2429] DOI: 10.1016/j.ijheatmasstransfer.2012.12.016
#   → HTTP 400: XML not available
# [372/2429] DOI: 10.1016/j.ijheatmasstransfer.2014.01.069
#   → HTTP 400: XML not available
# [373/2429] DOI: 10.1080/17455030.2021.1873455
#   → HTTP 404: XML not available
# [374/2429] DOI: 10.1140/epjp/s13360-020-00599-y
#   → HTTP 404: XML not available
# [375/2429] DOI: 10.1016/j.icheatmasstransfer.2017.10.001
#   → HTTP 400: XML not available
# [376/2429] DOI: 10.1016/j.molliq.2021.116890
#   → HTTP 400: XML not available
# [377/2429] DOI: 10.1016/j.ijheatmasstransfer.2019.119072
#   → HTTP 400: XML not available
# [378/2429] DOI: 10.1115/1.1405129
#   → HTTP 404: XML not available
# [379/2429] DOI: 10.1186/1556-276X-6-184
#   → HTTP 404: XML not available
# [380/2429] DOI: 10.1016/j.ijheatmasstransfer.2016.06.100
#   → HTTP 400: XML not available
# [381/2429] DOI: 10.1016/j.icheatmasstransfer.2020.104663
#   → HTTP 400: XML not available
# [382/2429] DOI: 10.1016/j.ijheatmasstransfer.2020.120797
#   → HTTP 400: XML not available
# [383/2429] DOI: 10.1016/j.molliq.2019.111332
#   → HTTP 400: XML not available
# [384/2429] DOI: 10.1016/j.icheatmasstransfer.2018.03.024
#   → HTTP 400: XML not available
# [385/2429] DOI: 10.1016/j.ijhydene.2021.04.101
#   → HTTP 400: XML not available
# [386/2429] DOI: 10.1016/j.ijthermalsci.2013.11.017
#   → HTTP 400: XML not available
# [387/2429] DOI: 10.1016/j.mssp.2016.03.012
#   → HTTP 400: XML not available
# [388/2429] DOI: 10.1016/j.ijthermalsci.2023.108825
#   → HTTP 400: XML not available
# [389/2429] DOI: 10.1002/adem.200700331
#   → HTTP 404: XML not available
# [390/2429] DOI: 10.1016/j.icheatmasstransfer.2015.09.007
#   → HTTP 400: XML not available
# [391/2429] DOI: 10.1016/j.combustflame.2018.10.016
#   → HTTP 400: XML not available
# [392/2429] DOI: 10.1016/j.ijheatmasstransfer.2022.123449
#   → HTTP 400: XML not available
# [393/2429] DOI: 10.1016/j.icheatmasstransfer.2020.104783
#   → HTTP 400: XML not available
# [394/2429] DOI: 10.1016/j.icheatmasstransfer.2024.107293
#   → Stage 1: PASS | Keywords: ['thermal', 'temperature']
# [395/2429] DOI: 10.1016/j.molliq.2020.114975
#   → HTTP 400: XML not available
# [396/2429] DOI: 10.1016/j.ijthermalsci.2017.07.014
#   → HTTP 400: XML not available
# [397/2429] DOI: 10.1016/j.icheatmasstransfer.2013.05.009
#   → HTTP 400: XML not available
# [398/2429] DOI: 10.1088/0957-0233/21/3/035106
#   → HTTP 404: XML not available
# [399/2429] DOI: 10.1016/j.ijheatmasstransfer.2010.06.016
#   → HTTP 400: XML not available
# [400/2429] DOI: 10.1039/c7cp01755c
#   → HTTP 404: XML not available
# [401/2429] DOI: 10.1115/1.1332777
#   → HTTP 404: XML not available
# [402/2429] DOI: 10.1115/1.4023584
#   → HTTP 404: XML not available
# [403/2429] DOI: 10.1016/j.ijheatmasstransfer.2011.05.006
#   → HTTP 400: XML not available
# [404/2429] DOI: 10.1016/j.icheatmasstransfer.2023.107002
#   → HTTP 400: XML not available
# [405/2429] DOI: 10.1016/j.ijthermalsci.2012.01.009
#   → HTTP 400: XML not available
# [406/2429] DOI: 10.1016/j.molliq.2018.08.161
#   → HTTP 400: XML not available
# [407/2429] DOI: 10.1007/s10973-014-4048-0
#   → HTTP 404: XML not available
# [408/2429] DOI: 10.1016/j.jqsrt.2009.03.022
#   → HTTP 400: XML not available
# [409/2429] DOI: 10.1016/j.ijheatmasstransfer.2020.120361
#   → HTTP 400: XML not available
# [410/2429] DOI: 10.1016/j.tca.2013.01.023
#   → HTTP 400: XML not available
# [411/2429] DOI: 10.1016/j.ijheatmasstransfer.2011.02.026
#   → HTTP 400: XML not available
# [412/2429] DOI: 10.1038/s41467-017-02652-4
#   → HTTP 404: XML not available
# [413/2429] DOI: 10.1016/j.ijheatmasstransfer.2018.03.094
#   → HTTP 400: XML not available
# [414/2429] DOI: 10.1016/j.ijthermalsci.2014.06.030
#   → HTTP 400: XML not available
# [415/2429] DOI: 10.1038/s41467-024-53441-9
#   → HTTP 404: XML not available
# [416/2429] DOI: 10.1017/jfm.2017.425
#   → HTTP 404: XML not available
# [417/2429] DOI: 10.1361/10599630523764
#   → HTTP 404: XML not available
# [418/2429] DOI: 10.2514/2.6714
#   → HTTP 404: XML not available
# [419/2429] DOI: 10.1016/j.icheatmasstransfer.2023.106976
#   → HTTP 400: XML not available
# [420/2429] DOI: 10.1080/01457632.2018.1546969
#   → HTTP 404: XML not available
# [421/2429] DOI: 10.1016/j.apsusc.2016.11.221
#   → HTTP 400: XML not available
# [422/2429] DOI: 10.1007/s10973-014-4197-1
#   → HTTP 404: XML not available
# [423/2429] DOI: 10.1016/j.cis.2022.102729
#   → HTTP 400: XML not available
# [424/2429] DOI: 10.1038/s41467-024-46806-7
#   → HTTP 404: XML not available
# [425/2429] DOI: 10.1016/j.ijheatmasstransfer.2013.09.075
#   → HTTP 400: XML not available
# [426/2429] DOI: 10.1007/s10765-020-02727-3
#   → HTTP 404: XML not available
# [427/2429] DOI: 10.1016/j.molliq.2018.05.124
#   → HTTP 400: XML not available
# [428/2429] DOI: 10.1038/s41565-023-01421-3
#   → HTTP 404: XML not available
# [429/2429] DOI: 10.1016/j.ijheatmasstransfer.2020.120607
#   → HTTP 400: XML not available
# [430/2429] DOI: 10.1016/0017-9310(91)90271-F
#   → HTTP 400: XML not available
# [431/2429] DOI: 10.1016/j.ijheatmasstransfer.2013.10.077
#   → HTTP 400: XML not available
# [432/2429] DOI: 10.1007/s10973-018-7670-4
#   → HTTP 404: XML not available
# [433/2429] DOI: 10.1016/j.ijheatmasstransfer.2015.07.108
#   → HTTP 400: XML not available
# [434/2429] DOI: 10.1016/j.ijheatmasstransfer.2018.03.103
#   → HTTP 400: XML not available
# [435/2429] DOI: 10.1115/1.1839588
#   → HTTP 404: XML not available
# [436/2429] DOI: 10.1016/j.ijheatmasstransfer.2019.118842
#   → HTTP 400: XML not available
# [437/2429] DOI: 10.1007/s10854-020-04089-w
#   → HTTP 404: XML not available
# [438/2429] DOI: 10.1007/s10973-019-08062-6
#   → HTTP 404: XML not available
# [439/2429] DOI: 10.1080/01457630701850851
#   → HTTP 404: XML not available
# [440/2429] DOI: 10.1016/j.ijhydene.2014.07.088
#   → HTTP 400: XML not available
# [441/2429] DOI: nan
# [442/2429] DOI: 10.1016/j.ijheatmasstransfer.2018.06.120
#   → HTTP 400: XML not available
# [443/2429] DOI: 10.1016/j.ijheatmasstransfer.2016.03.045
#   → HTTP 400: XML not available
# [444/2429] DOI: 10.1016/j.ijhydene.2015.07.149
#   → HTTP 400: XML not available
# [445/2429] DOI: 10.1038/s41467-021-24208-3
#   → HTTP 404: XML not available
# [446/2429] DOI: 10.1016/j.ijthermalsci.2017.08.006
#   → HTTP 400: XML not available
# [447/2429] DOI: 10.1016/j.icheatmasstransfer.2022.106408
#   → HTTP 400: XML not available
# [448/2429] DOI: 10.1007/s11051-009-9657-3
#   → HTTP 404: XML not available
# [449/2429] DOI: 10.1016/j.ijheatmasstransfer.2019.118899
#   → HTTP 400: XML not available
# [450/2429] DOI: 10.1016/j.ijheatmasstransfer.2019.06.028
#   → HTTP 400: XML not available
# [451/2429] DOI: 10.1115/1.2904175
#   → HTTP 404: XML not available
# [452/2429] DOI: 10.1016/j.icheatmasstransfer.2014.08.001
#   → HTTP 400: XML not available
# [453/2429] DOI: 10.1016/j.ijheatmasstransfer.2019.118939
#   → HTTP 400: XML not available
# [454/2429] DOI: 10.1007/s00231-002-0382-z
#   → HTTP 404: XML not available
# [455/2429] DOI: 10.1149/1.3498997
#   → HTTP 404: XML not available
# [456/2429] DOI: 10.1016/j.fluid.2004.05.011
#   → HTTP 400: XML not available
# [457/2429] DOI: 10.1016/j.ijheatmasstransfer.2004.06.014
#   → HTTP 400: XML not available
# [458/2429] DOI: 10.1016/j.ijheatmasstransfer.2016.02.056
#   → HTTP 400: XML not available
# [459/2429] DOI: 10.1016/j.apacoust.2021.108126
#   → HTTP 400: XML not available
# [460/2429] DOI: 10.1016/j.ultsonch.2019.01.001
#   → Stage 1: PASS | Keywords: ['curve', 'temperature']
# [461/2429] DOI: 10.1016/j.ijthermalsci.2007.07.003
#   → HTTP 400: XML not available
# [462/2429] DOI: 10.1016/j.ijheatmasstransfer.2012.06.004
#   → HTTP 400: XML not available
# [463/2429] DOI: 10.1016/j.combustflame.2012.11.006
#   → HTTP 400: XML not available
# [464/2429] DOI: 10.1016/j.tca.2015.08.025
#   → HTTP 400: XML not available
# [465/2429] DOI: 10.1016/j.cryogenics.2019.01.005
#   → HTTP 400: XML not available
# [466/2429] DOI: 10.1063/1.4789404
#   → HTTP 404: XML not available
# [467/2429] DOI: 10.1080/10407782.2018.1505092
#   → HTTP 404: XML not available
# [468/2429] DOI: 10.1016/0017-9310(85)90119-X
#   → HTTP 400: XML not available
# [469/2429] DOI: 10.1080/00102209708935748
#   → HTTP 404: XML not available
# [470/2429] DOI: 10.1016/j.ijheatmasstransfer.2011.04.048
#   → HTTP 400: XML not available
# [471/2429] DOI: 10.1016/j.ijheatmasstransfer.2019.01.110
#   → HTTP 400: XML not available
# [472/2429] DOI: 10.1016/j.ijheatmasstransfer.2008.05.014
#   → HTTP 400: XML not available
# [473/2429] DOI: 10.1007/s10765-020-02702-y
#   → HTTP 404: XML not available
# [474/2429] DOI: 10.1016/j.cis.2012.08.001
#   → HTTP 400: XML not available
# [475/2429] DOI: 10.1016/j.ijheatmasstransfer.2017.10.090
#   → HTTP 400: XML not available
# [476/2429] DOI: 10.1016/j.ijheatmasstransfer.2013.07.085
#   → HTTP 400: XML not available
# [477/2429] DOI: 10.1016/j.ijheatmasstransfer.2016.03.129
#   → HTTP 400: XML not available
# [478/2429] DOI: 10.1016/S0017-9310(99)00339-7
#   → HTTP 400: XML not available
# [479/2429] DOI: 10.1016/j.ultsonch.2019.104701
#   → HTTP 400: XML not available
# [480/2429] DOI: 10.1016/j.ijheatmasstransfer.2017.09.109
#   → HTTP 400: XML not available
# [481/2429] DOI: 10.1016/j.cap.2008.12.047
#   → HTTP 400: XML not available
# [482/2429] DOI: 10.1016/j.molliq.2018.12.093
#   → HTTP 400: XML not available
# [483/2429] DOI: 10.1016/j.ijheatmasstransfer.2017.03.040
#   → HTTP 400: XML not available
# [484/2429] DOI: 10.1016/j.icheatmasstransfer.2014.06.009
#   → HTTP 400: XML not available
# [485/2429] DOI: 10.1016/j.ijheatmasstransfer.2018.09.097
#   → HTTP 400: XML not available
# [486/2429] DOI: 10.1016/j.molliq.2023.123727
#   → HTTP 400: XML not available
# [487/2429] DOI: 10.1016/j.icheatmasstransfer.2016.09.010
#   → HTTP 400: XML not available
# [488/2429] DOI: 10.1016/j.molliq.2019.111377
#   → HTTP 400: XML not available
# [489/2429] DOI: 10.1016/j.molliq.2019.01.137
#   → HTTP 400: XML not available
# [490/2429] DOI: 10.1016/j.molliq.2019.111613
#   → HTTP 400: XML not available
# [491/2429] DOI: 10.1115/1.2217750
#   → HTTP 404: XML not available
# [492/2429] DOI: 10.1016/j.icheatmasstransfer.2019.104333
#   → HTTP 400: XML not available
# [493/2429] DOI: 10.1115/1.1288405
#   → HTTP 404: XML not available
# [494/2429] DOI: 10.1016/0017-9310(95)00075-K
#   → HTTP 400: XML not available
# [495/2429] DOI: 10.1016/0017-9310(88)90013-0
#   → HTTP 400: XML not available
# [496/2429] DOI: 10.1016/j.ijhydene.2021.05.103
#   → HTTP 400: XML not available
# [497/2429] DOI: 10.1016/j.icheatmasstransfer.2014.02.014
#   → HTTP 400: XML not available
# [498/2429] DOI: 10.1016/S0029-5493(02)00393-X
#   → HTTP 400: XML not available
# [499/2429] DOI: 10.1115/1.1833367
#   → HTTP 404: XML not available
# [500/2429] DOI: 10.1016/j.colsurfa.2021.126562
#   → HTTP 400: XML not available
# [501/2429] DOI: 10.1016/j.ijheatmasstransfer.2022.123070
#   → Stage 1: PASS | Keywords: ['heat flux', 'thermal', 'conductivity']
# [502/2429] DOI: 10.1016/j.ijthermalsci.2022.107493
#   → HTTP 400: XML not available
# [503/2429] DOI: 10.1016/j.icheatmasstransfer.2021.105847
#   → HTTP 400: XML not available
# [504/2429] DOI: 10.1016/j.icheatmasstransfer.2014.04.010
#   → HTTP 400: XML not available
# [505/2429] DOI: 10.1615/HeatTransRes.2018025111
#   → HTTP 404: XML not available
# [506/2429] DOI: 10.1007/s10765-020-02784-8
#   → HTTP 404: XML not available
# [507/2429] DOI: 10.1016/j.ijheatmasstransfer.2006.06.044
#   → HTTP 400: XML not available
# [508/2429] DOI: 10.1016/j.molliq.2016.09.106
#   → HTTP 400: XML not available
# [509/2429] DOI: nan
# [510/2429] DOI: 10.1016/j.colsurfa.2022.129083
#   → HTTP 400: XML not available
# [511/2429] DOI: 10.1007/s11630-017-0938-3
#   → HTTP 404: XML not available
# [512/2429] DOI: 10.1016/j.ijheatmasstransfer.2013.02.060
#   → HTTP 400: XML not available
# [513/2429] DOI: 10.1016/j.tca.2014.01.009
#   → HTTP 400: XML not available
# [514/2429] DOI: 10.1016/j.ijheatmasstransfer.2024.125863
#   → HTTP 400: XML not available
# [515/2429] DOI: 10.1016/j.cryogenics.2018.02.006
#   → HTTP 400: XML not available
# [516/2429] DOI: 10.1016/j.colsurfa.2021.126167
#   → HTTP 400: XML not available
# [517/2429] DOI: 10.1016/j.ijheatmasstransfer.2023.123845
#   → HTTP 400: XML not available
# [518/2429] DOI: 10.1080/01457632.2016.1255090
#   → HTTP 404: XML not available
# [519/2429] DOI: 10.1016/j.icheatmasstransfer.2015.10.003
#   → HTTP 400: XML not available
# [520/2429] DOI: 10.1016/S0017-9310(99)00334-8
#   → HTTP 400: XML not available
# [521/2429] DOI: 10.1016/S0011-2275(99)00033-8
#   → HTTP 400: XML not available
# [522/2429] DOI: 10.1016/j.icheatmasstransfer.2022.106540
#   → HTTP 400: XML not available
# [523/2429] DOI: 10.1063/1.4894511
#   → HTTP 404: XML not available
# [524/2429] DOI: 10.1016/j.molliq.2020.112499
#   → HTTP 400: XML not available
# [525/2429] DOI: 10.1016/0017-9310(91)90230-C
#   → HTTP 400: XML not available
# [526/2429] DOI: 10.1016/j.ijheatmasstransfer.2018.11.001
#   → HTTP 400: XML not available
# [527/2429] DOI: 10.3390/app12083794
#   → HTTP 404: XML not available
# [528/2429] DOI: 10.1080/01457632.2018.1442305
#   → HTTP 404: XML not available
# [529/2429] DOI: 10.1088/2053-1583/ab097d
#   → HTTP 404: XML not available
# [530/2429] DOI: 10.1016/j.ijheatmasstransfer.2023.124853
#   → HTTP 400: XML not available
# [531/2429] DOI: 10.1016/j.icheatmasstransfer.2015.04.012
#   → HTTP 400: XML not available
# [532/2429] DOI: 10.1115/1.4049195
#   → HTTP 404: XML not available
# [533/2429] DOI: 10.1016/j.ijheatmasstransfer.2021.121502
#   → HTTP 400: XML not available
# [534/2429] DOI: 10.1016/j.icheatmasstransfer.2021.105237
#   → HTTP 400: XML not available
# [535/2429] DOI: 10.1016/j.colsurfa.2014.07.017
#   → HTTP 400: XML not available
# [536/2429] DOI: 10.1016/j.icheatmasstransfer.2023.106912
#   → HTTP 400: XML not available
# [537/2429] DOI: 10.1038/s41467-024-49936-0
#   → HTTP 404: XML not available
# [538/2429] DOI: 10.1016/j.combustflame.2007.07.002
#   → HTTP 400: XML not available
# [539/2429] DOI: 10.1016/j.combustflame.2024.113435
#   → Stage 1: PASS | Keywords: ['temperature']
# [540/2429] DOI: 10.1016/j.ijthermalsci.2021.107206
#   → HTTP 400: XML not available
# [541/2429] DOI: 10.1016/j.ijheatmasstransfer.2020.119600
#   → HTTP 400: XML not available
# [542/2429] DOI: 10.1166/jnn.2017.12695
#   → HTTP 404: XML not available
# [543/2429] DOI: 10.1007/s10765-021-02798-w
#   → HTTP 404: XML not available
# [544/2429] DOI: 10.1016/j.ijheatmasstransfer.2023.123853
#   → HTTP 400: XML not available
# [545/2429] DOI: 10.1007/s10973-019-08626-6
#   → HTTP 404: XML not available
# [546/2429] DOI: 10.1016/j.ijheatmasstransfer.2021.121322
#   → HTTP 400: XML not available
# [547/2429] DOI: 10.1080/14328917.2016.1198549
#   → HTTP 404: XML not available
# [548/2429] DOI: 10.3390/app112311203
#   → HTTP 404: XML not available
# [549/2429] DOI: 10.1007/BF00503514
#   → HTTP 404: XML not available
# [550/2429] DOI: 10.1016/j.ijheatmasstransfer.2017.07.028
#   → HTTP 400: XML not available
# [551/2429] DOI: 10.1016/0017-9310(91)90233-5
#   → HTTP 400: XML not available
# [552/2429] DOI: 10.1016/j.ijthermalsci.2021.107045
#   → HTTP 400: XML not available
# [553/2429] DOI: 10.1007/s11666-019-00836-6
#   → HTTP 404: XML not available
# [554/2429] DOI: 10.1016/j.ijheatmasstransfer.2016.10.059
#   → HTTP 400: XML not available
# [555/2429] DOI: 10.1007/s10973-022-11534-x
#   → HTTP 404: XML not available
# [556/2429] DOI: 10.1016/j.combustflame.2022.112119
#   → HTTP 400: XML not available
# [557/2429] DOI: 10.1007/s002310100258
#   → HTTP 404: XML not available
# [558/2429] DOI: 10.1017/jfm.2013.664
#   → HTTP 404: XML not available
# [559/2429] DOI: 10.1080/01411594.2019.1574010
#   → HTTP 404: XML not available
# [560/2429] DOI: 10.1016/j.icheatmasstransfer.2019.104392
#   → HTTP 400: XML not available
# [561/2429] DOI: 10.2514/2.6497
#   → HTTP 404: XML not available
# [562/2429] DOI: 10.1016/j.ijthermalsci.2019.106038
#   → HTTP 400: XML not available
# [563/2429] DOI: 10.1016/j.combustflame.2023.113020
#   → HTTP 400: XML not available
# [564/2429] DOI: 10.1016/j.ijheatmasstransfer.2024.125284
#   → HTTP 400: XML not available
# [565/2429] DOI: 10.1007/s10973-021-10756-9
#   → HTTP 404: XML not available
# [566/2429] DOI: 10.3390/app12094767
#   → HTTP 404: XML not available
# [567/2429] DOI: 10.1063/5.0186490
#   → HTTP 404: XML not available
# [568/2429] DOI: 10.1088/0957-0233/17/1/012
#   → HTTP 404: XML not available
# [569/2429] DOI: 10.1007/s00231-015-1682-4
#   → HTTP 404: XML not available
# [570/2429] DOI: 10.1016/j.ijheatmasstransfer.2013.03.020
#   → HTTP 400: XML not available
# [571/2429] DOI: 10.1016/j.ijthermalsci.2020.106632
#   → HTTP 400: XML not available
# [572/2429] DOI: 10.1007/s10973-021-10973-2
#   → HTTP 404: XML not available
# [573/2429] DOI: 10.3390/app12010329
#   → HTTP 404: XML not available
# [574/2429] DOI: 10.1016/j.icheatmasstransfer.2020.104842
#   → HTTP 400: XML not available
# [575/2429] DOI: 10.1016/j.ijthermalsci.2020.106546
#   → HTTP 400: XML not available
# [576/2429] DOI: 10.1016/j.icheatmasstransfer.2017.10.002
#   → HTTP 400: XML not available
# [577/2429] DOI: 10.1007/s00231-011-0887-4
#   → HTTP 404: XML not available
# [578/2429] DOI: 10.1007/s11630-020-1225-2
#   → HTTP 404: XML not available
# [579/2429] DOI: 10.1016/j.ultramic.2015.12.006
#   → HTTP 400: XML not available
# [580/2429] DOI: 10.3390/ma11060950
#   → HTTP 404: XML not available
# [581/2429] DOI: 10.1016/j.molliq.2023.123218
#   → HTTP 400: XML not available
# [582/2429] DOI: 10.1016/j.ijhydene.2012.02.016
#   → HTTP 400: XML not available
# [583/2429] DOI: 10.1016/j.cryogenics.2019.07.005
#   → HTTP 400: XML not available
# [584/2429] DOI: 10.1016/j.ijthermalsci.2008.11.005
#   → HTTP 400: XML not available
# [585/2429] DOI: 10.1007/s10765-024-03343-1
#   → HTTP 404: XML not available
# [586/2429] DOI: 10.1016/j.molliq.2016.08.047
#   → HTTP 400: XML not available
# [587/2429] DOI: 10.3390/ma8085246
#   → HTTP 404: XML not available
# [588/2429] DOI: 10.1016/j.ijheatmasstransfer.2024.125598
#   → Stage 1: PASS | Keywords: ['heat flux', 'thermal', 'conductivity', 'temperature']
# [589/2429] DOI: 10.1002/pssb.19660180243
#   → HTTP 404: XML not available
# [590/2429] DOI: 10.1080/18811248.1982.9734169
#   → HTTP 404: XML not available
# [591/2429] DOI: 10.1063/5.0125714
#   → HTTP 404: XML not available
# [592/2429] DOI: 10.1016/j.ijheatfluidflow.2016.11.001
#   → HTTP 400: XML not available
# [593/2429] DOI: 10.1016/j.ijheatmasstransfer.2021.121862
#   → HTTP 400: XML not available
# [594/2429] DOI: 10.1063/1.3671067
#   → HTTP 404: XML not available
# [595/2429] DOI: 10.1016/j.sna.2020.111999
#   → HTTP 400: XML not available
# [596/2429] DOI: 10.1016/j.ijheatmasstransfer.2019.119077
#   → HTTP 400: XML not available
# [597/2429] DOI: 10.1016/j.ijthermalsci.2021.107149
#   → HTTP 400: XML not available
# [598/2429] DOI: 10.1016/j.ijheatfluidflow.2019.03.008
#   → HTTP 400: XML not available
# [599/2429] DOI: 10.1007/s10973-022-11660-6
#   → HTTP 404: XML not available
# [600/2429] DOI: 10.1080/10407780600939628
#   → HTTP 404: XML not available
# ...
# [2197/2429] DOI: 10.1201/9781003509837-5
#   → HTTP 404: XML not available
# [2198/2429] DOI: 10.1016/j.ijheatmasstransfer.2025.128191
#   → HTTP 400: XML not available
# [2199/2429] DOI: nan
# [2200/2429] DOI: nan
# [2201/2429] DOI: 10.1504/IJNT.2025.152233
#   → HTTP 404: XML not available
# [2202/2429] DOI: 10.1016/j.ijthermalsci.2026.110837
#   → HTTP 400: XML not available
# [2203/2429] DOI: 10.13182/NURETH20-40289
#   → HTTP 404: XML not available
# [2204/2429] DOI: 10.1007/s00231-022-03265-4
#   → HTTP 404: XML not available
# [2205/2429] DOI: 10.13182/NUTHOS14-193
#   → HTTP 404: XML not available
# [2206/2429] DOI: 10.1115/1.4066909
#   → HTTP 404: XML not available
# [2207/2429] DOI: nan
# [2208/2429] DOI: 10.1115/1.4070521
#   → HTTP 404: XML not available
# [2209/2429] DOI: 10.1063/5.0133116
#   → HTTP 404: XML not available
# [2210/2429] DOI: 10.18462/iir.icr.2019.1278
#   → HTTP 404: XML not available
# [2211/2429] DOI: 10.1016/j.ijheatmasstransfer.2026.128625
#   → HTTP 400: XML not available
# [2212/2429] DOI: 10.18280/ijht.430505
#   → HTTP 404: XML not available
# [2213/2429] DOI: 10.1007/s10973-022-11734-5
#   → HTTP 404: XML not available
# [2214/2429] DOI: nan
# [2215/2429] DOI: 10.1063/5.0274151
#   → HTTP 404: XML not available
# [2216/2429] DOI: 10.1016/j.ijhydene.2024.11.035
#   → HTTP 400: XML not available
# [2217/2429] DOI: 10.1299/kikaib.62.3118
#   → HTTP 404: XML not available
# [2218/2429] DOI: nan
# [2219/2429] DOI: 10.3390/coatings15070777
#   → HTTP 404: XML not available
# [2220/2429] DOI: 10.1016/j.ijheatmasstransfer.2021.121888
#   → HTTP 400: XML not available
# [2221/2429] DOI: 10.1115/HT2019-3484
#   → HTTP 404: XML not available
# [2222/2429] DOI: 10.1088/1742-6596/2888/1/012013
#   → HTTP 404: XML not available
# [2223/2429] DOI: 10.1016/j.ijthermalsci.2025.110622
#   → HTTP 400: XML not available
# [2224/2429] DOI: 10.1016/j.molliq.2026.129502
#   → Stage 1: PASS | Keywords: ['thermal', 'conductivity', 'temperature']
# [2225/2429] DOI: 10.1007/s10973-025-14982-3
#   → HTTP 404: XML not available
# [2226/2429] DOI: 10.1299/kikaib.59.1712
#   → HTTP 404: XML not available
# [2227/2429] DOI: 10.1115/IPACK2025-164328
#   → HTTP 404: XML not available
# [2228/2429] DOI: nan
# [2229/2429] DOI: nan
# [2230/2429] DOI: 10.1088/1361-6463/ae4e3d
#   → HTTP 404: XML not available
# [2231/2429] DOI: 10.3390/ma19081617
#   → HTTP 404: XML not available
# [2232/2429] DOI: nan
# [2233/2429] DOI: 10.3390/fluids10110282
#   → HTTP 404: XML not available
# [2234/2429] DOI: 10.1109/RAST.2019.8767799
#   → HTTP 404: XML not available
# [2235/2429] DOI: 10.1063/5.0317543
#   → HTTP 404: XML not available
# [2236/2429] DOI: 10.1134/S0869864311010148
#   → HTTP 404: XML not available
# [2237/2429] DOI: 10.31202/ecjse.1123146
#   → HTTP 404: XML not available
# [2238/2429] DOI: 10.1016/0017-9310(72)90014-2
#   → HTTP 400: XML not available
# [2239/2429] DOI: 10.1016/j.icheatmasstransfer.2026.110773
#   → HTTP 400: XML not available
# [2240/2429] DOI: 10.1088/1742-6596/3193/1/012023
#   → HTTP 404: XML not available
# [2241/2429] DOI: nan
# [2242/2429] DOI: 10.1016/0257-8972(89)90078-9
#   → HTTP 400: XML not available
# [2243/2429] DOI: 10.1117/12.2040664
#   → HTTP 404: XML not available
# [2244/2429] DOI: 10.1615/TFEC2026.cbf.061295
#   → HTTP 404: XML not available
# [2245/2429] DOI: 10.1299/kikaib.57.604
#   → HTTP 404: XML not available
# [2246/2429] DOI: 10.1063/1.2134655
#   → HTTP 404: XML not available
# [2247/2429] DOI: 10.52202/083090-0102
#   → HTTP 404: XML not available
# [2248/2429] DOI: 10.1016/j.ijheatfluidflow.2025.110110
#   → HTTP 400: XML not available
# [2249/2429] DOI: 10.1615/ICHMT.2015.IntSympAdvComputHeatTransf.520
#   → HTTP 404: XML not available
# [2250/2429] DOI: 10.1063/5.0135781
#   → HTTP 404: XML not available
# [2251/2429] DOI: 10.1140/epjp/s13360-025-07173-4
#   → HTTP 404: XML not available
# [2252/2429] DOI: 10.1063/5.0217521
#   → HTTP 404: XML not available
# [2253/2429] DOI: 10.1615/ihtc16.cod.022811
#   → HTTP 404: XML not available
# [2254/2429] DOI: 10.1063/1.3464874
#   → HTTP 404: XML not available
# [2255/2429] DOI: 10.1038/s41467-026-69907-x
#   → HTTP 404: XML not available
# [2256/2429] DOI: 10.1007/978-981-96-6541-9_9
#   → HTTP 404: XML not available
# [2257/2429] DOI: 10.1016/j.colsurfa.2026.139836
#   → HTTP 400: XML not available
# [2258/2429] DOI: 10.1016/j.ijthermalsci.2026.110714
#   → HTTP 400: XML not available
# [2259/2429] DOI: 10.1080/08916152.2026.2624544
#   → HTTP 404: XML not available
# [2260/2429] DOI: nan
# [2261/2429] DOI: 10.1109/ITHERM.2006.1645481
#   → HTTP 404: XML not available
# [2262/2429] DOI: 10.1109/TASC.2004.830651
#   → HTTP 404: XML not available
# [2263/2429] DOI: 10.1142/S1793292025500456
#   → HTTP 404: XML not available
# [2264/2429] DOI: nan
# [2265/2429] DOI: 10.1016/j.ijthermalsci.2025.110545
#   → Stage 1: PASS | Keywords: ['heat flux', 'thermal', 'conductivity', 'temperature']
# [2266/2429] DOI: 10.1016/j.nucengdes.2013.03.035
#   → HTTP 400: XML not available
# [2267/2429] DOI: 10.2514/1.T7178
#   → HTTP 404: XML not available
# [2268/2429] DOI: 10.3390/ma18184330
#   → HTTP 404: XML not available
# [2269/2429] DOI: 10.1299/kikaib.55.2054
#   → HTTP 404: XML not available
# [2270/2429] DOI: nan
# [2271/2429] DOI: 10.1016/j.ijthermalsci.2025.110244
#   → HTTP 400: XML not available
# [2272/2429] DOI: 10.1063/5.0291751
#   → HTTP 404: XML not available
# [2273/2429] DOI: 10.1615/ihtc16.nmt.022699
#   → HTTP 404: XML not available
# [2274/2429] DOI: nan
# [2275/2429] DOI: 10.1299/kikaib.54.2905
#   → HTTP 404: XML not available
# [2276/2429] DOI: 10.1016/j.icheatmasstransfer.2026.110764
#   → HTTP 400: XML not available
# [2277/2429] DOI: nan
# [2278/2429] DOI: 10.1186/s11671-026-04602-w
#   → HTTP 404: XML not available
# [2279/2429] DOI: nan
# [2280/2429] DOI: 10.1016/j.ijthermalsci.2026.110718
#   → HTTP 400: XML not available
# [2281/2429] DOI: nan
# [2282/2429] DOI: 10.1016/j.ijthermalsci.2026.110979
#   → HTTP 400: XML not available
# [2283/2429] DOI: 10.1016/j.ijheatmasstransfer.2025.127594
#   → Stage 1: PASS | Keywords: ['nusselt', 'heat flux', 'temperature', 'thermal', 'conductivity']
# [2284/2429] DOI: nan
# [2285/2429] DOI: 10.1007/s10973-025-15188-3
#   → HTTP 404: XML not available
# [2286/2429] DOI: nan
# [2287/2429] DOI: nan
# [2288/2429] DOI: 10.1007/s10765-026-03742-6
#   → HTTP 404: XML not available
# [2289/2429] DOI: 10.1088/1742-6596/2707/1/012158
#   → HTTP 404: XML not available
# [2290/2429] DOI: 10.1063/1.5066891
#   → HTTP 404: XML not available
# [2291/2429] DOI: 10.1016/j.ijheatmasstransfer.2025.127889
#   → HTTP 400: XML not available
# [2292/2429] DOI: 10.1016/j.icheatmasstransfer.2025.109524
#   → HTTP 400: XML not available
# [2293/2429] DOI: 10.2514/3.733
#   → HTTP 404: XML not available
# [2294/2429] DOI: 10.1063/5.0033668
#   → HTTP 404: XML not available
# [2295/2429] DOI: 10.1016/j.ijmultiphaseflow.2025.105565
#   → HTTP 400: XML not available
# [2296/2429] DOI: 10.1007/s10765-025-03635-0
#   → HTTP 404: XML not available
# [2297/2429] DOI: nan
# [2298/2429] DOI: 10.1115/MNHT2008-52293
#   → HTTP 404: XML not available
# [2299/2429] DOI: nan
# [2300/2429] DOI: 10.1007/s10973-025-14907-0
#   → HTTP 404: XML not available
# [2301/2429] DOI: 10.29235/1561-2430-2021-57-1-77-84
#   → HTTP 404: XML not available
# [2302/2429] DOI: 10.1088/1742-6596/3169/1/012083
#   → HTTP 404: XML not available
# [2303/2429] DOI: 10.3103/S106287381703011X
#   → HTTP 404: XML not available
# [2304/2429] DOI: 10.1021/acs.langmuir.6c00986
#   → HTTP 404: XML not available
# [2305/2429] DOI: 10.1016/j.combustflame.2025.114707
#   → Stage 1: PASS | Keywords: ['temperature']
# [2306/2429] DOI: 10.1063/5.0279376
#   → HTTP 404: XML not available
# [2307/2429] DOI: 10.4028/p-m3KISR
#   → HTTP 404: XML not available
# [2308/2429] DOI: 10.1007/s10891-022-02491-1
#   → HTTP 404: XML not available
# [2309/2429] DOI: 10.1088/1742-6596/3175/1/012040
#   → HTTP 404: XML not available
# [2310/2429] DOI: 10.1299/kikaib.53.2181
#   → HTTP 404: XML not available
# [2311/2429] DOI: 10.1115/MNHT2008-52009
#   → HTTP 404: XML not available
# [2312/2429] DOI: 10.1007/s10891-025-03153-8
#   → HTTP 404: XML not available
# [2313/2429] DOI: 10.1007/s10891-025-03111-4
#   → HTTP 404: XML not available
# [2314/2429] DOI: 10.18462/iir.icr.2019.1308
#   → HTTP 404: XML not available
# [2315/2429] DOI: 10.1063/5.0198549
#   → HTTP 404: XML not available
# [2316/2429] DOI: 10.1016/j.icheatmasstransfer.2026.111460
#   → HTTP 400: XML not available
# [2317/2429] DOI: 10.1299/kikaib.59.2058
#   → HTTP 404: XML not available
# [2318/2429] DOI: 10.1088/1742-6596/3129/1/012054
#   → HTTP 404: XML not available
# [2319/2429] DOI: 10.4028/www.scientific.net/MSF.916.221
#   → HTTP 404: XML not available
# [2320/2429] DOI: 10.1038/s41467-025-68261-8
#   → HTTP 404: XML not available
# [2321/2429] DOI: 10.1063/5.0121306
#   → HTTP 404: XML not available
# [2322/2429] DOI: 10.1007/978-981-95-3297-1_51
#   → HTTP 404: XML not available
# [2323/2429] DOI: nan
# [2324/2429] DOI: nan
# [2325/2429] DOI: 10.1063/5.0315263
#   → HTTP 404: XML not available
# [2326/2429] DOI: 10.1088/1742-6596/2119/1/012172
#   → HTTP 404: XML not available
# [2327/2429] DOI: 10.1016/j.ijthermalsci.2026.110863
#   → HTTP 400: XML not available
# [2328/2429] DOI: 10.1007/s00231-025-03632-x
#   → HTTP 404: XML not available
# [2329/2429] DOI: 10.1063/5.0317485
#   → HTTP 404: XML not available
# [2330/2429] DOI: 10.1088/1742-6596/2893/l/012110
#   → HTTP 404: XML not available
# [2331/2429] DOI: nan
# [2332/2429] DOI: 10.1016/j.ijheatmasstransfer.2025.127967
#   → HTTP 400: XML not available
# [2333/2429] DOI: 10.1016/j.icheatmasstransfer.2026.110508
#   → HTTP 400: XML not available
# [2334/2429] DOI: 10.1063/5.0236623
#   → HTTP 404: XML not available
# [2335/2429] DOI: 10.1088/1742-6596/3113/1/012009
#   → HTTP 404: XML not available
# [2336/2429] DOI: 10.1007/BF01019537
#   → HTTP 404: XML not available
# [2337/2429] DOI: 10.1063/5.0305969
#   → HTTP 404: XML not available
# [2338/2429] DOI: 10.1117/12.3066632
#   → HTTP 404: XML not available
# [2339/2429] DOI: 10.1615/JPorMedia.2023045469
#   → HTTP 404: XML not available
# [2340/2429] DOI: 10.1016/j.ijheatmasstransfer.2026.128765
#   → Stage 1: PASS | Keywords: ['convection', 'temperature', 'curve', 'thermal', 'conductivity']
# [2341/2429] DOI: 10.1117/12.3055200
#   → HTTP 404: XML not available
# [2342/2429] DOI: 10.1016/j.cryogenics.2025.104081
#   → Stage 1: PASS | Keywords: ['curve', 'thermal', 'conductivity', 'temperature']
# [2343/2429] DOI: 10.32908/hthp.v52.1281
#   → HTTP 404: XML not available
# [2344/2429] DOI: 10.3390/sym18010035
#   → HTTP 404: XML not available
# [2345/2429] DOI: 10.1063/5.0286399
#   → HTTP 404: XML not available
# [2346/2429] DOI: nan
# [2347/2429] DOI: 10.1039/d5cp04643b
#   → HTTP 404: XML not available
# [2348/2429] DOI: 10.1016/j.ijthermalsci.2026.110687
#   → HTTP 400: XML not available
# [2349/2429] DOI: 10.1007/s10973-026-15387-6
#   → HTTP 404: XML not available
# [2350/2429] DOI: 10.1016/j.icheatmasstransfer.2026.111348
#   → HTTP 400: XML not available
# [2351/2429] DOI: nan
# [2352/2429] DOI: 10.1016/j.ijthermalsci.2026.110694
#   → HTTP 400: XML not available
# [2353/2429] DOI: 10.1016/0040-6031(93)80169-B
#   → HTTP 400: XML not available
# [2354/2429] DOI: nan
# [2355/2429] DOI: 10.1063/1.2908507
#   → HTTP 404: XML not available
# [2356/2429] DOI: 10.1088/1742-6596/3121/1/012012
#   → HTTP 404: XML not available
# [2357/2429] DOI: nan
# [2358/2429] DOI: 10.1080/01457632.2026.2614107
#   → HTTP 404: XML not available
# [2359/2429] DOI: nan
# [2360/2429] DOI: nan
# [2361/2429] DOI: nan
# [2362/2429] DOI: 10.1007/s00231-025-03624-x
#   → HTTP 404: XML not available
# [2363/2429] DOI: nan
# [2364/2429] DOI: 10.1016/j.ijheatmasstransfer.2026.128626
#   → HTTP 400: XML not available
# [2365/2429] DOI: nan
# [2366/2429] DOI: 10.1063/5.0131623
#   → HTTP 404: XML not available
# [2367/2429] DOI: 10.1016/j.ijheatmasstransfer.2025.127633
#   → Stage 1: PASS | Keywords: ['nusselt', 'temperature']
# [2368/2429] DOI: 10.1115/1.4053182
#   → HTTP 404: XML not available
# [2369/2429] DOI: 10.1016/j.cryogenics.2025.104044
#   → HTTP 400: XML not available
# [2370/2429] DOI: 10.1615/HeatTransRes.2025061208
#   → HTTP 404: XML not available
# [2371/2429] DOI: nan
# [2372/2429] DOI: 10.1007/s10973-026-15491-7
#   → HTTP 404: XML not available
# [2373/2429] DOI: 10.1115/1.4070221
#   → HTTP 404: XML not available
# [2374/2429] DOI: 10.1063/5.0093740
#   → HTTP 404: XML not available
# [2375/2429] DOI: 10.1016/j.icheatmasstransfer.2025.110364
#   → Stage 1: PASS | Keywords: ['thermal']
# [2376/2429] DOI: 10.1615/HeatTransRes.2024052479
#   → HTTP 404: XML not available
# [2377/2429] DOI: 10.1016/j.ijheatmasstransfer.2025.128262
#   → Stage 1: DROP | Keywords: []
# [2378/2429] DOI: 10.1063/5.0307165
#   → HTTP 404: XML not available
# [2379/2429] DOI: 10.1016/j.ijthermalsci.2025.110393
#   → Stage 1: PASS | Keywords: ['gradient', 'nusselt', 'temperature']
# [2380/2429] DOI: 10.1016/j.ijheatmasstransfer.2026.128894
#   → HTTP 400: XML not available
# [2381/2429] DOI: 10.1080/01457632.2026.2649996
#   → HTTP 404: XML not available
# [2382/2429] DOI: 10.1007/s00231-025-03635-8
#   → HTTP 404: XML not available
# [2383/2429] DOI: 10.1063/5.0291825
#   → HTTP 404: XML not available
# [2384/2429] DOI: 10.1002/htj.70215
#   → HTTP 404: XML not available
# [2385/2429] DOI: 10.18462/iir.cryo.2019.0079
#   → HTTP 404: XML not available
# [2386/2429] DOI: 10.1016/j.ijthermalsci.2026.110975
#   → HTTP 400: XML not available
# [2387/2429] DOI: 10.1016/j.nucengdes.2025.114693
#   → HTTP 400: XML not available
# [2388/2429] DOI: 10.1155/2010/681476
#   → HTTP 404: XML not available
# [2389/2429] DOI: 10.1088/1742-6596/2972/1/012011
#   → HTTP 404: XML not available
# [2390/2429] DOI: 10.1002/pssa.202500740
#   → HTTP 404: XML not available
# [2391/2429] DOI: nan
# [2392/2429] DOI: 10.1016/j.ijheatmasstransfer.2025.128272
#   → HTTP 400: XML not available
# [2393/2429] DOI: 10.1063/5.0303997
#   → HTTP 404: XML not available
# [2394/2429] DOI: 10.1063/1.2750939
#   → HTTP 404: XML not available
# [2395/2429] DOI: 10.1016/j.icheatmasstransfer.2025.110346
#   → HTTP 400: XML not available
# [2396/2429] DOI: 10.1615/.2014010938
#   → HTTP 404: XML not available
# [2397/2429] DOI: 10.1007/s10973-025-14604-y
#   → HTTP 404: XML not available
# [2398/2429] DOI: 10.1117/12.3026239
#   → HTTP 404: XML not available
# [2399/2429] DOI: 10.1108/eb037753
#   → HTTP 404: XML not available
# [2400/2429] DOI: 10.4028/p-85299u
#   → HTTP 404: XML not available
# [2401/2429] DOI: nan
# [2402/2429] DOI: 10.1615/TFEC2026.ess.061517
#   → HTTP 404: XML not available
# [2403/2429] DOI: 10.3390/ma17225412
#   → HTTP 404: XML not available
# [2404/2429] DOI: 10.1115/1.4071500
#   → HTTP 404: XML not available
# [2405/2429] DOI: 10.1007/s10973-025-15162-z
#   → HTTP 404: XML not available
# [2406/2429] DOI: 10.1504/IJNT.2025.152231
#   → HTTP 404: XML not available
# [2407/2429] DOI: 10.1063/5.0131840
#   → HTTP 404: XML not available
# [2408/2429] DOI: 10.1007/BF01476530
#   → HTTP 404: XML not available
# [2409/2429] DOI: 10.1115/1.2834102
#   → HTTP 404: XML not available
# [2410/2429] DOI: 10.3390/app16042093
#   → HTTP 404: XML not available
# [2411/2429] DOI: 10.17654/0973576323019
#   → HTTP 404: XML not available
# [2412/2429] DOI: 10.1016/j.ijheatmasstransfer.2026.128602
#   → Stage 1: PASS | Keywords: ['thermal', 'temperature']
# [2413/2429] DOI: 10.1007/s10854-026-16989-4
#   → HTTP 404: XML not available
# [2414/2429] DOI: 10.3390/app15179679
#   → HTTP 404: XML not available
# [2415/2429] DOI: nan
# [2416/2429] DOI: 10.1016/j.icheatmasstransfer.2025.109433
#   → HTTP 400: XML not available
# [2417/2429] DOI: nan
# [2418/2429] DOI: 10.1115/1.4003904
#   → HTTP 404: XML not available
# [2419/2429] DOI: 10.1016/j.mtphys.2025.101978
#   → HTTP 400: XML not available
# [2420/2429] DOI: nan
# [2421/2429] DOI: 10.1615/HeatTransRes.2025061270
#   → HTTP 404: XML not available
# [2422/2429] DOI: 10.1063/5.0232195
#   → HTTP 404: XML not available
# [2423/2429] DOI: 10.1039/9781782622031-00437
#   → HTTP 404: XML not available
# [2424/2429] DOI: 10.1063/5.0148806
#   → HTTP 404: XML not available
# [2425/2429] DOI: 10.1016/j.icheatmasstransfer.2025.110220
#   → HTTP 400: XML not available
# [2426/2429] DOI: 10.1063/5.0279510
#   → HTTP 404: XML not available
# [2427/2429] DOI: 10.1615/ihtc16.mtr.023719
#   → HTTP 404: XML not available
# [2428/2429] DOI: 10.1063/5.0037714
#   → HTTP 404: XML not available
# [2429/2429] DOI: 10.1063/5.0290491
#   → HTTP 404: XML not available
#
# ✓ Stage 1 complete.
#   Passed : 75
#   Dropped: 4

# %%
# ─────────────────────────────────────────────
# BLOCK 5: Stage 2 — OCR Keyword Filter
# For papers that passed Stage 1, downloads
# images TEMPORARILY (in memory only),
# runs Tesseract OCR, and scans for keywords.
# No images are saved to disk.
# ─────────────────────────────────────────────

stage2_results = []

# Only process papers that passed Stage 1
stage1_passed = df[df['stage1_status'] == 'passed_stage1']
print(f"Running Stage 2 on {len(stage1_passed)} papers...\n")

for i, row in stage1_passed.iterrows():
    figure_csv_path = os.path.join(CSV_DIR, f'output{i+1}.csv')

    if not os.path.exists(figure_csv_path):
        print(f"[{i+1}] Figure CSV not found — skipping")
        stage2_results.append({'index': i, 'stage2_status': 'no_figure_csv', 'stage2_matched_kws': ''})
        continue

    dof = pd.read_csv(figure_csv_path)
    print(f"[{i+1}] Processing {len(dof[dof['stage1_hit'] == 1])} stage-1 figures...")

    paper_matched = []

    for j, fig_row in dof[dof['stage1_hit'] == 1].iterrows():
        url = fig_row['link']
        ocr_status, text, matched = ocr_image_from_url(url, KEYWORDS)

        dof.at[j, 'stage2_ocr_status']   = ocr_status
        dof.at[j, 'stage2_ocr_text']      = text
        dof.at[j, 'stage2_keywords']      = ', '.join(matched)
        dof.at[j, 'stage2_hit']           = 1 if ocr_status == 2 else 0

        if ocr_status == 2:
            print(f"  Figure {j}: OCR MATCH — {matched}")
            paper_matched.extend(matched)

    # Save updated figure CSV with stage2 columns
    dof.to_csv(figure_csv_path, index=False)

    paper_hit = bool(paper_matched)
    status    = 'passed_stage2' if paper_hit else 'dropped_stage2'
    print(f"  → Stage 2: {'PASS' if paper_hit else 'DROP'}\n")

    stage2_results.append({
        'index':               i,
        'stage2_status':       status,
        'stage2_matched_kws':  ', '.join(set(paper_matched)),
    })

# ── Attach Stage 2 results to main dataframe ──────────────
s2_df = pd.DataFrame(stage2_results).set_index('index')
df = df.join(s2_df)

# Papers that never reached Stage 2 get a clear label
df['stage2_status']      = df['stage2_status'].fillna('not_processed_stage2')
df['stage2_matched_kws'] = df['stage2_matched_kws'].fillna('')

print(f"\n✓ Stage 2 complete.")
print(f"  Passed : {(df['stage2_status'] == 'passed_stage2').sum()}")
print(f"  Dropped: {(df['stage2_status'] == 'dropped_stage2').sum()}")
# Out:
# Running Stage 2 on 75 papers...
#
# [26] Processing 7 stage-1 figures...
#   Figure 7: OCR MATCH — ['temperature']
#   Figure 14: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [40] Processing 5 stage-1 figures...
#   Figure 3: OCR MATCH — ['thermal', 'conductivity']
#   Figure 4: OCR MATCH — ['thermal', 'conductivity']
#   Figure 5: OCR MATCH — ['thermal', 'conductivity']
#   Figure 6: OCR MATCH — ['thermal', 'conductivity']
#   Figure 7: OCR MATCH — ['thermal', 'conductivity']
#   → Stage 2: PASS
#
# [77] Processing 2 stage-1 figures...
#   Figure 2: OCR MATCH — ['thermal']
#   → Stage 2: PASS
#
# [225] Processing 6 stage-1 figures...
#   → Stage 2: DROP
#
# [250] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [292] Processing 2 stage-1 figures...
#   Figure 0: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [394] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [460] Processing 6 stage-1 figures...
#   → Stage 2: DROP
#
# [501] Processing 8 stage-1 figures...
#   Figure 9: OCR MATCH — ['thermal']
#   Figure 11: OCR MATCH — ['temperature']
#   Figure 12: OCR MATCH — ['thermal']
#   Figure 13: OCR MATCH — ['thermal', 'conductivity']
#   → Stage 2: PASS
#
# [539] Processing 9 stage-1 figures...
#   Figure 5: OCR MATCH — ['temperature']
#   Figure 6: OCR MATCH — ['temperature']
#   Figure 11: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [588] Processing 12 stage-1 figures...
#   Figure 1: OCR MATCH — ['heat flux']
#   Figure 2: OCR MATCH — ['temperature']
#   Figure 3: OCR MATCH — ['temperature']
#   Figure 4: OCR MATCH — ['temperature']
#   Figure 7: OCR MATCH — ['temperature']
#   Figure 8: OCR MATCH — ['temperature']
#   Figure 9: OCR MATCH — ['thermal', 'conductivity']
#   Figure 10: OCR MATCH — ['temperature']
#   Figure 12: OCR MATCH — ['temperature']
#   Figure 13: OCR MATCH — ['heat flux']
#   → Stage 2: PASS
#
# [620] Processing 6 stage-1 figures...
#   Figure 3: OCR MATCH — ['reynolds']
#   Figure 6: OCR MATCH — ['reynolds']
#   Figure 7: OCR MATCH — ['temperature', 'conductivity']
#   → Stage 2: PASS
#
# [623] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [644] Processing 5 stage-1 figures...
#   Figure 4: OCR MATCH — ['thermal']
#   → Stage 2: PASS
#
# [648] Processing 7 stage-1 figures...
#   Figure 3: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [715] Processing 4 stage-1 figures...
#   Figure 3: OCR MATCH — ['temperature', 'thermal']
#   Figure 14: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [735] Processing 6 stage-1 figures...
#   Figure 1: OCR MATCH — ['nusselt', 'reynolds']
#   Figure 4: OCR MATCH — ['reynolds']
#   Figure 8: OCR MATCH — ['reynolds']
#   Figure 14: OCR MATCH — ['temperature', 'thermal', 'conductivity']
#   → Stage 2: PASS
#
# [748] Processing 6 stage-1 figures...
#   Figure 11: OCR MATCH — ['nusselt']
#   Figure 13: OCR MATCH — ['nusselt']
#   Figure 14: OCR MATCH — ['thermal', 'conductivity']
#   → Stage 2: PASS
#
# [800] Processing 2 stage-1 figures...
#   Figure 5: OCR MATCH — ['thermal', 'conductivity']
#   → Stage 2: PASS
#
# [890] Processing 11 stage-1 figures...
#   Figure 4: OCR MATCH — ['temperature']
#   Figure 9: OCR MATCH — ['temperature']
#   Figure 10: OCR MATCH — ['temperature']
#   Figure 11: OCR MATCH — ['temperature']
#   Figure 13: OCR MATCH — ['temperature']
#   Figure 14: OCR MATCH — ['reynolds']
#   → Stage 2: PASS
#
# [974] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [991] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [1011] Processing 10 stage-1 figures...
#   Figure 0: OCR MATCH — ['thermal', 'conductivity']
#   Figure 1: OCR MATCH — ['thermal', 'conductivity']
#   Figure 3: OCR MATCH — ['temperature']
#   Figure 4: OCR MATCH — ['thermal', 'conductivity']
#   Figure 6: OCR MATCH — ['thermal', 'conductivity']
#   Figure 8: OCR MATCH — ['thermal', 'conductivity']
#   Figure 9: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [1018] Processing 6 stage-1 figures...
#   Figure 2: OCR MATCH — ['temperature']
#   Figure 4: OCR MATCH — ['temperature']
#   Figure 8: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [1022] Processing 7 stage-1 figures...
#   Figure 10: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [1033] Processing 3 stage-1 figures...
#   Figure 6: OCR MATCH — ['thermal']
#   → Stage 2: PASS
#
# [1039] Processing 3 stage-1 figures...
#   Figure 7: OCR MATCH — ['temperature', 'thermal', 'conductivity']
#   Figure 9: OCR MATCH — ['temperature']
#   Figure 10: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [1078] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [1080] Processing 4 stage-1 figures...
#   Figure 12: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [1160] Processing 8 stage-1 figures...
#   Figure 2: OCR MATCH — ['nusselt']
#   Figure 8: OCR MATCH — ['nusselt']
#   Figure 10: OCR MATCH — ['nusselt']
#   Figure 12: OCR MATCH — ['nusselt']
#   → Stage 2: PASS
#
# [1183] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [1190] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [1303] Processing 15 stage-1 figures...
#   → Stage 2: DROP
#
# [1318] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [1326] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [1366] Processing 4 stage-1 figures...
#   Figure 7: OCR MATCH — ['temperature', 'thermal', 'convection']
#   → Stage 2: PASS
#
# [1368] Processing 7 stage-1 figures...
#   Figure 5: OCR MATCH — ['temperature']
#   Figure 8: OCR MATCH — ['thermal']
#   Figure 9: OCR MATCH — ['temperature']
#   Figure 10: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [1384] Processing 8 stage-1 figures...
#   Figure 0: OCR MATCH — ['temperature']
#   Figure 1: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [1394] Processing 3 stage-1 figures...
#   Figure 4: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [1401] Processing 12 stage-1 figures...
#   Figure 5: OCR MATCH — ['temperature', 'thermal']
#   Figure 15: OCR MATCH — ['temperature']
#   Figure 16: OCR MATCH — ['temperature', 'thermal', 'nusselt', 'reynolds']
#   → Stage 2: PASS
#
# [1416] Processing 18 stage-1 figures...
#   Figure 2: OCR MATCH — ['thermal']
#   Figure 3: OCR MATCH — ['thermal', 'conductivity']
#   Figure 5: OCR MATCH — ['thermal']
#   Figure 10: OCR MATCH — ['heat flux']
#   Figure 16: OCR MATCH — ['temperature', 'thermal']
#   Figure 17: OCR MATCH — ['thermal']
#   Figure 19: OCR MATCH — ['thermal']
#   Figure 26: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [1429] Processing 8 stage-1 figures...
#   Figure 5: OCR MATCH — ['temperature', 'thermal', 'conductivity', 'heat flux', 'curve']
#   Figure 11: OCR MATCH — ['thermal', 'heat flux']
#   → Stage 2: PASS
#
# [1440] Processing 9 stage-1 figures...
#   Figure 2: OCR MATCH — ['conductivity']
#   → Stage 2: PASS
#
# [1459] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [1531] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [1575] Processing 7 stage-1 figures...
#   Figure 6: OCR MATCH — ['temperature']
#   Figure 7: OCR MATCH — ['temperature']
#   Figure 10: OCR MATCH — ['temperature', 'thermal', 'conductivity']
#   Figure 11: OCR MATCH — ['temperature']
#   Figure 13: OCR MATCH — ['temperature', 'thermal', 'conductivity']
#   → Stage 2: PASS
#
# [1577] Processing 8 stage-1 figures...
#   Figure 3: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [1614] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [1663] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [1704] Processing 13 stage-1 figures...
#   Figure 1: OCR MATCH — ['reynolds']
#   Figure 2: OCR MATCH — ['heat flux', 'convection']
#   Figure 5: OCR MATCH — ['heat flux', 'convection']
#   Figure 6: OCR MATCH — ['heat flux']
#   Figure 8: OCR MATCH — ['reynolds']
#   Figure 11: OCR MATCH — ['heat flux']
#   Figure 13: OCR MATCH — ['reynolds']
#   → Stage 2: PASS
#
# [1725] Processing 6 stage-1 figures...
#   Figure 14: OCR MATCH — ['thermal']
#   → Stage 2: PASS
#
# [1757] Processing 11 stage-1 figures...
#   Figure 11: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [1767] Processing 4 stage-1 figures...
#   Figure 6: OCR MATCH — ['temperature']
#   Figure 8: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [1854] Processing 7 stage-1 figures...
#   Figure 7: OCR MATCH — ['heat flux']
#   Figure 9: OCR MATCH — ['temperature']
#   Figure 10: OCR MATCH — ['temperature', 'curve']
#   Figure 13: OCR MATCH — ['heat flux']
#   → Stage 2: PASS
#
# [1893] Processing 16 stage-1 figures...
#   Figure 0: OCR MATCH — ['temperature']
#   Figure 1: OCR MATCH — ['temperature']
#   Figure 2: OCR MATCH — ['temperature']
#   Figure 5: OCR MATCH — ['temperature']
#   Figure 6: OCR MATCH — ['temperature']
#   Figure 8: OCR MATCH — ['temperature', 'thermal', 'conductivity']
#   Figure 9: OCR MATCH — ['temperature']
#   Figure 10: OCR MATCH — ['temperature']
#   Figure 11: OCR MATCH — ['temperature']
#   Figure 12: OCR MATCH — ['temperature']
#   Figure 13: OCR MATCH — ['temperature']
#   Figure 15: OCR MATCH — ['temperature', 'thermal', 'conductivity']
#   Figure 16: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [1902] Processing 8 stage-1 figures...
#   Figure 0: OCR MATCH — ['temperature']
#   Figure 1: OCR MATCH — ['thermal']
#   Figure 5: OCR MATCH — ['convection']
#   → Stage 2: PASS
#
# [1925] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [1935] Processing 7 stage-1 figures...
#   Figure 0: OCR MATCH — ['temperature']
#   Figure 6: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [1955] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [1989] Processing 7 stage-1 figures...
#   Figure 4: OCR MATCH — ['thermal']
#   Figure 9: OCR MATCH — ['thermal', 'conductivity']
#   Figure 11: OCR MATCH — ['thermal', 'conductivity']
#   → Stage 2: PASS
#
# [2019] Processing 6 stage-1 figures...
#   Figure 10: OCR MATCH — ['temperature']
#   Figure 14: OCR MATCH — ['temperature', 'thermal', 'conductivity']
#   → Stage 2: PASS
#
# [2049] Processing 10 stage-1 figures...
#   Figure 4: OCR MATCH — ['temperature']
#   Figure 8: OCR MATCH — ['temperature']
#   Figure 9: OCR MATCH — ['curve']
#   Figure 10: OCR MATCH — ['temperature']
#   Figure 11: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [2063] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [2088] Processing 10 stage-1 figures...
#   Figure 1: OCR MATCH — ['thermal', 'conductivity', 'convection']
#   Figure 6: OCR MATCH — ['temperature']
#   Figure 7: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [2121] Processing 14 stage-1 figures...
#   Figure 8: OCR MATCH — ['temperature']
#   Figure 11: OCR MATCH — ['temperature']
#   Figure 12: OCR MATCH — ['temperature']
#   Figure 13: OCR MATCH — ['temperature']
#   Figure 14: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [2224] Processing 9 stage-1 figures...
#   Figure 1: OCR MATCH — ['temperature']
#   Figure 7: OCR MATCH — ['temperature']
#   Figure 10: OCR MATCH — ['temperature']
#   Figure 12: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [2265] Processing 6 stage-1 figures...
#   Figure 2: OCR MATCH — ['temperature']
#   Figure 6: OCR MATCH — ['heat flux']
#   → Stage 2: PASS
#
# [2283] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [2305] Processing 3 stage-1 figures...
#   Figure 5: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [2340] Processing 13 stage-1 figures...
#   Figure 0: OCR MATCH — ['temperature']
#   Figure 1: OCR MATCH — ['thermal']
#   Figure 3: OCR MATCH — ['temperature', 'thermal']
#   Figure 7: OCR MATCH — ['temperature']
#   Figure 9: OCR MATCH — ['temperature']
#   Figure 14: OCR MATCH — ['temperature']
#   Figure 18: OCR MATCH — ['temperature']
#   → Stage 2: PASS
#
# [2342] Processing 6 stage-1 figures...
#   Figure 7: OCR MATCH — ['temperature']
#   Figure 9: OCR MATCH — ['temperature', 'thermal', 'conductivity', 'curve']
#   → Stage 2: PASS
#
# [2367] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [2375] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [2379] Processing 6 stage-1 figures...
#   → Stage 2: DROP
#
# [2412] Processing 4 stage-1 figures...
#   Figure 9: OCR MATCH — ['temperature', 'thermal', 'conductivity']
#   Figure 11: OCR MATCH — ['temperature', 'thermal', 'conductivity']
#   → Stage 2: PASS
#
#
# ✓ Stage 2 complete.
#   Passed : 51
#   Dropped: 24

# %%
# ─────────────────────────────────────────────
# BLOCK 6: Save Outputs
# 1. tracker.csv  — every paper with status at
#    each stage and reason for dropping
# 2. relevant_papers.csv — papers that passed
#    both stages, with full original metadata
# ─────────────────────────────────────────────

# ── Derive a single human-readable "final_status" column ──
def get_final_status(row):
    s1 = row.get('stage1_status', '')
    s2 = row.get('stage2_status', '')
    if s1 in ('no_xml', 'parse_error', 'skipped'):
        return f'dropped — {s1}'
    if s1 == 'dropped_stage1':
        return 'dropped — no caption keywords (stage 1)'
    if s2 == 'dropped_stage2':
        return 'dropped — no OCR keywords (stage 2)'
    if s2 == 'passed_stage2':
        return 'relevant'
    return 'undetermined'

df['final_status'] = df.apply(get_final_status, axis=1)

# ── tracker.csv — full picture of every paper ─────────────
tracker_cols = [
    'Authors', 'Author full names', "Author(s) ID",
    'Year', 'Cited by', 'DOI', 'Link',
    'stage1_status', 'stage1_matched_kws',
    'stage2_status', 'stage2_matched_kws',
    'final_status',
]
# Keep only columns that actually exist in df
tracker_cols = [c for c in tracker_cols if c in df.columns]
df[tracker_cols].to_csv(TRACKER_OUT, index=False)
print(f"✓ Tracker saved → {TRACKER_OUT}")

# ── relevant_papers.csv — only the papers that made it ────
relevant = df[df['final_status'] == 'relevant'].copy()
relevant.to_csv(RELEVANT_OUT, index=False)
print(f"✓ Relevant papers saved → {RELEVANT_OUT}")
print(f"\n  Total papers    : {len(df)}")
print(f"  Relevant        : {len(relevant)}")
print(f"  Dropped stage 1 : {(df['stage1_status'] == 'dropped_stage1').sum()}")
print(f"  Dropped stage 2 : {(df['stage2_status'] == 'dropped_stage2').sum()}")
print(f"  No XML / errors : {df['stage1_status'].isin(['no_xml','parse_error','skipped']).sum()}")
# Out:
# ✓ Tracker saved → /content/drive/MyDrive/final_ugp/pipeline/tracker.csv
# ✓ Relevant papers saved → /content/drive/MyDrive/final_ugp/pipeline/relevant_papers.csv
#
#   Total papers    : 2429
#   Relevant        : 51
#   Dropped stage 1 : 4
#   Dropped stage 2 : 24
#   No XML / errors : 2350
