# %%
# ─────────────────────────────────────────────
# BLOCK 1: Setup & Configuration
# Mount drive, install libraries, define keywords
# ─────────────────────────────────────────────

# Install pytesseract and tesseract-ocr
# !pip install pytesseract Pillow==9.0.0
# !sudo apt update
# !sudo apt install tesseract-ocr

from google.colab import drive
drive.mount('/content/drive')

import os
import re
import csv
import requests
import pandas as pd
import xml.etree.ElementTree as ET
from PIL import Image, ImageEnhance
import pytesseract

# ── Paths ──────────────────────────────────────────────────
INPUT_CSV     = '/content/drive/MyDrive/final_ugp/scopus.csv'          # your input file (read-only)
XML_DIR       = '/content/drive/MyDrive/final_ugp/pipeline/xmls'       # downloaded XML files
CSV_DIR       = '/content/drive/MyDrive/final_ugp/pipeline/csvs'       # per-paper figure CSVs
RELEVANT_OUT  = '/content/drive/MyDrive/final_ugp/pipeline/relevant_papers.csv'
TRACKER_OUT   = '/content/drive/MyDrive/final_ugp/pipeline/tracker.csv'

for d in [XML_DIR, CSV_DIR]:
    os.makedirs(d, exist_ok=True)

# ── Elsevier API key ───────────────────────────────────────
API_KEY = 'Your_Els_API_Key_Here'  # Replace with your actual API key

# ── Keywords to search for ─────────────────────────────────
KEYWORDS = [
    'frequency', 'amplitude', 'wavelength', 'spectrogram',
    'acoustic', 'decibel', 'hz', 'wave', 'spectrum', 'attenuation'
]

print("✓ Setup complete. Paths and keywords are ready.")
# Out:
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Requirement already satisfied: Pillow==9.0.0 in /usr/local/lib/python3.12/dist-packages (9.0.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from pytesseract) (26.1)
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 3,917 B in 1s (3,817 B/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 57 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 57 not upgraded.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✓ Setup complete. Paths and keywords are ready.

# %%
# ─────────────────────────────────────────────
# BLOCK 2: Install Tesseract OCR
# Only needs to run once per Colab session
# ─────────────────────────────────────────────

# !apt-get update -qq
# !apt-get install -y -qq tesseract-ocr libtesseract-dev
# !tesseract --version
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# tesseract 4.1.1
#  leptonica-1.82.0
#   libgif 5.1.9 : libjpeg 8d (libjpeg-turbo 2.1.1) : libpng 1.6.37 : libtiff 4.3.0 : zlib 1.2.11 : libwebp 1.2.2 : libopenjp2 2.4.0
#  Found AVX512BW
#  Found AVX512F
#  Found AVX2
#  Found AVX
#  Found FMA
#  Found SSE
#  Found libarchive 3.6.0 zlib/1.2.11 liblzma/5.2.5 bz2lib/1.0.8 liblz4/1.9.3 libzstd/1.4.8

# %%
# ─────────────────────────────────────────────
# BLOCK 3: Helper Functions
# Reusable utilities used in Stages 1 and 2
# ─────────────────────────────────────────────

def keyword_scan(text, keywords):
    """
    Checks if any keyword appears as a whole word in the given text.
    Returns (found: bool, matched_keywords: list).
    """
    if not isinstance(text, str):
        return False, []
    found_keywords = []
    for kw in keywords:
        if re.search(r'\b' + re.escape(kw) + r'\b', text, re.IGNORECASE):
            found_keywords.append(kw)
    return bool(found_keywords), found_keywords


def fetch_xml(doi, api_key):
    """
    Fetches the full-text XML for a paper from the Elsevier API.
    Returns (status_code, response_content_or_None).
    """
    url = f'https://api.elsevier.com/content/article/doi/{doi}?view=FULL'
    headers = {'X-ELS-APIKEY': api_key, 'Accept': 'text/xml'}
    try:
        r = requests.get(url, stream=True, headers=headers, timeout=30)
        return r.status_code, r if r.status_code == 200 else None
    except Exception as e:
        print(f"  [fetch_xml] Error for DOI {doi}: {e}")
        return 0, None


def parse_figures_from_xml(xml_path):
    """
    Parses an Elsevier XML file and extracts figure metadata:
    attachment EID, UCS locator, filename, and caption text.
    Returns a list of dicts.
    """
    tree = ET.parse(xml_path)
    root = tree.getroot()

    NS_CE   = {'ce':   'http://www.elsevier.com/xml/common/dtd'}
    NS_XOCS = {'xocs': 'http://www.elsevier.com/xml/xocs/dtd'}

    # --- Captions ------------------------------------------------
    captions = []
    for figure in root.findall('.//ce:figure', NS_CE):
        cap_el = figure.find('.//ce:caption', NS_CE)
        if cap_el is not None:
            sp_el = cap_el.find('.//ce:simple-para', NS_CE)
            if sp_el is not None:
                raw = ET.tostring(sp_el, encoding='unicode', method='text')
                captions.append(" ".join(re.sub('<.*?>', '', raw).split()))
            else:
                captions.append(None)
        else:
            captions.append(None)

    # --- Attachments (images) ------------------------------------
    attachments = []
    for att in root.findall('.//xocs:attachment', NS_XOCS):
        try:
            eid      = att.find('.//xocs:attachment-eid', NS_XOCS).text
            locator  = att.find('.//xocs:ucs-locator',    NS_XOCS).text
            filename = att.find('.//xocs:filename',        NS_XOCS).text
            attachments.append({'eid': eid, 'locator': locator, 'filename': filename})
        except AttributeError:
            continue  # skip malformed entries

    # --- Zip captions and attachments together -------------------
    figures = []
    for i, att in enumerate(attachments):
        caption = captions[i] if i < len(captions) else None
        link    = f"https://ars.els-cdn.com/content/image/{att['eid']}".replace('.jpg', '_lrg.jpg')
        figures.append({
            'UTD_EID':     att['eid'],
            'UCS_Locator': att['locator'],
            'Filename':    att['filename'],
            'Caption':     caption,
            'link':        link,
        })
    return figures


def ocr_image_from_url(url, keywords):
    """
    Downloads an image directly into memory, runs Tesseract OCR,
    and scans the extracted text for keywords.
    Returns (status_code, extracted_text, matched_keywords).
      status_code: 2 = keywords found, 0 = no keywords, 1 = error
    """
    try:
        response = requests.get(url, stream=True, timeout=30)
        if response.status_code != 200:
            return 1, '', []

        # Load image from bytes without saving to disk
        from io import BytesIO
        image = Image.open(BytesIO(response.content)).convert('L')
        image = ImageEnhance.Contrast(image).enhance(2)
        text  = pytesseract.image_to_string(image)

        found, matched = keyword_scan(text, keywords)
        return (2 if found else 0), text, matched

    except Exception as e:
        print(f"  [ocr_image_from_url] Error: {e}")
        return 1, '', []

print("✓ Helper functions defined.")
# Out:
# ✓ Helper functions defined.

# %%
# ─────────────────────────────────────────────
# BLOCK 4: Stage 1 — Caption Keyword Filter
# Downloads XML for each paper, parses figure
# captions, and checks for keywords.
# Does NOT save images.
# ─────────────────────────────────────────────

df_input = pd.read_csv(INPUT_CSV)

# We work on a fresh copy — original scopus.csv is never touched
df = df_input.copy()

stage1_results = []  # per-paper results for the tracker

for i, row in df.iterrows():
    doi = row.get('DOI', '')
    print(f"[{i+1}/{len(df)}] DOI: {doi}")

    if pd.isna(doi) or str(doi).strip() == '':
        stage1_results.append({'index': i, 'stage1_status': 'skipped', 'stage1_matched_kws': ''})
        continue

    # ── Fetch XML ──────────────────────────────────────────────
    status_code, response = fetch_xml(str(doi).strip(), API_KEY)

    if status_code != 200:
        print(f"  → HTTP {status_code}: XML not available")
        stage1_results.append({'index': i, 'stage1_status': 'no_xml', 'stage1_matched_kws': ''})
        continue

    # ── Save XML to disk (needed for Stage 2 parsing) ──────────
    xml_path = os.path.join(XML_DIR, f'{i+1}.xml')
    with open(xml_path, 'wb') as f:
        for chunk in response.iter_content(2048):
            f.write(chunk)

    # ── Parse figures & scan captions ─────────────────────────
    try:
        figures = parse_figures_from_xml(xml_path)
    except ET.ParseError as e:
        print(f"  → ParseError: {e}")
        stage1_results.append({'index': i, 'stage1_status': 'parse_error', 'stage1_matched_kws': ''})
        continue

    # Save per-paper figure CSV (used in Stage 2)
    figure_csv_path = os.path.join(CSV_DIR, f'output{i+1}.csv')
    pd.DataFrame(figures).to_csv(figure_csv_path, index=False)

    # Check if any caption contains a keyword
    all_matched = []
    for fig in figures:
        found, matched = keyword_scan(fig.get('Caption', ''), KEYWORDS)
        fig['stage1_hit']      = 1 if found else 0
        fig['stage1_keywords'] = ', '.join(matched)
        all_matched.extend(matched)

    # Save updated figure CSV with stage1 columns
    pd.DataFrame(figures).to_csv(figure_csv_path, index=False)

    paper_hit = bool(all_matched)
    status    = 'passed_stage1' if paper_hit else 'dropped_stage1'
    print(f"  → Stage 1: {'PASS' if paper_hit else 'DROP'} | Keywords: {list(set(all_matched))}")
    stage1_results.append({
        'index':               i,
        'stage1_status':       status,
        'stage1_matched_kws':  ', '.join(set(all_matched)),
    })

# ── Attach Stage 1 results to main dataframe ──────────────
s1_df = pd.DataFrame(stage1_results).set_index('index')
df = df.join(s1_df)

print(f"\n✓ Stage 1 complete.")
print(f"  Passed : {(df['stage1_status'] == 'passed_stage1').sum()}")
print(f"  Dropped: {(df['stage1_status'] == 'dropped_stage1').sum()}")
# Out:
# Streaming output truncated to the last 5000 lines.
#   → HTTP 404: XML not available
# [2477/5000] DOI: 10.1016/j.ultrasmedbio.2008.01.001
#   → HTTP 400: XML not available
# [2478/5000] DOI: 10.1109/ULTSYM.2009.5441472
#   → HTTP 404: XML not available
# [2479/5000] DOI: 10.1016/S0041-624X(03)00180-X
#   → HTTP 400: XML not available
# [2480/5000] DOI: 10.1016/j.ultsonch.2016.06.008
#   → HTTP 400: XML not available
# [2481/5000] DOI: 10.1016/j.ultsonch.2023.106334
#   → Stage 1: PASS | Keywords: ['acoustic', 'frequency']
# [2482/5000] DOI: 10.1016/j.ultrasmedbio.2018.03.016
#   → HTTP 400: XML not available
# [2483/5000] DOI: 10.1016/j.ultrasmedbio.2009.11.005
#   → HTTP 400: XML not available
# [2484/5000] DOI: 10.1117/12.808777
#   → HTTP 404: XML not available
# [2485/5000] DOI: 10.1063/1.4804647
#   → HTTP 404: XML not available
# [2486/5000] DOI: 10.1016/j.ultrasmedbio.2008.04.005
#   → HTTP 400: XML not available
# [2487/5000] DOI: 10.1121/1.3607196
#   → HTTP 404: XML not available
# [2488/5000] DOI: 10.1016/j.ultrasmedbio.2009.10.004
#   → HTTP 400: XML not available
# [2489/5000] DOI: 10.1016/j.ultsonch.2017.01.016
#   → HTTP 400: XML not available
# [2490/5000] DOI: 10.1016/j.ultras.2011.08.001
#   → HTTP 400: XML not available
# [2491/5000] DOI: 10.1121/1.4932166
#   → HTTP 404: XML not available
# [2492/5000] DOI: 10.1103/PhysRevB.69.174303
#   → HTTP 404: XML not available
# [2493/5000] DOI: 10.1016/j.ultrasmedbio.2022.07.016
#   → HTTP 400: XML not available
# [2494/5000] DOI: 10.1016/j.ultras.2004.01.068
#   → HTTP 400: XML not available
# [2495/5000] DOI: 10.1016/j.ultrasmedbio.2006.06.004
#   → HTTP 400: XML not available
# [2496/5000] DOI: 10.1016/j.ndteint.2005.07.002
#   → HTTP 400: XML not available
# [2497/5000] DOI: 10.1121/1.428282
#   → HTTP 404: XML not available
# [2498/5000] DOI: 10.1016/j.ultrasmedbio.2008.11.017
#   → HTTP 400: XML not available
# [2499/5000] DOI: 10.1016/j.measurement.2021.109407
#   → HTTP 400: XML not available
# [2500/5000] DOI: 10.1016/j.ndteint.2007.10.013
#   → HTTP 400: XML not available
# [2501/5000] DOI: 10.1016/j.ultras.2004.01.069
#   → HTTP 400: XML not available
# [2502/5000] DOI: 10.1016/j.ultsonch.2020.105186
#   → Stage 1: PASS | Keywords: ['spectrum']
# [2503/5000] DOI: 10.1016/j.ultras.2006.05.097
#   → HTTP 400: XML not available
# [2504/5000] DOI: 10.1109/TUFFC.2020.2972327
#   → HTTP 404: XML not available
# [2505/5000] DOI: 10.1109/TUFFC.2020.2968479
#   → HTTP 404: XML not available
# [2506/5000] DOI: 10.1016/j.ultrasmedbio.2009.05.004
#   → HTTP 400: XML not available
# [2507/5000] DOI: 10.1016/0301-5629(77)90040-0
#   → HTTP 400: XML not available
# [2508/5000] DOI: 10.1016/j.ultsonch.2021.105768
#   → Stage 1: PASS | Keywords: ['wave', 'hz', 'amplitude', 'frequency']
# [2509/5000] DOI: 10.1016/j.ultras.2012.01.005
#   → HTTP 400: XML not available
# [2510/5000] DOI: 10.1016/S0041-624X(02)00461-4
#   → HTTP 400: XML not available
# [2511/5000] DOI: 10.1016/j.ultras.2008.12.002
#   → HTTP 400: XML not available
# [2512/5000] DOI: 10.1109/TUFFC.2020.3043893
#   → HTTP 404: XML not available
# [2513/5000] DOI: 10.1088/0957-0233/2/1/010
#   → HTTP 404: XML not available
# [2514/5000] DOI: 10.1088/0022-3727/37/22/003
#   → HTTP 404: XML not available
# [2515/5000] DOI: 10.1016/j.ultsonch.2012.07.026
#   → HTTP 400: XML not available
# [2516/5000] DOI: 10.1016/0041-624X(88)90066-2
#   → HTTP 400: XML not available
# [2517/5000] DOI: 10.1117/12.462173
#   → HTTP 404: XML not available
# [2518/5000] DOI: 10.1109/TUFFC.2009.1081
#   → HTTP 404: XML not available
# [2519/5000] DOI: 10.1063/1.4804951
#   → HTTP 404: XML not available
# [2520/5000] DOI: 10.1179/014426009X12448168550064
#   → HTTP 404: XML not available
# [2521/5000] DOI: 10.1016/j.icheatmasstransfer.2019.03.002
#   → HTTP 400: XML not available
# [2522/5000] DOI: 10.1016/j.ultrasmedbio.2009.03.009
#   → HTTP 400: XML not available
# [2523/5000] DOI: 10.1143/JJAP.49.07HF18
#   → HTTP 404: XML not available
# [2524/5000] DOI: 10.1016/j.colsurfa.2006.03.031
#   → HTTP 400: XML not available
# [2525/5000] DOI: 10.1109/TUFFC.2011.2076
#   → HTTP 404: XML not available
# [2526/5000] DOI: 10.1016/j.ultras.2010.05.001
#   → HTTP 400: XML not available
# [2527/5000] DOI: 10.1016/j.ultsonch.2019.104835
#   → HTTP 400: XML not available
# [2528/5000] DOI: 10.1016/S0378-3812(02)00327-8
#   → HTTP 400: XML not available
# [2529/5000] DOI: 10.1016/j.ultrasmedbio.2008.09.006
#   → HTTP 400: XML not available
# [2530/5000] DOI: 10.1016/j.ultras.2017.09.016
#   → HTTP 400: XML not available
# [2531/5000] DOI: 10.1016/j.ultsonch.2020.105109
#   → Stage 1: PASS | Keywords: ['acoustic', 'wave', 'spectrum', 'frequency']
# [2532/5000] DOI: 10.1016/j.ultsonch.2012.10.013
#   → HTTP 400: XML not available
# [2533/5000] DOI: 10.1063/5.0143762
#   → HTTP 404: XML not available
# [2534/5000] DOI: 10.1121/1.4812879
#   → HTTP 404: XML not available
# [2535/5000] DOI: 10.1109/TUFFC.2010.1403
#   → HTTP 404: XML not available
# [2536/5000] DOI: 10.1109/TUFFC.2019.2953190
#   → HTTP 404: XML not available
# [2537/5000] DOI: 10.1016/j.ultras.2003.12.008
#   → HTTP 400: XML not available
# [2538/5000] DOI: 10.1121/1.1578080
#   → HTTP 404: XML not available
# [2539/5000] DOI: 10.1016/j.ultsonch.2024.107163
#   → Stage 1: PASS | Keywords: ['acoustic', 'frequency']
# [2540/5000] DOI: 10.1117/12.620374
#   → HTTP 404: XML not available
# [2541/5000] DOI: 10.1016/j.ultrasmedbio.2007.12.019
#   → HTTP 400: XML not available
# [2542/5000] DOI: 10.3390/s21175962
#   → HTTP 404: XML not available
# [2543/5000] DOI: 10.1063/1.1471579
#   → HTTP 404: XML not available
# [2544/5000] DOI: 10.1021/nn300768d
#   → HTTP 404: XML not available
# [2545/5000] DOI: 10.1109/TUFFC.2012.2442
#   → HTTP 404: XML not available
# [2546/5000] DOI: 10.1016/j.ultras.2008.09.010
#   → HTTP 400: XML not available
# [2547/5000] DOI: 10.1109/TUFFC.887
#   → HTTP 404: XML not available
# [2548/5000] DOI: 10.1016/0301-5629(81)90037-5
#   → HTTP 400: XML not available
# [2549/5000] DOI: 10.1016/j.ultsonch.2022.105930
#   → Stage 1: PASS | Keywords: ['acoustic']
# [2550/5000] DOI: 10.1109/ULTSYM.2009.5441662
#   → HTTP 404: XML not available
# [2551/5000] DOI: 10.1121/1.2532113
#   → HTTP 404: XML not available
# [2552/5000] DOI: 10.1063/1.2743947
#   → HTTP 404: XML not available
# [2553/5000] DOI: 10.1007/s10765-010-0791-z
#   → HTTP 404: XML not available
# [2554/5000] DOI: 10.1364/AO.54.007508
#   → HTTP 404: XML not available
# [2555/5000] DOI: 10.1109/TUFFC.2009.1352
#   → HTTP 404: XML not available
# [2556/5000] DOI: 10.1103/PhysRev.184.466
#   → HTTP 404: XML not available
# [2557/5000] DOI: 10.1016/j.ultras.2008.10.009
#   → HTTP 400: XML not available
# [2558/5000] DOI: 10.1016/j.ultrasmedbio.2008.03.019
#   → HTTP 400: XML not available
# [2559/5000] DOI: 10.1063/1.2945882
#   → HTTP 404: XML not available
# [2560/5000] DOI: 10.1109/ULTSYM.2008.0174
#   → HTTP 404: XML not available
# [2561/5000] DOI: 10.1016/j.ultsonch.2014.10.008
#   → Stage 1: PASS | Keywords: ['acoustic']
# [2562/5000] DOI: 10.1109/TUFFC.2007.271
#   → HTTP 404: XML not available
# [2563/5000] DOI: 10.1016/j.ultsonch.2018.05.037
#   → Stage 1: PASS | Keywords: ['amplitude']
# [2564/5000] DOI: 10.1016/j.ultsonch.2010.02.009
#   → HTTP 400: XML not available
# [2565/5000] DOI: 10.1103/PhysRevE.71.056618
#   → HTTP 404: XML not available
# [2566/5000] DOI: 10.1016/j.ultrasmedbio.2009.06.1096
#   → HTTP 400: XML not available
# [2567/5000] DOI: 10.1121/1.4895681
#   → HTTP 404: XML not available
# [2568/5000] DOI: 10.1016/j.ultras.2008.03.001
#   → HTTP 400: XML not available
# [2569/5000] DOI: 10.1002/pssb.201600077
#   → HTTP 404: XML not available
# [2570/5000] DOI: 10.1080/14786435.2013.789144
#   → HTTP 404: XML not available
# [2571/5000] DOI: 10.1016/j.ndteint.2009.09.004
#   → HTTP 400: XML not available
# [2572/5000] DOI: 10.1016/j.ultsonch.2023.106492
#   → Stage 1: PASS | Keywords: ['frequency']
# [2573/5000] DOI: 10.1016/j.ultrasmedbio.2012.01.005
#   → HTTP 400: XML not available
# [2574/5000] DOI: 10.1016/j.ultrasmedbio.2016.08.006
#   → HTTP 400: XML not available
# [2575/5000] DOI: 10.1039/c3cp55088e
#   → HTTP 404: XML not available
# [2576/5000] DOI: 10.1016/j.ultras.2008.05.003
#   → HTTP 400: XML not available
# [2577/5000] DOI: 10.1109/TIM.2009.2012936
#   → HTTP 404: XML not available
# [2578/5000] DOI: 10.1016/j.sna.2010.03.020
#   → HTTP 400: XML not available
# [2579/5000] DOI: 10.1016/j.ultrasmedbio.2006.07.039
#   → HTTP 400: XML not available
# [2580/5000] DOI: 10.1063/1.3665646
#   → HTTP 404: XML not available
# [2581/5000] DOI: 10.1080/00319100802706691
#   → HTTP 404: XML not available
# [2582/5000] DOI: 10.1016/j.ultsonch.2018.01.012
#   → Stage 1: PASS | Keywords: ['wave', 'amplitude']
# [2583/5000] DOI: 10.1163/092764409X12477425232217
#   → HTTP 404: XML not available
# [2584/5000] DOI: 10.1016/j.ultrasmedbio.2015.05.021
#   → HTTP 400: XML not available
# [2585/5000] DOI: 10.1016/j.ultrasmedbio.2003.08.005
#   → HTTP 400: XML not available
# [2586/5000] DOI: 10.1016/j.ultras.2009.08.008
#   → HTTP 400: XML not available
# [2587/5000] DOI: 10.1109/ULTSYM.2004.1417726
#   → HTTP 404: XML not available
# [2588/5000] DOI: 10.1016/j.ultras.2012.05.004
#   → HTTP 400: XML not available
# [2589/5000] DOI: 10.1364/OE.25.008022
#   → HTTP 404: XML not available
# [2590/5000] DOI: 10.1121/1.387336
#   → HTTP 404: XML not available
# [2591/5000] DOI: 10.1103/PhysRevLett.101.074505
#   → HTTP 404: XML not available
# [2592/5000] DOI: 10.1121/1.2346132
#   → HTTP 404: XML not available
# [2593/5000] DOI: 10.1016/j.ultras.2003.12.001
#   → HTTP 400: XML not available
# [2594/5000] DOI: 10.1143/JJAP.34.2584
#   → HTTP 404: XML not available
# [2595/5000] DOI: 10.1016/j.ultrasmedbio.2020.07.032
#   → HTTP 400: XML not available
# [2596/5000] DOI: 10.1163/092764409X12477481859067
#   → HTTP 404: XML not available
# [2597/5000] DOI: 10.1121/1.2874557
#   → HTTP 404: XML not available
# [2598/5000] DOI: 10.1109/TUFFC.2004.1304274
#   → HTTP 404: XML not available
# [2599/5000] DOI: 10.1121/1.1849960
#   → HTTP 404: XML not available
# [2600/5000] DOI: 10.1121/1.4843175
#   → HTTP 404: XML not available
# [2601/5000] DOI: 10.1016/j.measurement.2008.05.004
#   → HTTP 400: XML not available
# [2602/5000] DOI: 10.1016/j.ultras.2011.07.007
#   → HTTP 400: XML not available
# [2603/5000] DOI: 10.1016/j.ultrasmedbio.2012.11.019
#   → HTTP 400: XML not available
# [2604/5000] DOI: 10.1121/10.0003930
#   → HTTP 404: XML not available
# [2605/5000] DOI: 10.1063/1.3259371
#   → HTTP 404: XML not available
# [2606/5000] DOI: 10.1364/AO.53.002366
#   → HTTP 404: XML not available
# [2607/5000] DOI: 10.1121/1.4864475
#   → HTTP 404: XML not available
# [2608/5000] DOI: 10.1021/acs.langmuir.2c01061
#   → HTTP 404: XML not available
# [2609/5000] DOI: 10.1016/0301-5629(91)90186-Z
#   → HTTP 400: XML not available
# [2610/5000] DOI: 10.1109/ULTSYM.2010.5935971
#   → HTTP 404: XML not available
# [2611/5000] DOI: 10.1016/j.sna.2005.08.033
#   → HTTP 400: XML not available
# [2612/5000] DOI: 10.1109/TUFFC.2020.3039743
#   → HTTP 404: XML not available
# [2613/5000] DOI: 10.1109/JLT.2010.2078489
#   → HTTP 404: XML not available
# [2614/5000] DOI: 10.1016/j.ultras.2009.10.001
#   → HTTP 400: XML not available
# [2615/5000] DOI: 10.1109/TUFFC.2003.1256310
#   → HTTP 404: XML not available
# [2616/5000] DOI: 10.1121/1.1289920
#   → HTTP 404: XML not available
# [2617/5000] DOI: 10.1016/j.apacoust.2008.10.005
#   → HTTP 400: XML not available
# [2618/5000] DOI: nan
# [2619/5000] DOI: 10.1016/j.ultrasmedbio.2011.04.005
#   → HTTP 400: XML not available
# [2620/5000] DOI: 10.1016/j.ultrasmedbio.2008.07.003
#   → HTTP 400: XML not available
# [2621/5000] DOI: 10.1121/1.400713
#   → HTTP 404: XML not available
# [2622/5000] DOI: 10.1016/j.ultrasmedbio.2013.11.015
#   → HTTP 400: XML not available
# [2623/5000] DOI: 10.1121/1.3455795
#   → HTTP 404: XML not available
# [2624/5000] DOI: 10.1016/j.ultras.2014.07.009
#   → HTTP 400: XML not available
# [2625/5000] DOI: 10.1143/jjap.40.3623
#   → HTTP 404: XML not available
# [2626/5000] DOI: 10.1143/JJAP.48.07GL04
#   → HTTP 404: XML not available
# [2627/5000] DOI: 10.1016/j.ndteint.2019.102170
#   → HTTP 400: XML not available
# [2628/5000] DOI: 10.1016/j.ultsonch.2011.03.007
#   → HTTP 400: XML not available
# [2629/5000] DOI: 10.1016/j.ultrasmedbio.2008.09.004
#   → HTTP 400: XML not available
# [2630/5000] DOI: 10.1016/j.ultras.2021.106363
#   → HTTP 400: XML not available
# [2631/5000] DOI: 10.1016/j.ultras.2006.05.073
#   → HTTP 400: XML not available
# [2632/5000] DOI: 10.1063/1.1767277
#   → HTTP 404: XML not available
# [2633/5000] DOI: 10.1016/j.pepi.2013.11.009
#   → HTTP 400: XML not available
# [2634/5000] DOI: 10.1002/adfm.202203109
#   → HTTP 404: XML not available
# [2635/5000] DOI: 10.1016/j.ultsonch.2016.11.003
#   → HTTP 400: XML not available
# [2636/5000] DOI: 10.1121/1.5083828
#   → HTTP 404: XML not available
# [2637/5000] DOI: 10.1121/1.2764475
#   → HTTP 404: XML not available
# [2638/5000] DOI: 10.1109/TUFFC.2005.1561677
#   → HTTP 404: XML not available
# [2639/5000] DOI: nan
# [2640/5000] DOI: 10.1109/58.990954
#   → HTTP 404: XML not available
# [2641/5000] DOI: 10.1063/1.3050340
#   → HTTP 404: XML not available
# [2642/5000] DOI: 10.1007/s12598-016-0694-7
#   → HTTP 404: XML not available
# [2643/5000] DOI: 10.1117/12.483801
#   → HTTP 404: XML not available
# [2644/5000] DOI: 10.1080/00319109908045122
#   → HTTP 404: XML not available
# [2645/5000] DOI: 10.1016/0301-5629(95)00028-P
#   → HTTP 400: XML not available
# [2646/5000] DOI: 10.1016/S0041-624X(00)00015-9
#   → HTTP 400: XML not available
# [2647/5000] DOI: 10.1109/MEMS51782.2021.9375135
#   → HTTP 404: XML not available
# [2648/5000] DOI: 10.1121/1.1373446
#   → HTTP 404: XML not available
# [2649/5000] DOI: 10.1115/1.4027752
#   → HTTP 404: XML not available
# [2650/5000] DOI: 10.1016/j.ultrasmedbio.2008.10.008
#   → HTTP 400: XML not available
# [2651/5000] DOI: 10.1121/1.380582
#   → HTTP 404: XML not available
# [2652/5000] DOI: 10.1016/j.ultsonch.2019.104679
#   → HTTP 400: XML not available
# [2653/5000] DOI: 10.1016/j.ultrasmedbio.2017.06.024
#   → HTTP 400: XML not available
# [2654/5000] DOI: 10.1115/1.4030731
#   → HTTP 404: XML not available
# [2655/5000] DOI: 10.1109/58.294114
#   → HTTP 404: XML not available
# [2656/5000] DOI: 10.1121/1.3087428
#   → HTTP 404: XML not available
# [2657/5000] DOI: 10.1109/LPT.2015.2421350
#   → HTTP 404: XML not available
# [2658/5000] DOI: 10.1109/ULTSYM.2010.5935824
#   → HTTP 404: XML not available
# [2659/5000] DOI: 10.1016/j.ultsonch.2017.04.004
#   → Stage 1: PASS | Keywords: ['spectrum']
# [2660/5000] DOI: 10.1103/PhysRevB.76.024311
#   → HTTP 404: XML not available
# [2661/5000] DOI: 10.1109/JDT.2009.2027612
#   → HTTP 404: XML not available
# [2662/5000] DOI: 10.1117/12.704240
#   → HTTP 404: XML not available
# [2663/5000] DOI: 10.1155/2012/376047
#   → HTTP 404: XML not available
# [2664/5000] DOI: 10.1109/58.990941
#   → HTTP 404: XML not available
# [2665/5000] DOI: 10.1016/j.ultras.2020.106210
#   → HTTP 400: XML not available
# [2666/5000] DOI: 10.1109/ULTSYM.2010.5935667
#   → HTTP 404: XML not available
# [2667/5000] DOI: 10.1016/0301-5629(81)90051-X
#   → HTTP 400: XML not available
# [2668/5000] DOI: 10.1121/1.1911265
#   → HTTP 404: XML not available
# [2669/5000] DOI: 10.1016/j.ultras.2010.11.010
#   → HTTP 400: XML not available
# [2670/5000] DOI: 10.1016/j.ijrobp.2009.01.061
#   → HTTP 400: XML not available
# [2671/5000] DOI: 10.1016/j.matlet.2020.127692
#   → HTTP 400: XML not available
# [2672/5000] DOI: 10.1134/S1063771009040198
#   → HTTP 404: XML not available
# [2673/5000] DOI: 10.1016/j.ultrasmedbio.2004.07.008
#   → HTTP 400: XML not available
# [2674/5000] DOI: 10.1016/j.ultrasmedbio.2011.05.020
#   → HTTP 400: XML not available
# [2675/5000] DOI: 10.1121/1.3630219
#   → HTTP 404: XML not available
# [2676/5000] DOI: 10.1016/j.ultras.2017.03.018
#   → HTTP 400: XML not available
# [2677/5000] DOI: 10.1016/S0301-5629(03)00907-4
#   → HTTP 400: XML not available
# [2678/5000] DOI: 10.1016/j.ultras.2015.06.016
#   → HTTP 400: XML not available
# [2679/5000] DOI: 10.1016/0301-5629(91)90184-X
#   → HTTP 400: XML not available
# [2680/5000] DOI: 10.1143/JJAP.47.4127
#   → HTTP 404: XML not available
# [2681/5000] DOI: 10.1002/ppsc.201600277
#   → HTTP 404: XML not available
# [2682/5000] DOI: 10.1117/1.3491113
#   → HTTP 404: XML not available
# [2683/5000] DOI: 10.1143/JJAP.47.4354
#   → HTTP 404: XML not available
# [2684/5000] DOI: 10.1016/0301-5629(94)90109-0
#   → HTTP 400: XML not available
# [2685/5000] DOI: 10.1016/j.ultras.2022.106911
#   → HTTP 400: XML not available
# [2686/5000] DOI: 10.1016/j.msec.2019.109749
#   → HTTP 400: XML not available
# [2687/5000] DOI: 10.1121/1.3662048
#   → HTTP 404: XML not available
# [2688/5000] DOI: 10.1016/j.ultras.2004.07.001
#   → HTTP 400: XML not available
# [2689/5000] DOI: 10.1063/1.4730943
#   → HTTP 404: XML not available
# [2690/5000] DOI: 10.1016/j.ultrasmedbio.2012.02.017
#   → HTTP 400: XML not available
# [2691/5000] DOI: 10.1016/j.isatra.2011.07.004
#   → HTTP 400: XML not available
# [2692/5000] DOI: 10.1121/1.4979695
#   → HTTP 404: XML not available
# [2693/5000] DOI: 10.1016/j.ultrasmedbio.2006.10.008
#   → HTTP 400: XML not available
# [2694/5000] DOI: 10.1109/TUFFC.2004.1386688
#   → HTTP 404: XML not available
# [2695/5000] DOI: 10.1109/TUFFC.2017.2682180
#   → HTTP 404: XML not available
# [2696/5000] DOI: 10.1016/j.ultras.2018.06.016
#   → HTTP 400: XML not available
# [2697/5000] DOI: 10.1016/j.matlet.2012.03.052
#   → HTTP 400: XML not available
# [2698/5000] DOI: 10.1016/S0301-5629(98)00121-5
#   → HTTP 400: XML not available
# [2699/5000] DOI: 10.1016/j.pacs.2022.100439
#   → Stage 1: PASS | Keywords: ['spectrum', 'wave', 'hz', 'frequency']
# [2700/5000] DOI: 10.1016/j.ultras.2021.106548
#   → HTTP 400: XML not available
# [2701/5000] DOI: 10.1117/12.813879
#   → HTTP 404: XML not available
# [2702/5000] DOI: 10.1016/S0041-624X(02)00449-3
#   → HTTP 400: XML not available
# [2703/5000] DOI: 10.1016/j.measurement.2010.09.021
#   → HTTP 400: XML not available
# [2704/5000] DOI: 10.1007/BF00504003
#   → HTTP 404: XML not available
# [2705/5000] DOI: 10.1016/0041-624X(95)00051-4
#   → HTTP 400: XML not available
# [2706/5000] DOI: 10.1121/1.396060
#   → HTTP 404: XML not available
# [2707/5000] DOI: 10.1016/j.ultrasmedbio.2018.04.017
#   → HTTP 400: XML not available
# [2708/5000] DOI: 10.1364/BOE.8.002245
#   → HTTP 404: XML not available
# [2709/5000] DOI: 10.1016/j.ultrasmedbio.2008.06.005
#   → HTTP 400: XML not available
# [2710/5000] DOI: 10.1109/TUFFC.2020.3008179
#   → HTTP 404: XML not available
# [2711/5000] DOI: 10.1016/j.ultras.2014.01.011
#   → HTTP 400: XML not available
# [2712/5000] DOI: 10.1088/1361-665X/ab6fe5
#   → HTTP 404: XML not available
# [2713/5000] DOI: 10.1109/ULTSYM.2007.131
#   → HTTP 404: XML not available
# [2714/5000] DOI: 10.1016/j.ultsonch.2012.09.015
#   → HTTP 400: XML not available
# [2715/5000] DOI: 10.1038/s41467-024-51620-2
#   → HTTP 404: XML not available
# [2716/5000] DOI: 10.1063/1.4863691
#   → HTTP 404: XML not available
# [2717/5000] DOI: 10.1143/jjap.36.6069
#   → HTTP 404: XML not available
# [2718/5000] DOI: 10.1016/j.ultrasmedbio.2008.03.013
#   → HTTP 400: XML not available
# [2719/5000] DOI: 10.1121/1.403713
#   → HTTP 404: XML not available
# [2720/5000] DOI: 10.1016/j.ultras.2018.08.008
#   → HTTP 400: XML not available
# [2721/5000] DOI: 10.7567/JJAP.52.07HF15
#   → HTTP 404: XML not available
# [2722/5000] DOI: 10.1121/1.399079
#   → HTTP 404: XML not available
# [2723/5000] DOI: 10.1063/5.0010842
#   → HTTP 404: XML not available
# [2724/5000] DOI: 10.1016/j.ultras.2004.01.029
#   → HTTP 400: XML not available
# [2725/5000] DOI: 10.1016/j.microrel.2003.09.004
#   → HTTP 400: XML not available
# [2726/5000] DOI: 10.1016/j.ultsonch.2023.106529
#   → Stage 1: PASS | Keywords: ['frequency']
# [2727/5000] DOI: 10.1016/j.ultsonch.2016.11.033
#   → HTTP 400: XML not available
# [2728/5000] DOI: 10.1016/j.ultrasmedbio.2013.03.006
#   → HTTP 400: XML not available
# [2729/5000] DOI: 10.1121/1.2739803
#   → HTTP 404: XML not available
# [2730/5000] DOI: 10.1016/j.ultras.2009.10.004
#   → HTTP 400: XML not available
# [2731/5000] DOI: 10.1121/1.428508
#   → HTTP 404: XML not available
# [2732/5000] DOI: 10.1109/ULTSYM.2018.8579709
#   → HTTP 404: XML not available
# [2733/5000] DOI: 10.1016/j.jnnfm.2010.04.010
#   → HTTP 400: XML not available
# [2734/5000] DOI: 10.1109/TUFFC.2018.2841848
#   → HTTP 404: XML not available
# [2735/5000] DOI: 10.1109/TUFFC.2008.789
#   → HTTP 404: XML not available
# [2736/5000] DOI: 10.1109/TUFFC.2008.871
#   → HTTP 404: XML not available
# [2737/5000] DOI: 10.1021/acs.langmuir.8b03288
#   → HTTP 404: XML not available
# [2738/5000] DOI: 10.1002/mop.31061
#   → HTTP 404: XML not available
# [2739/5000] DOI: 10.1121/1.4789390
#   → HTTP 404: XML not available
# [2740/5000] DOI: 10.1016/j.ijheatmasstransfer.2012.07.028
#   → HTTP 400: XML not available
# [2741/5000] DOI: 10.1016/j.ultrasmedbio.2010.10.010
#   → HTTP 400: XML not available
# [2742/5000] DOI: 10.1016/j.ultsonch.2021.105734
#   → Stage 1: PASS | Keywords: ['amplitude']
# [2743/5000] DOI: 10.1016/j.optlastec.2022.108758
#   → HTTP 400: XML not available
# [2744/5000] DOI: 10.1016/j.ultras.2009.01.001
#   → HTTP 400: XML not available
# [2745/5000] DOI: 10.1121/1.5063578
#   → HTTP 404: XML not available
# [2746/5000] DOI: 10.1016/j.ultrasmedbio.2008.08.013
#   → HTTP 400: XML not available
# [2747/5000] DOI: 10.1088/0957-0233/17/8/037
#   → HTTP 404: XML not available
# [2748/5000] DOI: 10.1016/j.ultras.2009.05.001
#   → HTTP 400: XML not available
# [2749/5000] DOI: 10.1016/j.ultsonch.2023.106669
#   → Stage 1: PASS | Keywords: ['acoustic']
# [2750/5000] DOI: 10.1016/j.ultras.2020.106205
#   → HTTP 400: XML not available
# [2751/5000] DOI: 10.1121/1.1480417
#   → HTTP 404: XML not available
# [2752/5000] DOI: 10.1088/0957-0233/15/5/023
#   → HTTP 404: XML not available
# [2753/5000] DOI: 10.1109/TUFFC.2008.861
#   → HTTP 404: XML not available
# [2754/5000] DOI: 10.1070/QEL17538
#   → HTTP 404: XML not available
# [2755/5000] DOI: 10.1016/j.ultsonch.2022.106091
#   → Stage 1: DROP | Keywords: []
# [2756/5000] DOI: 10.1109/TUFFC.2021.3059715
#   → HTTP 404: XML not available
# [2757/5000] DOI: 10.1063/1.3142478
#   → HTTP 404: XML not available
# [2758/5000] DOI: 10.1063/1.3490788
#   → HTTP 404: XML not available
# [2759/5000] DOI: 10.1016/S0921-5093(01)01357-0
#   → HTTP 400: XML not available
# [2760/5000] DOI: nan
# [2761/5000] DOI: 10.1121/1.1652131
#   → HTTP 404: XML not available
# [2762/5000] DOI: 10.1117/1.JBO.22.4.041014
#   → HTTP 404: XML not available
# [2763/5000] DOI: 10.1016/j.ultsonch.2023.106721
#   → Stage 1: PASS | Keywords: ['attenuation', 'acoustic']
# [2764/5000] DOI: 10.1016/j.apacoust.2018.03.021
#   → HTTP 400: XML not available
# [2765/5000] DOI: 10.1109/TUFFC.2017.2778509
#   → HTTP 404: XML not available
# [2766/5000] DOI: 10.1016/j.ultras.2006.05.002
#   → HTTP 400: XML not available
# [2767/5000] DOI: 10.1109/TUFFC.2009.1160
#   → HTTP 404: XML not available
# [2768/5000] DOI: 10.1016/j.ultrasmedbio.2011.05.023
#   → HTTP 400: XML not available
# [2769/5000] DOI: 10.1016/j.ultras.2010.03.004
#   → HTTP 400: XML not available
# [2770/5000] DOI: 10.1063/1.2150257
#   → HTTP 404: XML not available
# [2771/5000] DOI: 10.1063/1.4951008
#   → HTTP 404: XML not available
# [2772/5000] DOI: 10.1016/0041-624X(85)90062-9
#   → HTTP 400: XML not available
# [2773/5000] DOI: 10.1364/OE.26.021700
#   → HTTP 404: XML not available
# [2774/5000] DOI: 10.1016/j.ultrasmedbio.2007.05.013
#   → HTTP 400: XML not available
# [2775/5000] DOI: 10.1016/j.molliq.2011.02.009
#   → HTTP 400: XML not available
# [2776/5000] DOI: 10.1121/1.2714920
#   → HTTP 404: XML not available
# [2777/5000] DOI: 10.1143/JJAP.49.07HF16
#   → HTTP 404: XML not available
# [2778/5000] DOI: 10.1016/j.tca.2004.05.016
#   → HTTP 400: XML not available
# [2779/5000] DOI: 10.1016/j.jsv.2010.09.032
#   → HTTP 400: XML not available
# [2780/5000] DOI: 10.1016/j.ultras.2009.09.002
#   → HTTP 400: XML not available
# [2781/5000] DOI: 10.1121/1.1289365
#   → HTTP 404: XML not available
# [2782/5000] DOI: 10.1109/ULTSYM.2010.5935789
#   → HTTP 404: XML not available
# [2783/5000] DOI: 10.1016/j.ultsonch.2023.106343
#   → Stage 1: PASS | Keywords: ['acoustic', 'spectrum', 'frequency']
# [2784/5000] DOI: 10.1016/S1350-4177(02)00074-3
#   → HTTP 400: XML not available
# [2785/5000] DOI: 10.1016/S0921-4526(02)00512-4
#   → HTTP 400: XML not available
# [2786/5000] DOI: 10.1016/0301-5629(92)90011-X
#   → HTTP 400: XML not available
# [2787/5000] DOI: 10.1016/S0301-5629(98)00019-2
#   → HTTP 400: XML not available
# [2788/5000] DOI: 10.1063/1.2403236
#   → HTTP 404: XML not available
# [2789/5000] DOI: 10.1121/1.2828210
#   → HTTP 404: XML not available
# [2790/5000] DOI: 10.1109/TUFFC.2020.3019573
#   → HTTP 404: XML not available
# [2791/5000] DOI: 10.1109/ULTSYM.2007.181
#   → HTTP 404: XML not available
# [2792/5000] DOI: 10.1109/TUFFC.2011.2114
#   → HTTP 404: XML not available
# [2793/5000] DOI: 10.1121/1.2957931
#   → HTTP 404: XML not available
# [2794/5000] DOI: 10.1016/j.ultrasmedbio.2009.01.008
#   → HTTP 400: XML not available
# [2795/5000] DOI: 10.1016/j.ultrasmedbio.2009.03.006
#   → HTTP 400: XML not available
# [2796/5000] DOI: 10.1121/1.3377061
#   → HTTP 404: XML not available
# [2797/5000] DOI: 10.1109/TUFFC.2006.1611034
#   → HTTP 404: XML not available
# [2798/5000] DOI: 10.1016/j.ijthermalsci.2012.06.007
#   → HTTP 400: XML not available
# [2799/5000] DOI: 10.1016/j.ultsonch.2021.105764
#   → Stage 1: PASS | Keywords: ['acoustic']
# [2800/5000] DOI: 10.1016/0301-5629(82)90097-7
#   → HTTP 400: XML not available
# [2801/5000] DOI: nan
# [2802/5000] DOI: 10.1080/00319100902774516
#   → HTTP 404: XML not available
# [2803/5000] DOI: 10.1109/LPT.2008.2006987
#   → HTTP 404: XML not available
# [2804/5000] DOI: 10.1016/j.ultrasmedbio.2022.04.005
#   → HTTP 400: XML not available
# [2805/5000] DOI: 10.1121/1.3561653
#   → HTTP 404: XML not available
# [2806/5000] DOI: 10.1109/TUFFC.2009.1037
#   → HTTP 404: XML not available
# [2807/5000] DOI: 10.1016/j.ultsonch.2023.106600
#   → Stage 1: DROP | Keywords: []
# [2808/5000] DOI: 10.1016/S0301-5629(97)00008-2
#   → Stage 1: DROP | Keywords: []
# [2809/5000] DOI: nan
# [2810/5000] DOI: 10.1016/j.ultsonch.2022.106080
#   → Stage 1: PASS | Keywords: ['acoustic', 'spectrum', 'spectrogram']
# [2811/5000] DOI: nan
# [2812/5000] DOI: 10.1109/TUFFC.2009.1298
#   → HTTP 404: XML not available
# [2813/5000] DOI: 10.1016/j.ultras.2018.11.012
#   → HTTP 400: XML not available
# [2814/5000] DOI: 10.1364/AO.44.003735
#   → HTTP 404: XML not available
# [2815/5000] DOI: 10.1016/j.ultrasmedbio.2021.06.008
#   → HTTP 400: XML not available
# [2816/5000] DOI: 10.1016/0041-624X(82)90025-7
#   → HTTP 400: XML not available
# [2817/5000] DOI: 10.1016/j.ultsonch.2023.106559
#   → Stage 1: PASS | Keywords: ['acoustic', 'frequency']
# [2818/5000] DOI: 10.1016/j.ultrasmedbio.2012.05.013
#   → HTTP 400: XML not available
# [2819/5000] DOI: 10.1002/adfm.202404941
#   → HTTP 404: XML not available
# [2820/5000] DOI: 10.1016/j.ultrasmedbio.2008.02.005
#   → HTTP 400: XML not available
# [2821/5000] DOI: 10.1063/1.1312389
#   → HTTP 404: XML not available
# [2822/5000] DOI: 10.1016/j.ultsonch.2006.04.004
#   → HTTP 400: XML not available
# [2823/5000] DOI: 10.1016/j.ultrasmedbio.2015.12.021
#   → HTTP 400: XML not available
# [2824/5000] DOI: 10.1121/1.2823258
#   → HTTP 404: XML not available
# [2825/5000] DOI: 10.1109/TUFFC.2020.2994877
#   → HTTP 404: XML not available
# [2826/5000] DOI: 10.1121/1.2982414
#   → HTTP 404: XML not available
# [2827/5000] DOI: 10.1016/S0041-624X(98)00007-9
#   → Stage 1: DROP | Keywords: []
# [2828/5000] DOI: 10.1109/ULTSYM.2007.330
#   → HTTP 404: XML not available
# [2829/5000] DOI: 10.1016/j.ultras.2019.02.002
#   → HTTP 400: XML not available
# [2830/5000] DOI: 10.1121/1.1757452
#   → HTTP 404: XML not available
# [2831/5000] DOI: 10.3233/JAE-2010-1196
#   → HTTP 404: XML not available
# [2832/5000] DOI: 10.1109/TUFFC.2020.2988159
#   → HTTP 404: XML not available
# [2833/5000] DOI: 10.1016/j.ultrasmedbio.2009.06.1101
#   → HTTP 400: XML not available
# [2834/5000] DOI: 10.1121/1.2896115
#   → HTTP 404: XML not available
# [2835/5000] DOI: 10.1121/1.3257584
#   → HTTP 404: XML not available
# [2836/5000] DOI: 10.1016/j.ultsonch.2021.105794
#   → Stage 1: PASS | Keywords: ['acoustic', 'spectrum', 'amplitude']
# [2837/5000] DOI: 10.1016/j.ultrasmedbio.2008.03.020
#   → HTTP 400: XML not available
# [2838/5000] DOI: 10.1063/1.3077018
#   → HTTP 404: XML not available
# [2839/5000] DOI: 10.1016/j.wavemoti.2009.09.002
#   → HTTP 400: XML not available
# [2840/5000] DOI: 10.1117/12.841671
#   → HTTP 404: XML not available
# [2841/5000] DOI: 10.1016/j.ultrasmedbio.2007.12.003
#   → HTTP 400: XML not available
# [2842/5000] DOI: 10.1016/0301-5629(95)00039-T
#   → HTTP 400: XML not available
# [2843/5000] DOI: 10.1016/j.ultras.2015.06.013
#   → HTTP 400: XML not available
# [2844/5000] DOI: 10.1109/TUFFC.2009.1325
#   → HTTP 404: XML not available
# [2845/5000] DOI: 10.1016/j.ultrasmedbio.2018.11.006
#   → HTTP 400: XML not available
# [2846/5000] DOI: 10.1016/j.ultsonch.2022.106056
#   → Stage 1: PASS | Keywords: ['acoustic', 'frequency']
# [2847/5000] DOI: 10.1063/1.3620879
#   → HTTP 404: XML not available
# [2848/5000] DOI: 10.1088/1742-6596/879/1/012026
#   → HTTP 404: XML not available
# [2849/5000] DOI: 10.1016/j.ultrasmedbio.2006.05.020
#   → HTTP 400: XML not available
# [2850/5000] DOI: 10.1016/j.pepi.2013.06.005
#   → HTTP 400: XML not available
# [2851/5000] DOI: 10.1063/1.3671062
#   → HTTP 404: XML not available
# [2852/5000] DOI: 10.1121/1.385540
#   → HTTP 404: XML not available
# [2853/5000] DOI: 10.1134/S1063771011060078
#   → HTTP 404: XML not available
# [2854/5000] DOI: 10.1109/TUFFC.2007.538
#   → HTTP 404: XML not available
# [2855/5000] DOI: 10.1109/TUFFC.2020.3001848
#   → HTTP 404: XML not available
# [2856/5000] DOI: 10.1016/j.ultrasmedbio.2006.03.011
#   → HTTP 400: XML not available
# [2857/5000] DOI: 10.1109/TUFFC.2010.1379
#   → HTTP 404: XML not available
# [2858/5000] DOI: 10.1016/j.ultsonch.2024.106859
#   → Stage 1: DROP | Keywords: []
# [2859/5000] DOI: 10.3390/s18010274
#   → HTTP 404: XML not available
# [2860/5000] DOI: 10.1016/0041-624X(74)90132-2
#   → HTTP 400: XML not available
# [2861/5000] DOI: 10.1063/1.4772644
#   → HTTP 404: XML not available
# [2862/5000] DOI: 10.1016/j.ndteint.2017.02.006
#   → HTTP 400: XML not available
# [2863/5000] DOI: 10.1121/1.1289665
#   → HTTP 404: XML not available
# [2864/5000] DOI: 10.1016/S0301-5629(03)00890-1
#   → HTTP 400: XML not available
# [2865/5000] DOI: 10.1016/S0041-624X(03)00179-3
#   → HTTP 400: XML not available
# [2866/5000] DOI: 10.1002/1521-396X(200206)191:2<445::AID-PSSA445>3.0.CO;2-H
#   → HTTP 404: XML not available
# [2867/5000] DOI: 10.1016/C2019-0-00783-2
#   → HTTP 400: XML not available
# [2868/5000] DOI: 10.1109/TUFFC.2009.1267
#   → HTTP 404: XML not available
# [2869/5000] DOI: 10.1016/j.apacoust.2010.04.004
#   → HTTP 400: XML not available
# [2870/5000] DOI: 10.1117/1.3365948
#   → HTTP 404: XML not available
# [2871/5000] DOI: 10.1016/j.ultrasmedbio.2017.08.004
#   → HTTP 400: XML not available
# [2872/5000] DOI: 10.1016/j.ultsonch.2011.03.005
#   → HTTP 400: XML not available
# [2873/5000] DOI: 10.1016/j.ultrasmedbio.2003.10.009
#   → HTTP 400: XML not available
# [2874/5000] DOI: 10.1016/0301-5629(91)90050-7
#   → HTTP 400: XML not available
# [2875/5000] DOI: 10.1109/TUFFC.2019.2924351
#   → HTTP 404: XML not available
# [2876/5000] DOI: 10.1016/j.ultras.2011.08.016
#   → HTTP 400: XML not available
# [2877/5000] DOI: 10.1016/S0041-624X(96)00104-7
#   → HTTP 400: XML not available
# [2878/5000] DOI: 10.1016/j.ultras.2010.03.002
#   → HTTP 400: XML not available
# [2879/5000] DOI: 10.1016/j.colsurfa.2010.01.044
#   → HTTP 400: XML not available
# [2880/5000] DOI: 10.1016/j.ultsonch.2021.105718
#   → Stage 1: PASS | Keywords: ['acoustic', 'hz', 'spectrum', 'frequency']
# [2881/5000] DOI: 10.1016/j.colsurfb.2006.08.011
#   → HTTP 400: XML not available
# [2882/5000] DOI: 10.1063/5.0101219
#   → HTTP 404: XML not available
# [2883/5000] DOI: 10.1121/1.388439
#   → HTTP 404: XML not available
# [2884/5000] DOI: 10.1016/j.ultrasmedbio.2009.04.009
#   → HTTP 400: XML not available
# [2885/5000] DOI: 10.1021/acs.langmuir.6b01075
#   → HTTP 404: XML not available
# [2886/5000] DOI: 10.1088/0022-3727/38/22/016
#   → HTTP 404: XML not available
# [2887/5000] DOI: 10.1016/j.ultrasmedbio.2019.05.024
#   → HTTP 400: XML not available
# [2888/5000] DOI: 10.1016/j.ultrasmedbio.2012.01.003
#   → HTTP 400: XML not available
# [2889/5000] DOI: 10.1016/j.snb.2022.132769
#   → HTTP 400: XML not available
# [2890/5000] DOI: 10.1016/0301-5629(85)90162-0
#   → HTTP 400: XML not available
# [2891/5000] DOI: 10.1121/1.1612486
#   → HTTP 404: XML not available
# [2892/5000] DOI: 10.1016/j.ultras.2006.10.001
#   → HTTP 400: XML not available
# [2893/5000] DOI: 10.1016/0041-624X(85)90027-7
#   → HTTP 400: XML not available
# [2894/5000] DOI: 10.1109/ULTSYM.2007.459
#   → HTTP 404: XML not available
# [2895/5000] DOI: 10.1121/1.4958991
#   → HTTP 404: XML not available
# [2896/5000] DOI: 10.1016/j.ultrasmedbio.2008.03.018
#   → HTTP 400: XML not available
# [2897/5000] DOI: 10.1016/j.ultrasmedbio.2014.10.008
#   → HTTP 400: XML not available
# [2898/5000] DOI: 10.1364/AO.51.004709
#   → HTTP 404: XML not available
# [2899/5000] DOI: 10.1016/j.ultrasmedbio.2008.08.016
#   → HTTP 400: XML not available
# [2900/5000] DOI: 10.1016/j.tsf.2011.05.014
#   → HTTP 400: XML not available
# [2901/5000] DOI: 10.1016/j.ultrasmedbio.2008.08.010
#   → HTTP 400: XML not available
# [2902/5000] DOI: 10.1121/1.3531941
#   → HTTP 404: XML not available
# [2903/5000] DOI: 10.1016/j.ultrasmedbio.2009.08.010
#   → HTTP 400: XML not available
# [2904/5000] DOI: 10.1063/1.1836018
#   → HTTP 404: XML not available
# [2905/5000] DOI: 10.1121/1.387417
#   → HTTP 404: XML not available
# [2906/5000] DOI: 10.1016/j.ultras.2010.12.012
#   → HTTP 400: XML not available
# [2907/5000] DOI: 10.1016/j.ultsonch.2022.106103
#   → Stage 1: PASS | Keywords: ['wave']
# [2908/5000] DOI: 10.1163/016942410X507605
#   → HTTP 404: XML not available
# [2909/5000] DOI: 10.1016/j.ultrasmedbio.2022.01.010
#   → HTTP 400: XML not available
# [2910/5000] DOI: 10.1088/0953-8984/23/11/115401
#   → HTTP 404: XML not available
# [2911/5000] DOI: 10.1016/j.ultras.2007.06.003
#   → HTTP 400: XML not available
# [2912/5000] DOI: 10.1016/j.ultras.2020.106089
#   → HTTP 400: XML not available
# [2913/5000] DOI: 10.1121/1.4937747
#   → HTTP 404: XML not available
# [2914/5000] DOI: 10.1016/j.ultrasmedbio.2019.09.016
#   → HTTP 400: XML not available
# [2915/5000] DOI: 10.1016/j.ultras.2009.08.003
#   → HTTP 400: XML not available
# [2916/5000] DOI: 10.1016/j.ultras.2014.06.013
#   → HTTP 400: XML not available
# [2917/5000] DOI: 10.1016/0041-624X(83)90045-8
#   → HTTP 400: XML not available
# [2918/5000] DOI: 10.1109/TUFFC.2017.2746900
#   → HTTP 404: XML not available
# [2919/5000] DOI: 10.1063/1.5023729
#   → HTTP 404: XML not available
# [2920/5000] DOI: 10.1117/12.770174
#   → HTTP 404: XML not available
# [2921/5000] DOI: 10.1016/j.ultsonch.2018.02.027
#   → HTTP 400: XML not available
# [2922/5000] DOI: 10.1109/TUFFC.2004.1350955
#   → HTTP 404: XML not available
# [2923/5000] DOI: 10.1063/1.1653585
#   → HTTP 404: XML not available
# [2924/5000] DOI: 10.1016/j.ultrasmedbio.2006.05.027
#   → HTTP 400: XML not available
# [2925/5000] DOI: 10.1109/TUFFC.2011.1819
#   → HTTP 404: XML not available
# [2926/5000] DOI: 10.1109/ULTSYM.1992.275856
#   → HTTP 404: XML not available
# [2927/5000] DOI: 10.1121/1.385937
#   → HTTP 404: XML not available
# [2928/5000] DOI: 10.1016/0301-5629(89)90100-2
#   → HTTP 400: XML not available
# [2929/5000] DOI: 10.1016/j.diamond.2004.11.025
#   → HTTP 400: XML not available
# [2930/5000] DOI: 10.1063/1.3033140
#   → HTTP 404: XML not available
# [2931/5000] DOI: 10.1016/j.ultrasmedbio.2014.09.018
#   → Stage 1: PASS | Keywords: ['spectrum', 'wave', 'frequency']
# [2932/5000] DOI: 10.1109/ULTSYM.2018.8580072
#   → HTTP 404: XML not available
# [2933/5000] DOI: nan
# [2934/5000] DOI: 10.1063/1.2939565
#   → HTTP 404: XML not available
# [2935/5000] DOI: 10.1016/j.jsv.2017.12.019
#   → HTTP 400: XML not available
# [2936/5000] DOI: 10.1063/1.4936345
#   → HTTP 404: XML not available
# [2937/5000] DOI: 10.1016/j.ultsonch.2011.07.007
#   → HTTP 400: XML not available
# [2938/5000] DOI: 10.1016/j.commatsci.2004.02.027
#   → HTTP 400: XML not available
# [2939/5000] DOI: nan
# [2940/5000] DOI: 10.1063/1.3388283
#   → HTTP 404: XML not available
# [2941/5000] DOI: 10.1016/j.ultrasmedbio.2018.07.017
#   → HTTP 400: XML not available
# [2942/5000] DOI: 10.1016/j.ultsonch.2013.11.014
#   → HTTP 400: XML not available
# [2943/5000] DOI: 10.1016/j.ultrasmedbio.2022.09.019
#   → HTTP 400: XML not available
# [2944/5000] DOI: 10.1016/j.pacs.2020.100208
#   → Stage 1: PASS | Keywords: ['spectrum', 'acoustic', 'amplitude', 'frequency']
# [2945/5000] DOI: 10.1364/OE.15.003291
#   → HTTP 404: XML not available
# [2946/5000] DOI: 10.1016/j.ultrasmedbio.2003.08.009
#   → HTTP 400: XML not available
# [2947/5000] DOI: 10.1016/j.ultrasmedbio.2012.02.008
#   → HTTP 400: XML not available
# [2948/5000] DOI: 10.1109/TUFFC.2012.2504
#   → HTTP 404: XML not available
# [2949/5000] DOI: 10.1109/ULTSYM.2010.5935507
#   → HTTP 404: XML not available
# [2950/5000] DOI: 10.1117/12.809973
#   → HTTP 404: XML not available
# [2951/5000] DOI: 10.1016/0041-624X(82)90060-9
#   → HTTP 400: XML not available
# [2952/5000] DOI: 10.1016/0301-5629(93)90111-Z
#   → HTTP 400: XML not available
# [2953/5000] DOI: 10.1121/1.2133683
#   → HTTP 404: XML not available
# [2954/5000] DOI: 10.1109/ULTSYM.2004.1417658
#   → HTTP 404: XML not available
# [2955/5000] DOI: 10.1121/1.2171516
#   → HTTP 404: XML not available
# [2956/5000] DOI: 10.1016/j.ultras.2010.06.003
#   → HTTP 400: XML not available
# [2957/5000] DOI: 10.1109/TUFFC.2011.2106
#   → HTTP 404: XML not available
# [2958/5000] DOI: 10.1016/j.ultsonch.2022.106061
#   → Stage 1: PASS | Keywords: ['hz', 'frequency']
# [2959/5000] DOI: 10.1109/TIM.2008.926408
#   → HTTP 404: XML not available
# [2960/5000] DOI: 10.1016/j.ultrasmedbio.2009.04.001
#   → HTTP 400: XML not available
# [2961/5000] DOI: 10.1117/12.806794
#   → HTTP 404: XML not available
# [2962/5000] DOI: 10.1103/PhysRevE.85.066309
#   → HTTP 404: XML not available
# [2963/5000] DOI: 10.1080/09349840209409714
#   → HTTP 404: XML not available
# [2964/5000] DOI: 10.1016/j.sna.2009.01.010
#   → HTTP 400: XML not available
# [2965/5000] DOI: 10.1121/1.4742722
#   → HTTP 404: XML not available
# [2966/5000] DOI: 10.1121/1.429345
#   → HTTP 404: XML not available
# [2967/5000] DOI: 10.1109/TUFFC.2010.1707
#   → HTTP 404: XML not available
# [2968/5000] DOI: 10.1016/j.ultras.2018.02.002
#   → HTTP 400: XML not available
# [2969/5000] DOI: 10.1016/j.ultras.2004.01.007
#   → HTTP 400: XML not available
# [2970/5000] DOI: 10.1121/1.4773256
#   → HTTP 404: XML not available
# [2971/5000] DOI: 10.1117/12.2510000
#   → HTTP 404: XML not available
# [2972/5000] DOI: 10.1002/adfm.202316093
#   → HTTP 404: XML not available
# [2973/5000] DOI: 10.1016/S0925-9635(00)00410-6
#   → HTTP 400: XML not available
# [2974/5000] DOI: 10.1016/j.ultrasmedbio.2018.06.011
#   → HTTP 400: XML not available
# [2975/5000] DOI: 10.1109/TUFFC.2008.828
#   → HTTP 404: XML not available
# [2976/5000] DOI: 10.1016/0041-624X(92)90028-K
#   → HTTP 400: XML not available
# [2977/5000] DOI: 10.1109/ULTSYM.2008.0012
#   → HTTP 404: XML not available
# [2978/5000] DOI: 10.1016/j.ultrasmedbio.2005.01.019
#   → HTTP 400: XML not available
# [2979/5000] DOI: 10.1016/j.ultras.2015.05.016
#   → HTTP 400: XML not available
# [2980/5000] DOI: 10.1007/BF00652510
#   → HTTP 404: XML not available
# [2981/5000] DOI: 10.1121/1.2963187
#   → HTTP 404: XML not available
# [2982/5000] DOI: 10.1016/j.ultrasmedbio.2005.10.005
#   → HTTP 400: XML not available
# [2983/5000] DOI: 10.1121/1.1564606
#   → HTTP 404: XML not available
# [2984/5000] DOI: 10.1121/1.3501115
#   → HTTP 404: XML not available
# [2985/5000] DOI: 10.1063/1.3609866
#   → HTTP 404: XML not available
# [2986/5000] DOI: 10.1109/TUFFC.2022.3197705
#   → HTTP 404: XML not available
# [2987/5000] DOI: 10.1016/S0301-5629(94)00101-4
#   → HTTP 400: XML not available
# [2988/5000] DOI: 10.1016/0301-5629(76)90019-3
#   → HTTP 400: XML not available
# [2989/5000] DOI: 10.1016/0301-5629(92)90097-T
#   → HTTP 400: XML not available
# [2990/5000] DOI: 10.1364/OL.37.003174
#   → HTTP 404: XML not available
# [2991/5000] DOI: 10.1088/0022-3727/40/22/041
#   → HTTP 404: XML not available
# [2992/5000] DOI: 10.1080/10402004.2010.533817
#   → HTTP 404: XML not available
# [2993/5000] DOI: 10.1016/j.wear.2015.02.049
#   → HTTP 400: XML not available
# [2994/5000] DOI: 10.1121/1.4812973
#   → HTTP 404: XML not available
# [2995/5000] DOI: 10.1038/lsa.2016.82
#   → HTTP 404: XML not available
# [2996/5000] DOI: 10.1016/j.ultsonch.2014.09.011
#   → Stage 1: PASS | Keywords: ['spectrum']
# [2997/5000] DOI: 10.1016/0301-5629(77)90071-0
#   → HTTP 400: XML not available
# [2998/5000] DOI: 10.1016/j.wavemoti.2006.10.003
#   → HTTP 400: XML not available
# [2999/5000] DOI: 10.1080/00150190211754
#   → HTTP 404: XML not available
# [3000/5000] DOI: 10.1016/S0038-1098(96)00687-4
#   → HTTP 400: XML not available
# [3001/5000] DOI: 10.1109/TUFFC.2020.3033304
#   → HTTP 404: XML not available
# [3002/5000] DOI: 10.1117/12.770393
#   → HTTP 404: XML not available
# [3003/5000] DOI: 10.1121/1.4931901
#   → HTTP 404: XML not available
# [3004/5000] DOI: 10.1016/j.ultsonch.2020.105127
#   → HTTP 400: XML not available
# [3005/5000] DOI: 10.1016/0301-5629(88)90159-7
#   → HTTP 400: XML not available
# [3006/5000] DOI: 10.1109/ULTSYM.2008.0212
#   → HTTP 404: XML not available
# [3007/5000] DOI: nan
# [3008/5000] DOI: 10.1109/ULTSYM.2008.0149
#   → HTTP 404: XML not available
# [3009/5000] DOI: 10.1121/1.1910235
#   → HTTP 404: XML not available
# [3010/5000] DOI: 10.3813/AAA.918267
#   → HTTP 404: XML not available
# [3011/5000] DOI: 10.1016/j.ultrasmedbio.2009.06.1089
#   → HTTP 400: XML not available
# [3012/5000] DOI: 10.1016/j.ultrasmedbio.2012.07.019
#   → HTTP 400: XML not available
# [3013/5000] DOI: 10.1016/j.ultras.2015.08.007
#   → HTTP 400: XML not available
# [3014/5000] DOI: 10.1016/j.molliq.2011.07.001
#   → HTTP 400: XML not available
# [3015/5000] DOI: 10.1016/j.ultsonch.2015.10.001
#   → Stage 1: PASS | Keywords: ['acoustic', 'frequency']
# [3016/5000] DOI: 10.1016/j.ultras.2008.09.001
#   → HTTP 400: XML not available
# [3017/5000] DOI: 10.1121/1.2897132
#   → HTTP 404: XML not available
# [3018/5000] DOI: 10.1016/j.ultrasmedbio.2008.07.006
#   → HTTP 400: XML not available
# [3019/5000] DOI: 10.1016/j.ultras.2006.02.001
#   → HTTP 400: XML not available
# [3020/5000] DOI: 10.1016/0041-624X(88)90027-3
#   → HTTP 400: XML not available
# [3021/5000] DOI: 10.1016/j.ultsonch.2023.106630
#   → Stage 1: DROP | Keywords: []
# [3022/5000] DOI: 10.1016/j.ultras.2010.12.011
#   → HTTP 400: XML not available
# [3023/5000] DOI: 10.1117/12.848901
#   → HTTP 404: XML not available
# [3024/5000] DOI: 10.1039/c1sm05871a
#   → HTTP 404: XML not available
# [3025/5000] DOI: 10.1007/s11249-015-0619-x
#   → HTTP 404: XML not available
# [3026/5000] DOI: 10.1117/12.768822
#   → HTTP 404: XML not available
# [3027/5000] DOI: 10.1364/OL.32.002285
#   → HTTP 404: XML not available
# [3028/5000] DOI: 10.1121/1.1914661
#   → HTTP 404: XML not available
# [3029/5000] DOI: 10.1063/1.1886276
#   → HTTP 404: XML not available
# [3030/5000] DOI: 10.1088/0022-3727/22/9/004
#   → HTTP 404: XML not available
# [3031/5000] DOI: 10.1121/1.4812878
#   → HTTP 404: XML not available
# [3032/5000] DOI: 10.1016/j.apacoust.2022.108833
#   → HTTP 400: XML not available
# [3033/5000] DOI: 10.1117/12.907714
#   → HTTP 404: XML not available
# [3034/5000] DOI: 10.1016/j.ultras.2008.10.020
#   → HTTP 400: XML not available
# [3035/5000] DOI: 10.1016/0041-624X(88)90034-0
#   → HTTP 400: XML not available
# [3036/5000] DOI: 10.1016/j.ultrasmedbio.2008.09.027
#   → HTTP 400: XML not available
# [3037/5000] DOI: 10.1063/1.2982584
#   → HTTP 404: XML not available
# [3038/5000] DOI: 10.1121/1.4916280
#   → HTTP 404: XML not available
# [3039/5000] DOI: 10.1143/jjap.37.2982
#   → HTTP 404: XML not available
# [3040/5000] DOI: 10.1016/0301-5629(94)90005-1
#   → HTTP 400: XML not available
# [3041/5000] DOI: 10.1121/1.418154
#   → HTTP 404: XML not available
# [3042/5000] DOI: 10.1016/j.ultras.2011.11.008
#   → HTTP 400: XML not available
# [3043/5000] DOI: 10.3390/s21041217
#   → HTTP 404: XML not available
# [3044/5000] DOI: 10.1121/1.4714339
#   → HTTP 404: XML not available
# [3045/5000] DOI: 10.4028/www.scientific.net/MSF.828-829.112
#   → HTTP 404: XML not available
# [3046/5000] DOI: 10.1016/j.flowmeasinst.2005.06.002
#   → HTTP 400: XML not available
# [3047/5000] DOI: 10.1109/TUFFC.2003.1244749
#   → HTTP 404: XML not available
# [3048/5000] DOI: 10.1121/1.1911452
#   → HTTP 404: XML not available
# [3049/5000] DOI: 10.1016/j.ultrasmedbio.2005.10.008
#   → HTTP 400: XML not available
# [3050/5000] DOI: 10.3390/s19020404
#   → HTTP 404: XML not available
# [3051/5000] DOI: 10.1117/12.841760
#   → HTTP 404: XML not available
# [3052/5000] DOI: 10.1016/j.sna.2021.112925
#   → HTTP 400: XML not available
# [3053/5000] DOI: 10.1007/s11051-008-9394-z
#   → HTTP 404: XML not available
# [3054/5000] DOI: 10.1121/1.4946831
#   → HTTP 404: XML not available
# [3055/5000] DOI: 10.1016/j.ultras.2016.03.007
#   → HTTP 400: XML not available
# [3056/5000] DOI: 10.1016/j.ultrasmedbio.2014.03.019
#   → HTTP 400: XML not available
# [3057/5000] DOI: 10.1121/1.2960899
#   → HTTP 404: XML not available
# [3058/5000] DOI: 10.1016/j.ultrasmedbio.2010.04.016
#   → HTTP 400: XML not available
# [3059/5000] DOI: 10.1121/1.1463449
#   → HTTP 404: XML not available
# [3060/5000] DOI: 10.1016/0301-5629(92)90086-P
#   → HTTP 400: XML not available
# [3061/5000] DOI: 10.1016/j.ultrasmedbio.2011.05.850
#   → HTTP 400: XML not available
# [3062/5000] DOI: 10.1016/0301-5629(81)90039-9
#   → HTTP 400: XML not available
# [3063/5000] DOI: 10.1143/JJAP.49.07HE16
#   → HTTP 404: XML not available
# [3064/5000] DOI: 10.1016/j.ultrasmedbio.2013.05.018
#   → HTTP 400: XML not available
# [3065/5000] DOI: 10.1109/TUFFC.2009.1295
#   → HTTP 404: XML not available
# [3066/5000] DOI: 10.1109/TUFFC.898
#   → HTTP 404: XML not available
# [3067/5000] DOI: 10.1109/TUFFC.2007.270
#   → HTTP 404: XML not available
# [3068/5000] DOI: 10.1016/j.optlastec.2004.05.002
#   → HTTP 400: XML not available
# [3069/5000] DOI: 10.1121/1.4792140
#   → HTTP 404: XML not available
# [3070/5000] DOI: 10.1121/1.2161799
#   → HTTP 404: XML not available
# [3071/5000] DOI: 10.1016/j.ultrasmedbio.2009.05.021
#   → HTTP 400: XML not available
# [3072/5000] DOI: 10.1038/s41467-024-55022-2
#   → HTTP 404: XML not available
# [3073/5000] DOI: 10.1098/rsta.2022.0025
#   → HTTP 404: XML not available
# [3074/5000] DOI: 10.1016/j.ultrasmedbio.2023.02.019
#   → HTTP 400: XML not available
# [3075/5000] DOI: 10.1016/j.ultras.2020.106245
#   → HTTP 400: XML not available
# [3076/5000] DOI: 10.1016/S0041-624X(03)00108-2
#   → HTTP 400: XML not available
# [3077/5000] DOI: 10.1088/1361-6463/aae96d
#   → HTTP 404: XML not available
# [3078/5000] DOI: 10.1080/14786435.2014.897008
#   → HTTP 404: XML not available
# [3079/5000] DOI: 10.1016/j.ndteint.2021.102576
#   → HTTP 400: XML not available
# [3080/5000] DOI: 10.1016/j.ultrasmedbio.2012.09.024
#   → HTTP 400: XML not available
# [3081/5000] DOI: 10.1007/978-981-287-278-4_1
#   → HTTP 404: XML not available
# [3082/5000] DOI: nan
# [3083/5000] DOI: 10.1121/1.4944758
#   → HTTP 404: XML not available
# [3084/5000] DOI: 10.1121/1.402477
#   → HTTP 404: XML not available
# [3085/5000] DOI: 10.1016/j.ultrasmedbio.2019.08.005
#   → Stage 1: PASS | Keywords: ['amplitude']
# [3086/5000] DOI: 10.1109/ULTSYM.2008.0161
#   → HTTP 404: XML not available
# [3087/5000] DOI: 10.1016/j.ultsonch.2021.105888
#   → Stage 1: DROP | Keywords: []
# [3088/5000] DOI: 10.1016/0301-5629(91)90131-F
#   → HTTP 400: XML not available
# [3089/5000] DOI: 10.1016/0301-5629(90)90040-J
#   → HTTP 400: XML not available
# [3090/5000] DOI: 10.1121/1.4824337
#   → HTTP 404: XML not available
# [3091/5000] DOI: 10.1016/j.ultsonch.2023.106737
#   → Stage 1: PASS | Keywords: ['acoustic', 'frequency']
# [3092/5000] DOI: 10.1103/PhysRevApplied.18.044047
#   → HTTP 404: XML not available
# [3093/5000] DOI: 10.1016/j.ultrasmedbio.2005.06.014
#   → HTTP 400: XML not available
# [3094/5000] DOI: 10.1016/S0041-624X(96)00077-7
#   → HTTP 400: XML not available
# [3095/5000] DOI: 10.1016/j.ultsonch.2016.04.029
#   → Stage 1: PASS | Keywords: ['frequency']
# [3096/5000] DOI: 10.1016/j.ultras.2018.06.013
#   → HTTP 400: XML not available
# [3097/5000] DOI: 10.1016/j.ndteint.2009.10.004
#   → HTTP 400: XML not available
# [3098/5000] DOI: 10.1063/1.5031519
#   → HTTP 404: XML not available
# [3099/5000] DOI: 10.1143/JJAP.50.07HE28
#   → HTTP 404: XML not available
# [3100/5000] DOI: 10.1016/0301-5629(85)90124-3
#   → HTTP 400: XML not available
# [3101/5000] DOI: nan
# [3102/5000] DOI: 10.1121/1.1414703
#   → HTTP 404: XML not available
# [3103/5000] DOI: 10.1016/j.physleta.2010.11.008
#   → HTTP 400: XML not available
# [3104/5000] DOI: 10.1016/j.ultras.2013.04.015
#   → HTTP 400: XML not available
# [3105/5000] DOI: 10.1109/ULTSYM.2010.5936014
#   → HTTP 404: XML not available
# [3106/5000] DOI: 10.1109/TUFFC.2005.1561663
#   → HTTP 404: XML not available
# [3107/5000] DOI: 10.1109/ULTSYM.2010.5935455
#   → HTTP 404: XML not available
# [3108/5000] DOI: 10.1016/S0301-5629(99)00021-6
#   → HTTP 400: XML not available
# ...
#   → HTTP 400: XML not available
# [4785/5000] DOI: 10.1117/12.835475
#   → HTTP 404: XML not available
# [4786/5000] DOI: 10.1016/j.apacoust.2010.11.015
#   → HTTP 400: XML not available
# [4787/5000] DOI: 10.1016/j.ultras.2011.02.008
#   → HTTP 400: XML not available
# [4788/5000] DOI: 10.1134/S1063771011020126
#   → HTTP 404: XML not available
# [4789/5000] DOI: 10.1016/j.ultrasmedbio.2019.03.013
#   → HTTP 400: XML not available
# [4790/5000] DOI: 10.1016/j.ultrasmedbio.2016.08.012
#   → HTTP 400: XML not available
# [4791/5000] DOI: 10.1121/1.5139423
#   → HTTP 404: XML not available
# [4792/5000] DOI: 10.1016/j.apacoust.2011.11.003
#   → HTTP 400: XML not available
# [4793/5000] DOI: 10.1016/j.ultrasmedbio.2010.12.010
#   → HTTP 400: XML not available
# [4794/5000] DOI: 10.1016/0301-5629(82)90086-2
#   → HTTP 400: XML not available
# [4795/5000] DOI: 10.1063/1.337607
#   → HTTP 404: XML not available
# [4796/5000] DOI: 10.1109/TUFFC.2010.1399
#   → HTTP 404: XML not available
# [4797/5000] DOI: 10.1117/1.2907791
#   → HTTP 404: XML not available
# [4798/5000] DOI: 10.1016/0301-5629(74)90027-1
#   → HTTP 400: XML not available
# [4799/5000] DOI: 10.1117/12.907427
#   → HTTP 404: XML not available
# [4800/5000] DOI: 10.1016/S0041-624X(99)00222-X
#   → HTTP 400: XML not available
# [4801/5000] DOI: 10.1109/TUFFC.2010.1492
#   → HTTP 404: XML not available
# [4802/5000] DOI: 10.1016/j.ultras.2006.07.005
#   → HTTP 400: XML not available
# [4803/5000] DOI: 10.1088/0022-3727/33/11/307
#   → HTTP 404: XML not available
# [4804/5000] DOI: nan
# [4805/5000] DOI: 10.1016/j.ultrasmedbio.2015.02.008
#   → Stage 1: DROP | Keywords: []
# [4806/5000] DOI: 10.1117/12.840627
#   → HTTP 404: XML not available
# [4807/5000] DOI: 10.1121/1.2957937
#   → HTTP 404: XML not available
# [4808/5000] DOI: 10.1016/j.matlet.2011.07.115
#   → HTTP 400: XML not available
# [4809/5000] DOI: 10.24200/sci.2017.4496
#   → HTTP 404: XML not available
# [4810/5000] DOI: 10.1016/j.ultras.2012.06.018
#   → HTTP 400: XML not available
# [4811/5000] DOI: 10.35848/1347-4065/abef14
#   → HTTP 404: XML not available
# [4812/5000] DOI: nan
# [4813/5000] DOI: 10.1121/1.2968297
#   → HTTP 404: XML not available
# [4814/5000] DOI: 10.1016/j.mee.2011.05.018
#   → HTTP 400: XML not available
# [4815/5000] DOI: 10.1121/1.3087427
#   → HTTP 404: XML not available
# [4816/5000] DOI: 10.1016/j.ultsonch.2023.106449
#   → Stage 1: DROP | Keywords: []
# [4817/5000] DOI: 10.1109/ULTSYM.2006.104
#   → HTTP 404: XML not available
# [4818/5000] DOI: nan
# [4819/5000] DOI: 10.1016/S0041-624X(99)00110-9
#   → HTTP 400: XML not available
# [4820/5000] DOI: 10.1016/j.measurement.2023.113379
#   → HTTP 400: XML not available
# [4821/5000] DOI: 10.1121/1.2126935
#   → HTTP 404: XML not available
# [4822/5000] DOI: 10.3390/s22197345
#   → HTTP 404: XML not available
# [4823/5000] DOI: 10.1021/acs.langmuir.0c03444
#   → HTTP 404: XML not available
# [4824/5000] DOI: 10.1016/j.colsurfa.2023.131210
#   → HTTP 400: XML not available
# [4825/5000] DOI: 10.1117/12.446687
#   → HTTP 404: XML not available
# [4826/5000] DOI: 10.1364/AO.378466
#   → HTTP 404: XML not available
# [4827/5000] DOI: 10.1007/s11630-008-0163-1
#   → HTTP 404: XML not available
# [4828/5000] DOI: 10.1016/j.flowmeasinst.2008.11.002
#   → HTTP 400: XML not available
# [4829/5000] DOI: 10.1109/58.384452
#   → HTTP 404: XML not available
# [4830/5000] DOI: 10.1121/1.5047669
#   → HTTP 404: XML not available
# [4831/5000] DOI: 10.1121/1.392776
#   → HTTP 404: XML not available
# [4832/5000] DOI: 10.1109/ULTSYM.2015.0315
#   → HTTP 404: XML not available
# [4833/5000] DOI: 10.3390/s21020421
#   → HTTP 404: XML not available
# [4834/5000] DOI: 10.1016/j.ultras.2008.11.005
#   → HTTP 400: XML not available
# [4835/5000] DOI: 10.1109/ULTSYM.2014.0487
#   → HTTP 404: XML not available
# [4836/5000] DOI: 10.1109/ULTSYM.2008.0179
#   → HTTP 404: XML not available
# [4837/5000] DOI: 10.1121/1.2884083
#   → HTTP 404: XML not available
# [4838/5000] DOI: 10.1016/j.ultsonch.2022.106138
#   → Stage 1: PASS | Keywords: ['spectrum', 'amplitude', 'hz', 'acoustic', 'frequency']
# [4839/5000] DOI: 10.2320/matertrans.M2010074
#   → HTTP 404: XML not available
# [4840/5000] DOI: 10.1016/j.jnoncrysol.2010.06.036
#   → HTTP 400: XML not available
# [4841/5000] DOI: 10.1016/j.ultras.2008.10.008
#   → HTTP 400: XML not available
# [4842/5000] DOI: 10.1016/j.ultrasmedbio.2019.11.011
#   → HTTP 400: XML not available
# [4843/5000] DOI: 10.1016/j.jmmm.2004.11.097
#   → HTTP 400: XML not available
# [4844/5000] DOI: 10.1143/JJAP.48.07GK08
#   → HTTP 404: XML not available
# [4845/5000] DOI: 10.1117/12.770321
#   → HTTP 404: XML not available
# [4846/5000] DOI: 10.1016/j.ultrasmedbio.2014.11.001
#   → HTTP 400: XML not available
# [4847/5000] DOI: 10.1016/j.ultsonch.2021.105882
#   → Stage 1: PASS | Keywords: ['spectrum', 'amplitude', 'hz', 'acoustic', 'frequency']
# [4848/5000] DOI: 10.1143/JJAP.47.3997
#   → HTTP 404: XML not available
# [4849/5000] DOI: 10.1016/j.ultrasmedbio.2018.05.010
#   → HTTP 400: XML not available
# [4850/5000] DOI: 10.7567/JJAP.57.07LE06
#   → HTTP 404: XML not available
# [4851/5000] DOI: 10.1016/0301-5629(89)90189-0
#   → HTTP 400: XML not available
# [4852/5000] DOI: 10.1121/1.4818774
#   → HTTP 404: XML not available
# [4853/5000] DOI: 10.18154/RWTH-CONV-238848
#   → HTTP 404: XML not available
# [4854/5000] DOI: nan
# [4855/5000] DOI: 10.1117/12.2008811
#   → HTTP 404: XML not available
# [4856/5000] DOI: 10.1109/ULTSYM.2008.0215
#   → HTTP 404: XML not available
# [4857/5000] DOI: 10.3390/s22062135
#   → HTTP 404: XML not available
# [4858/5000] DOI: 10.1016/j.ultras.2009.08.013
#   → HTTP 400: XML not available
# [4859/5000] DOI: 10.1016/j.sna.2009.02.022
#   → HTTP 400: XML not available
# [4860/5000] DOI: 10.1088/1361-6463/aacaed
#   → HTTP 404: XML not available
# [4861/5000] DOI: 10.1088/1674-1056/26/5/054302
#   → HTTP 404: XML not available
# [4862/5000] DOI: nan
# [4863/5000] DOI: 10.1016/S0301-5629(98)00141-0
#   → HTTP 400: XML not available
# [4864/5000] DOI: 10.1109/TUFFC.2008.698
#   → HTTP 404: XML not available
# [4865/5000] DOI: 10.1143/JJAP.49.07HE21
#   → HTTP 404: XML not available
# [4866/5000] DOI: 10.1109/TUFFC.2009.1070
#   → HTTP 404: XML not available
# [4867/5000] DOI: 10.1103/PhysRevB.103.064303
#   → HTTP 404: XML not available
# [4868/5000] DOI: 10.1021/acssensors.4c00291
#   → HTTP 404: XML not available
# [4869/5000] DOI: 10.1016/0301-5629(92)90077-N
#   → HTTP 400: XML not available
# [4870/5000] DOI: 10.1016/j.ultsonch.2025.107643
#   → Stage 1: DROP | Keywords: []
# [4871/5000] DOI: 10.1063/1.4861882
#   → HTTP 404: XML not available
# [4872/5000] DOI: 10.2320/matertrans.MRA2008270
#   → HTTP 404: XML not available
# [4873/5000] DOI: 10.1063/5.0087303
#   → HTTP 404: XML not available
# [4874/5000] DOI: 10.1016/j.ultrasmedbio.2008.10.003
#   → HTTP 400: XML not available
# [4875/5000] DOI: 10.1117/12.462165
#   → HTTP 404: XML not available
# [4876/5000] DOI: 10.1016/j.ultras.2008.04.014
#   → HTTP 400: XML not available
# [4877/5000] DOI: 10.1016/j.apacoust.2010.10.009
#   → HTTP 400: XML not available
# [4878/5000] DOI: 10.3390/s22218100
#   → HTTP 404: XML not available
# [4879/5000] DOI: 10.1016/0301-5629(89)90134-8
#   → Stage 1: DROP | Keywords: []
# [4880/5000] DOI: nan
# [4881/5000] DOI: 10.1016/j.msea.2004.10.019
#   → HTTP 400: XML not available
# [4882/5000] DOI: 10.1134/S1061830914030024
#   → HTTP 404: XML not available
# [4883/5000] DOI: 10.1016/j.ultras.2015.05.005
#   → HTTP 400: XML not available
# [4884/5000] DOI: 10.1121/1.1624069
#   → HTTP 404: XML not available
# [4885/5000] DOI: 10.1121/1.3132526
#   → HTTP 404: XML not available
# [4886/5000] DOI: 10.1117/12.816046
#   → HTTP 404: XML not available
# [4887/5000] DOI: 10.1016/j.matlet.2004.03.039
#   → HTTP 400: XML not available
# [4888/5000] DOI: 10.1117/1.JBO.22.4.041013
#   → HTTP 404: XML not available
# [4889/5000] DOI: 10.1109/TUFFC.2009.1075
#   → HTTP 404: XML not available
# [4890/5000] DOI: 10.1109/TUFFC.2009.1069
#   → HTTP 404: XML not available
# [4891/5000] DOI: 10.1109/ULTSYM.2007.310
#   → HTTP 404: XML not available
# [4892/5000] DOI: 10.1121/1.3515838
#   → HTTP 404: XML not available
# [4893/5000] DOI: 10.1143/JJAP.48.09KD10
#   → HTTP 404: XML not available
# [4894/5000] DOI: 10.7567/JJAP.54.07HF16
#   → HTTP 404: XML not available
# [4895/5000] DOI: 10.1016/j.ultrasmedbio.2009.05.015
#   → HTTP 400: XML not available
# [4896/5000] DOI: 10.1016/j.ultsonch.2019.03.029
#   → Stage 1: PASS | Keywords: ['acoustic']
# [4897/5000] DOI: 10.1016/j.ultrasmedbio.2014.02.004
#   → HTTP 400: XML not available
# [4898/5000] DOI: 10.1117/12.811713
#   → HTTP 404: XML not available
# [4899/5000] DOI: 10.1121/1.1646398
#   → HTTP 404: XML not available
# [4900/5000] DOI: 10.1016/j.ultrasmedbio.2008.08.007
#   → HTTP 400: XML not available
# [4901/5000] DOI: 10.1109/ULTSYM.2008.0257
#   → HTTP 404: XML not available
# [4902/5000] DOI: 10.1016/S0301-5629(94)00117-0
#   → HTTP 400: XML not available
# [4903/5000] DOI: 10.1121/1.393803
#   → HTTP 404: XML not available
# [4904/5000] DOI: 10.3390/s17010173
#   → HTTP 404: XML not available
# [4905/5000] DOI: 10.1016/j.jmps.2012.04.006
#   → HTTP 400: XML not available
# [4906/5000] DOI: 10.1121/1.4767448
#   → HTTP 404: XML not available
# [4907/5000] DOI: 10.1109/ULTSYM.2007.480
#   → HTTP 404: XML not available
# [4908/5000] DOI: 10.1109/TUFFC.2006.1642520
#   → HTTP 404: XML not available
# [4909/5000] DOI: 10.1016/j.ultras.2011.02.005
#   → HTTP 400: XML not available
# [4910/5000] DOI: 10.1109/ULTSYM.2008.0029
#   → HTTP 404: XML not available
# [4911/5000] DOI: 10.1109/ULTSYM.2008.0513
#   → HTTP 404: XML not available
# [4912/5000] DOI: 10.1016/j.jsv.2017.08.047
#   → HTTP 400: XML not available
# [4913/5000] DOI: 10.1016/S0893-388X(99)80025-6
#   → HTTP 400: XML not available
# [4914/5000] DOI: 10.1016/S0301-5629(02)00530-6
#   → HTTP 400: XML not available
# [4915/5000] DOI: 10.1016/j.ultrasmedbio.2003.11.015
#   → HTTP 400: XML not available
# [4916/5000] DOI: 10.1016/j.ultsonch.2020.105125
#   → HTTP 400: XML not available
# [4917/5000] DOI: 10.1016/j.pepi.2011.11.003
#   → HTTP 400: XML not available
# [4918/5000] DOI: 10.1016/j.ultrasmedbio.2019.05.013
#   → HTTP 400: XML not available
# [4919/5000] DOI: 10.1016/j.jct.2015.08.009
#   → HTTP 400: XML not available
# [4920/5000] DOI: 10.1109/TUFFC.2013.6644746
#   → HTTP 404: XML not available
# [4921/5000] DOI: 10.1063/5.0252650
#   → HTTP 404: XML not available
# [4922/5000] DOI: 10.1121/1.2945706
#   → HTTP 404: XML not available
# [4923/5000] DOI: 10.1143/JJAP.47.956
#   → HTTP 404: XML not available
# [4924/5000] DOI: 10.1016/j.sna.2023.114837
#   → HTTP 400: XML not available
# [4925/5000] DOI: 10.1016/j.ultrasmedbio.2009.10.008
#   → HTTP 400: XML not available
# [4926/5000] DOI: 10.1117/12.810952
#   → HTTP 404: XML not available
# [4927/5000] DOI: 10.1016/j.ultsonch.2023.106728
#   → Stage 1: PASS | Keywords: ['acoustic']
# [4928/5000] DOI: 10.1109/ULTSYM.2011.0529
#   → HTTP 404: XML not available
# [4929/5000] DOI: 10.1109/TUFFC.2021.3093867
#   → HTTP 404: XML not available
# [4930/5000] DOI: 10.1016/j.ultras.2014.06.019
#   → HTTP 400: XML not available
# [4931/5000] DOI: 10.1016/j.ultras.2024.107273
#   → HTTP 400: XML not available
# [4932/5000] DOI: 10.1016/j.ultrasmedbio.2014.03.016
#   → HTTP 400: XML not available
# [4933/5000] DOI: 10.1016/j.ultras.2009.01.004
#   → HTTP 400: XML not available
# [4934/5000] DOI: 10.1016/j.ultrasmedbio.2008.12.011
#   → HTTP 400: XML not available
# [4935/5000] DOI: 10.1117/12.878041
#   → HTTP 404: XML not available
# [4936/5000] DOI: 10.1109/58.143170
#   → HTTP 404: XML not available
# [4937/5000] DOI: 10.1016/j.wavemoti.2014.06.001
#   → HTTP 400: XML not available
# [4938/5000] DOI: 10.1016/j.apacoust.2010.11.013
#   → HTTP 400: XML not available
# [4939/5000] DOI: 10.2320/matertrans.M2009432
#   → HTTP 404: XML not available
# [4940/5000] DOI: 10.1016/j.ultrasmedbio.2022.08.014
#   → Stage 1: PASS | Keywords: ['acoustic']
# [4941/5000] DOI: 10.1016/j.ultrasmedbio.2012.07.015
#   → HTTP 400: XML not available
# [4942/5000] DOI: 10.1016/j.ultrasmedbio.2009.03.015
#   → HTTP 400: XML not available
# [4943/5000] DOI: 10.1016/j.ijthermalsci.2023.108582
#   → HTTP 400: XML not available
# [4944/5000] DOI: 10.1016/j.apsusc.2011.06.153
#   → HTTP 400: XML not available
# [4945/5000] DOI: 10.1117/12.812994
#   → HTTP 404: XML not available
# [4946/5000] DOI: 10.1109/TUFFC.2012.2253
#   → HTTP 404: XML not available
# [4947/5000] DOI: 10.1143/JJAP.47.4176
#   → HTTP 404: XML not available
# [4948/5000] DOI: 10.3390/s18051327
#   → HTTP 404: XML not available
# [4949/5000] DOI: 10.1016/j.ultras.2009.02.002
#   → HTTP 400: XML not available
# [4950/5000] DOI: 10.1016/S0041-624X(97)00009-7
#   → HTTP 400: XML not available
# [4951/5000] DOI: 10.1016/S1003-6326(11)60779-6
#   → HTTP 400: XML not available
# [4952/5000] DOI: 10.1117/12.847603
#   → HTTP 404: XML not available
# [4953/5000] DOI: 10.3390/ma14112988
#   → HTTP 404: XML not available
# [4954/5000] DOI: 10.1007/s11433-021-1744-x
#   → HTTP 404: XML not available
# [4955/5000] DOI: 10.1109/JLT.2009.2024088
#   → HTTP 404: XML not available
# [4956/5000] DOI: nan
# [4957/5000] DOI: 10.1179/mst.1993.9.7.609
#   → HTTP 404: XML not available
# [4958/5000] DOI: 10.1121/1.2756969
#   → HTTP 404: XML not available
# [4959/5000] DOI: 10.1109/ULTSYM.2008.0495
#   → HTTP 404: XML not available
# [4960/5000] DOI: 10.1016/0041-624X(90)90076-Z
#   → HTTP 400: XML not available
# [4961/5000] DOI: 10.1016/j.ultrasmedbio.2008.12.014
#   → HTTP 400: XML not available
# [4962/5000] DOI: 10.1007/s10765-014-1773-3
#   → HTTP 404: XML not available
# [4963/5000] DOI: 10.1117/12.894056
#   → HTTP 404: XML not available
# [4964/5000] DOI: 10.1016/j.ultras.2009.09.025
#   → HTTP 400: XML not available
# [4965/5000] DOI: 10.1121/1.3519408
#   → HTTP 404: XML not available
# [4966/5000] DOI: 10.1016/j.ultras.2006.07.016
#   → HTTP 400: XML not available
# [4967/5000] DOI: 10.1117/12.2081449
#   → HTTP 404: XML not available
# [4968/5000] DOI: 10.1121/1.390975
#   → HTTP 404: XML not available
# [4969/5000] DOI: 10.1117/12.841479
#   → HTTP 404: XML not available
# [4970/5000] DOI: 10.1016/j.ultras.2008.03.013
#   → HTTP 400: XML not available
# [4971/5000] DOI: 10.1063/1.4789068
#   → HTTP 404: XML not available
# [4972/5000] DOI: 10.1088/1742-6596/656/1/012027
#   → HTTP 404: XML not available
# [4973/5000] DOI: 10.1063/5.0088503
#   → HTTP 404: XML not available
# [4974/5000] DOI: 10.1121/1.398344
#   → HTTP 404: XML not available
# [4975/5000] DOI: 10.1109/TUFFC.2021.3111710
#   → HTTP 404: XML not available
# [4976/5000] DOI: 10.1109/ULTSYM.2008.0520
#   → HTTP 404: XML not available
# [4977/5000] DOI: 10.3390/s23135788
#   → HTTP 404: XML not available
# [4978/5000] DOI: 10.1143/jjap.39.3184
#   → HTTP 404: XML not available
# [4979/5000] DOI: 10.1016/j.ultras.2005.04.001
#   → HTTP 400: XML not available
# [4980/5000] DOI: 10.1016/j.ultrasmedbio.2010.10.001
#   → HTTP 400: XML not available
# [4981/5000] DOI: 10.1016/0301-5629(90)90104-K
#   → HTTP 400: XML not available
# [4982/5000] DOI: 10.1109/ULTSYM.2008.0002
#   → HTTP 404: XML not available
# [4983/5000] DOI: 10.1117/12.2037299
#   → HTTP 404: XML not available
# [4984/5000] DOI: 10.3390/bios13050528
#   → HTTP 404: XML not available
# [4985/5000] DOI: 10.1016/j.wear.2008.04.030
#   → HTTP 400: XML not available
# [4986/5000] DOI: 10.12693/APhysPolA.106.239
#   → HTTP 404: XML not available
# [4987/5000] DOI: 10.1088/1361-6501/abfced
#   → HTTP 404: XML not available
# [4988/5000] DOI: 10.1121/1.3626133
#   → HTTP 404: XML not available
# [4989/5000] DOI: 10.1364/OL.35.002633
#   → HTTP 404: XML not available
# [4990/5000] DOI: 10.1109/ULTSYM.1992.275927
#   → HTTP 404: XML not available
# [4991/5000] DOI: 10.1016/0041-624X(91)90169-9
#   → HTTP 400: XML not available
# [4992/5000] DOI: 10.1016/j.ultrasmedbio.2012.04.019
#   → HTTP 400: XML not available
# [4993/5000] DOI: 10.1016/S0921-5107(00)00792-3
#   → HTTP 400: XML not available
# [4994/5000] DOI: 10.1080/10589750802588028
#   → HTTP 404: XML not available
# [4995/5000] DOI: 10.1143/JJAP.48.07GK10
#   → HTTP 404: XML not available
# [4996/5000] DOI: 10.1016/j.ultras.2021.106630
#   → HTTP 400: XML not available
# [4997/5000] DOI: 10.1016/j.ultras.2019.105967
#   → HTTP 400: XML not available
# [4998/5000] DOI: 10.1016/j.ultrasmedbio.2015.09.004
#   → HTTP 400: XML not available
# [4999/5000] DOI: 10.1109/ULTSYM.2010.5935705
#   → HTTP 404: XML not available
# [5000/5000] DOI: 10.1109/ULTSYM.2018.8579732
#   → HTTP 404: XML not available
#
# ✓ Stage 1 complete.
#   Passed : 205
#   Dropped: 96

# %%
# ─────────────────────────────────────────────
# BLOCK 5: Stage 2 — OCR Keyword Filter
# For papers that passed Stage 1, downloads
# images TEMPORARILY (in memory only),
# runs Tesseract OCR, and scans for keywords.
# No images are saved to disk.
# ─────────────────────────────────────────────

stage2_results = []

# Only process papers that passed Stage 1
stage1_passed = df[df['stage1_status'] == 'passed_stage1']
print(f"Running Stage 2 on {len(stage1_passed)} papers...\n")

for i, row in stage1_passed.iterrows():
    figure_csv_path = os.path.join(CSV_DIR, f'output{i+1}.csv')

    if not os.path.exists(figure_csv_path):
        print(f"[{i+1}] Figure CSV not found — skipping")
        stage2_results.append({'index': i, 'stage2_status': 'no_figure_csv', 'stage2_matched_kws': ''})
        continue

    dof = pd.read_csv(figure_csv_path)
    print(f"[{i+1}] Processing {len(dof[dof['stage1_hit'] == 1])} stage-1 figures...")

    paper_matched = []

    for j, fig_row in dof[dof['stage1_hit'] == 1].iterrows():
        url = fig_row['link']
        ocr_status, text, matched = ocr_image_from_url(url, KEYWORDS)

        dof.at[j, 'stage2_ocr_status']   = ocr_status
        dof.at[j, 'stage2_ocr_text']      = text
        dof.at[j, 'stage2_keywords']      = ', '.join(matched)
        dof.at[j, 'stage2_hit']           = 1 if ocr_status == 2 else 0

        if ocr_status == 2:
            print(f"  Figure {j}: OCR MATCH — {matched}")
            paper_matched.extend(matched)

    # Save updated figure CSV with stage2 columns
    dof.to_csv(figure_csv_path, index=False)

    paper_hit = bool(paper_matched)
    status    = 'passed_stage2' if paper_hit else 'dropped_stage2'
    print(f"  → Stage 2: {'PASS' if paper_hit else 'DROP'}\n")

    stage2_results.append({
        'index':               i,
        'stage2_status':       status,
        'stage2_matched_kws':  ', '.join(set(paper_matched)),
    })

# ── Attach Stage 2 results to main dataframe ──────────────
s2_df = pd.DataFrame(stage2_results).set_index('index')
df = df.join(s2_df)

# Papers that never reached Stage 2 get a clear label
df['stage2_status']      = df['stage2_status'].fillna('not_processed_stage2')
df['stage2_matched_kws'] = df['stage2_matched_kws'].fillna('')

print(f"\n✓ Stage 2 complete.")
print(f"  Passed : {(df['stage2_status'] == 'passed_stage2').sum()}")
print(f"  Dropped: {(df['stage2_status'] == 'dropped_stage2').sum()}")
# Out:
# Running Stage 2 on 205 papers...
#
# [8] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [12] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [17] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [69] Processing 7 stage-1 figures...
#   → Stage 2: DROP
#
# [112] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [128] Processing 6 stage-1 figures...
#   Figure 4: OCR MATCH — ['amplitude']
#   → Stage 2: PASS
#
# [150] Processing 4 stage-1 figures...
#   Figure 3: OCR MATCH — ['frequency', 'hz']
#   Figure 13: OCR MATCH — ['acoustic']
#   → Stage 2: PASS
#
# [175] Processing 6 stage-1 figures...
#   → Stage 2: DROP
#
# [213] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [240] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [242] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [244] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [245] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [296] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [299] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [332] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [447] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [454] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [466] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [494] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [505] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [541] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [550] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [562] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [621] Processing 2 stage-1 figures...
#   Figure 7: OCR MATCH — ['wave']
#   → Stage 2: PASS
#
# [658] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [681] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [687] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [702] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [714] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [720] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [732] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [733] Processing 8 stage-1 figures...
#   → Stage 2: DROP
#
# [750] Processing 4 stage-1 figures...
#   Figure 1: OCR MATCH — ['wave']
#   Figure 2: OCR MATCH — ['frequency']
#   → Stage 2: PASS
#
# [784] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [835] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [888] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [896] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [1002] Processing 9 stage-1 figures...
#   Figure 4: OCR MATCH — ['frequency', 'hz']
#   Figure 6: OCR MATCH — ['frequency']
#   → Stage 2: PASS
#
# [1017] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [1041] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [1049] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [1068] Processing 10 stage-1 figures...
#   Figure 0: OCR MATCH — ['wave']
#   Figure 1: OCR MATCH — ['amplitude']
#   Figure 9: OCR MATCH — ['frequency']
#   Figure 10: OCR MATCH — ['amplitude']
#   → Stage 2: PASS
#
# [1101] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [1108] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [1151] Processing 7 stage-1 figures...
#   Figure 2: OCR MATCH — ['frequency']
#   → Stage 2: PASS
#
# [1277] Processing 7 stage-1 figures...
#   → Stage 2: DROP
#
# [1308] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [1331] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [1335] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [1336] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [1338] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [1344] Processing 6 stage-1 figures...
#   → Stage 2: DROP
#
# [1398] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [1405] Processing 1 stage-1 figures...
#   Figure 0: OCR MATCH — ['hz']
#   → Stage 2: PASS
#
# [1416] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [1455] Processing 1 stage-1 figures...
#   Figure 3: OCR MATCH — ['acoustic']
#   → Stage 2: PASS
#
# [1479] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [1481] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [1490] Processing 13 stage-1 figures...
#   → Stage 2: DROP
#
# [1514] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [1515] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [1517] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [1531] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [1539] Processing 6 stage-1 figures...
#   Figure 2: OCR MATCH — ['amplitude']
#   → Stage 2: PASS
#
# [1600] Processing 5 stage-1 figures...
#   Figure 3: OCR MATCH — ['wavelength']
#   Figure 4: OCR MATCH — ['wavelength']
#   → Stage 2: PASS
#
# [1602] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [1618] Processing 7 stage-1 figures...
#   → Stage 2: DROP
#
# [1622] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [1629] Processing 8 stage-1 figures...
#   → Stage 2: DROP
#
# [1635] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [1636] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [1677] Processing 6 stage-1 figures...
#   Figure 0: OCR MATCH — ['frequency']
#   → Stage 2: PASS
#
# [1695] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [1711] Processing 7 stage-1 figures...
#   → Stage 2: DROP
#
# [1762] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [1766] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [1772] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [1778] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [1796] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [1835] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [1843] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [1889] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [1908] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [1910] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [1919] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [1945] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [1984] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [1999] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [2008] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [2045] Processing 10 stage-1 figures...
#   → Stage 2: DROP
#
# [2055] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [2056] Processing 7 stage-1 figures...
#   → Stage 2: DROP
#
# [2060] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [2072] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [2096] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [2117] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [2129] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [2132] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [2172] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [2177] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [2209] Processing 6 stage-1 figures...
#   → Stage 2: DROP
#
# [2211] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [2229] Processing 2 stage-1 figures...
#   Figure 1: OCR MATCH — ['amplitude']
#   Figure 2: OCR MATCH — ['wavelength']
#   → Stage 2: PASS
#
# [2258] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [2267] Processing 4 stage-1 figures...
#   Figure 0: OCR MATCH — ['frequency']
#   Figure 1: OCR MATCH — ['frequency']
#   Figure 5: OCR MATCH — ['frequency']
#   Figure 6: OCR MATCH — ['frequency']
#   → Stage 2: PASS
#
# [2270] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [2271] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [2275] Processing 7 stage-1 figures...
#   Figure 1: OCR MATCH — ['acoustic']
#   → Stage 2: PASS
#
# [2311] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [2346] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [2404] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [2413] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [2414] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [2434] Processing 7 stage-1 figures...
#   → Stage 2: DROP
#
# [2481] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [2502] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [2508] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [2531] Processing 6 stage-1 figures...
#   Figure 2: OCR MATCH — ['wave']
#   → Stage 2: PASS
#
# [2539] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [2549] Processing 1 stage-1 figures...
#   Figure 1: OCR MATCH — ['acoustic']
#   → Stage 2: PASS
#
# [2561] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [2563] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [2572] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [2582] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [2659] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [2699] Processing 3 stage-1 figures...
#   Figure 0: OCR MATCH — ['frequency', 'hz', 'spectrum']
#   → Stage 2: PASS
#
# [2726] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [2742] Processing 7 stage-1 figures...
#   → Stage 2: DROP
#
# [2749] Processing 5 stage-1 figures...
#   Figure 4: OCR MATCH — ['acoustic']
#   → Stage 2: PASS
#
# [2763] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [2783] Processing 5 stage-1 figures...
#   Figure 8: OCR MATCH — ['spectrum']
#   → Stage 2: PASS
#
# [2799] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [2810] Processing 2 stage-1 figures...
#   Figure 1: OCR MATCH — ['frequency']
#   → Stage 2: PASS
#
# [2817] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [2836] Processing 2 stage-1 figures...
#   Figure 3: OCR MATCH — ['amplitude']
#   Figure 7: OCR MATCH — ['wavelength']
#   → Stage 2: PASS
#
# [2846] Processing 7 stage-1 figures...
#   Figure 0: OCR MATCH — ['amplitude']
#   Figure 1: OCR MATCH — ['amplitude']
#   Figure 6: OCR MATCH — ['amplitude']
#   → Stage 2: PASS
#
# [2880] Processing 5 stage-1 figures...
#   Figure 9: OCR MATCH — ['acoustic']
#   → Stage 2: PASS
#
# [2907] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [2931] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [2944] Processing 5 stage-1 figures...
#   Figure 1: OCR MATCH — ['frequency', 'amplitude']
#   Figure 2: OCR MATCH — ['amplitude', 'hz']
#   Figure 5: OCR MATCH — ['frequency']
#   → Stage 2: PASS
#
# [2958] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [2996] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [3015] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [3085] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [3091] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [3095] Processing 8 stage-1 figures...
#   → Stage 2: DROP
#
# [3151] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [3158] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [3176] Processing 6 stage-1 figures...
#   Figure 1: OCR MATCH — ['amplitude', 'acoustic']
#   Figure 2: OCR MATCH — ['amplitude']
#   → Stage 2: PASS
#
# [3183] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [3253] Processing 6 stage-1 figures...
#   Figure 0: OCR MATCH — ['frequency', 'amplitude', 'hz']
#   Figure 2: OCR MATCH — ['frequency', 'hz']
#   Figure 6: OCR MATCH — ['amplitude']
#   Figure 8: OCR MATCH — ['frequency', 'hz']
#   → Stage 2: PASS
#
# [3255] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [3270] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [3327] Processing 5 stage-1 figures...
#   Figure 14: OCR MATCH — ['acoustic']
#   → Stage 2: PASS
#
# [3388] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [3389] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [3405] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [3474] Processing 11 stage-1 figures...
#   Figure 8: OCR MATCH — ['frequency']
#   → Stage 2: PASS
#
# [3475] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [3481] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [3564] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [3576] Processing 4 stage-1 figures...
#   Figure 7: OCR MATCH — ['amplitude']
#   → Stage 2: PASS
#
# [3632] Processing 4 stage-1 figures...
#   Figure 0: OCR MATCH — ['acoustic']
#   Figure 4: OCR MATCH — ['acoustic']
#   → Stage 2: PASS
#
# [3664] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [3671] Processing 11 stage-1 figures...
#   → Stage 2: DROP
#
# [3774] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [3829] Processing 9 stage-1 figures...
#   Figure 1: OCR MATCH — ['frequency']
#   → Stage 2: PASS
#
# [3893] Processing 7 stage-1 figures...
#   Figure 6: OCR MATCH — ['acoustic']
#   → Stage 2: PASS
#
# [3935] Processing 4 stage-1 figures...
#   Figure 1: OCR MATCH — ['frequency']
#   Figure 2: OCR MATCH — ['frequency', 'amplitude']
#   Figure 3: OCR MATCH — ['frequency']
#   → Stage 2: PASS
#
# [3968] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [3973] Processing 8 stage-1 figures...
#   Figure 6: OCR MATCH — ['acoustic']
#   → Stage 2: PASS
#
# [3983] Processing 6 stage-1 figures...
#   → Stage 2: DROP
#
# [4033] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [4051] Processing 6 stage-1 figures...
#   → Stage 2: DROP
#
# [4109] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [4111] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [4127] Processing 9 stage-1 figures...
#   Figure 12: OCR MATCH — ['acoustic']
#   → Stage 2: PASS
#
# [4132] Processing 3 stage-1 figures...
#   Figure 1: OCR MATCH — ['frequency']
#   Figure 2: OCR MATCH — ['frequency']
#   → Stage 2: PASS
#
# [4167] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [4178] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [4185] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [4193] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [4234] Processing 3 stage-1 figures...
#   Figure 1: OCR MATCH — ['frequency']
#   → Stage 2: PASS
#
# [4272] Processing 2 stage-1 figures...
#   Figure 7: OCR MATCH — ['wavelength', 'acoustic']
#   → Stage 2: PASS
#
# [4315] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [4317] Processing 4 stage-1 figures...
#   Figure 2: OCR MATCH — ['frequency', 'hz']
#   Figure 6: OCR MATCH — ['frequency', 'amplitude', 'hz']
#   Figure 7: OCR MATCH — ['frequency', 'hz']
#   → Stage 2: PASS
#
# [4348] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [4353] Processing 5 stage-1 figures...
#   Figure 3: OCR MATCH — ['amplitude']
#   → Stage 2: PASS
#
# [4404] Processing 8 stage-1 figures...
#   → Stage 2: DROP
#
# [4424] Processing 4 stage-1 figures...
#   Figure 1: OCR MATCH — ['acoustic']
#   Figure 4: OCR MATCH — ['acoustic']
#   → Stage 2: PASS
#
# [4444] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [4492] Processing 2 stage-1 figures...
#   → Stage 2: DROP
#
# [4532] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [4591] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [4612] Processing 5 stage-1 figures...
#   → Stage 2: DROP
#
# [4613] Processing 4 stage-1 figures...
#   Figure 6: OCR MATCH — ['amplitude']
#   → Stage 2: PASS
#
# [4658] Processing 4 stage-1 figures...
#   → Stage 2: DROP
#
# [4705] Processing 8 stage-1 figures...
#   Figure 0: OCR MATCH — ['frequency']
#   Figure 2: OCR MATCH — ['frequency']
#   Figure 4: OCR MATCH — ['frequency']
#   Figure 6: OCR MATCH — ['frequency']
#   Figure 7: OCR MATCH — ['frequency']
#   → Stage 2: PASS
#
# [4745] Processing 5 stage-1 figures...
#   Figure 7: OCR MATCH — ['attenuation']
#   → Stage 2: PASS
#
# [4838] Processing 9 stage-1 figures...
#   Figure 4: OCR MATCH — ['frequency', 'acoustic', 'hz']
#   Figure 5: OCR MATCH — ['hz']
#   Figure 6: OCR MATCH — ['acoustic']
#   Figure 7: OCR MATCH — ['hz']
#   Figure 8: OCR MATCH — ['amplitude', 'acoustic']
#   Figure 9: OCR MATCH — ['frequency', 'amplitude', 'acoustic', 'hz']
#   Figure 10: OCR MATCH — ['hz']
#   → Stage 2: PASS
#
# [4847] Processing 4 stage-1 figures...
#   Figure 2: OCR MATCH — ['frequency']
#   Figure 3: OCR MATCH — ['frequency']
#   Figure 4: OCR MATCH — ['acoustic']
#   → Stage 2: PASS
#
# [4896] Processing 1 stage-1 figures...
#   → Stage 2: DROP
#
# [4927] Processing 3 stage-1 figures...
#   → Stage 2: DROP
#
# [4940] Processing 2 stage-1 figures...
#   Figure 3: OCR MATCH — ['frequency', 'spectrum']
#   → Stage 2: PASS
#
#
# ✓ Stage 2 complete.
#   Passed : 48
#   Dropped: 157

# %%
# ─────────────────────────────────────────────
# BLOCK 6: Save Outputs
# 1. tracker.csv  — every paper with status at
#    each stage and reason for dropping
# 2. relevant_papers.csv — papers that passed
#    both stages, with full original metadata
# ─────────────────────────────────────────────

# ── Derive a single human-readable "final_status" column ──
def get_final_status(row):
    s1 = row.get('stage1_status', '')
    s2 = row.get('stage2_status', '')
    if s1 in ('no_xml', 'parse_error', 'skipped'):
        return f'dropped — {s1}'
    if s1 == 'dropped_stage1':
        return 'dropped — no caption keywords (stage 1)'
    if s2 == 'dropped_stage2':
        return 'dropped — no OCR keywords (stage 2)'
    if s2 == 'passed_stage2':
        return 'relevant'
    return 'undetermined'

df['final_status'] = df.apply(get_final_status, axis=1)

# ── tracker.csv — full picture of every paper ─────────────
tracker_cols = [
    'Authors', 'Author full names', "Author(s) ID",
    'Year', 'Cited by', 'DOI', 'Link',
    'stage1_status', 'stage1_matched_kws',
    'stage2_status', 'stage2_matched_kws',
    'final_status',
]
# Keep only columns that actually exist in df
tracker_cols = [c for c in tracker_cols if c in df.columns]
df[tracker_cols].to_csv(TRACKER_OUT, index=False)
print(f"✓ Tracker saved → {TRACKER_OUT}")

# ── relevant_papers.csv — only the papers that made it ────
relevant = df[df['final_status'] == 'relevant'].copy()
relevant.to_csv(RELEVANT_OUT, index=False)
print(f"✓ Relevant papers saved → {RELEVANT_OUT}")
print(f"\n  Total papers    : {len(df)}")
print(f"  Relevant        : {len(relevant)}")
print(f"  Dropped stage 1 : {(df['stage1_status'] == 'dropped_stage1').sum()}")
print(f"  Dropped stage 2 : {(df['stage2_status'] == 'dropped_stage2').sum()}")
print(f"  No XML / errors : {df['stage1_status'].isin(['no_xml','parse_error','skipped']).sum()}")
# Out:
# ✓ Tracker saved → /content/drive/MyDrive/final_ugp/pipeline/tracker.csv
# ✓ Relevant papers saved → /content/drive/MyDrive/final_ugp/pipeline/relevant_papers.csv
#
#   Total papers    : 5000
#   Relevant        : 48
#   Dropped stage 1 : 96
#   Dropped stage 2 : 157
#   No XML / errors : 4699
